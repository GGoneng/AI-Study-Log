# %% [markdown]
# #### Ensemble - ExtraTree
# - 배깅 방식의 앙상블 ==> 중복 랜덤 샘플 + 동일 모델(DT)
#     * RandomForest:
#
# - 페이스트 방식의 앙상블 ==> 랜덤 샘플 + 동일 모델(DT)
#     * 대표 알고리즘 : ExtraTreeC/R

# %% [markdown]
# [목표] 와인 분류 => 0과 1 2개 종류 분류

# %% [markdown]
# [1] 모듈 로딩 및 데이터 준비

# %%
# 모듈 로딩
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
DATA_FILE = '../Data/wine.csv'

wineDF = pd.read_csv(DATA_FILE)

# %%
# 데이터 확인
wineDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   alcohol  6497 non-null   float64
#  1   sugar    6497 non-null   float64
#  2   pH       6497 non-null   float64
#  3   class    6497 non-null   float64
# dtypes: float64(4)
# memory usage: 203.2 KB

# %%
wineDF.head(2)
# Out:
#    alcohol  sugar    pH  class
# 0      9.4    1.9  3.51    0.0
# 1      9.8    2.6  3.20    0.0

# %%
# 타겟 / 라벨의 클래스 분포
wineDF['class'].value_counts()
# Out:
# class
# 1.0    4898
# 0.0    1599
# Name: count, dtype: int64

# %%
wineDF.describe()
# Out:
#            alcohol        sugar           pH        class
# count  6497.000000  6497.000000  6497.000000  6497.000000
# mean     10.491801     5.443235     3.218501     0.753886
# std       1.192712     4.757804     0.160787     0.430779
# min       8.000000     0.600000     2.720000     0.000000
# 25%       9.500000     1.800000     3.110000     1.000000
# 50%      10.300000     3.000000     3.210000     1.000000
# 75%      11.300000     8.100000     3.320000     1.000000
# max      14.900000    65.800000     4.010000     1.000000

# %% [markdown]
# [2] 학습 준비

# %%
# 학습용 & 테스트용 데이터셋 분할
from sklearn.model_selection import train_test_split

# %%
# 피쳐/독립변수와 타겟/라벨/종속변수 분리

featureDF = wineDF[wineDF.columns[:-1]]
targetSR = wineDF[wineDF.columns[-1]]

print(f'featureDF : {featureDF.shape}  targetSR : {targetSR.shape}')
# Out:
# featureDF : (6497, 3)  targetSR : (6497,)

# %%
# 학습용, 테스트용 데이터셋 분리
X_train, X_test, y_train, y_test = train_test_split(featureDF,
                                                    targetSR,
                                                    test_size = 0.2,
                                                    stratify = targetSR,
                                                    random_state = 1)

# %%
print(f'X_Train : {X_train.shape} y_train : {y_train.shape}')
print(f'X_Test : {X_test.shape}  y_test : {y_test.shape}')
# Out:
# X_Train : (5197, 3) y_train : (5197,)
# X_Test : (1300, 3)  y_test : (1300,)

# %% [markdown]
# [3] 학습 진행

# %%
# 학습방법 : 지도학습 > 분류
# 알고리즘 : 앙상블 > 배깅 - RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier

# %%
# 인스턴스 생성 => 100개의 내부 DT 모델에서 사용할 데이터셋 생성
#                 random_state 매개변수 설정으로 고정된 데이터셋 생성
#                 ood_score 매개변수 : 샘플 데이터셋 추출 후 남은 데이터셋 검증용으로 사용
lf_model = ExtraTreesClassifier(random_state = 7)

# 학습
lf_model.fit(X_train, y_train)
# Out:
# ExtraTreesClassifier(random_state=7)

# %%
# 모델 파라미터
print(f"classes_ : {lf_model.classes_}")
print(F"n_classes_ : {lf_model.n_classes_}개")
print()
print(f"feature_names_in_ : {lf_model.feature_names_in_}")
print(F"n_features_in : {lf_model.n_features_in_}개")
print(f"feature_importances_ : {lf_model.feature_importances_}")
# Out:
# classes_ : [0. 1.]
# n_classes_ : 2개
#
# feature_names_in_ : ['alcohol' 'sugar' 'pH']
# n_features_in : 3개
# feature_importances_ : [0.18992806 0.53030305 0.2797689 ]

# %%
# 모델 파라미터
print(f'classes_     : {lf_model.estimator_}')
for est in lf_model.estimators_:
    print(est)
# Out:
# classes_     : ExtraTreeClassifier()
# ExtraTreeClassifier(random_state=327741615)
# ExtraTreeClassifier(random_state=976413892)
# ExtraTreeClassifier(random_state=1202242073)
# ExtraTreeClassifier(random_state=1369975286)
# ExtraTreeClassifier(random_state=1882953283)
# ExtraTreeClassifier(random_state=2053951699)
# ExtraTreeClassifier(random_state=959775639)
# ExtraTreeClassifier(random_state=1956722279)
# ExtraTreeClassifier(random_state=2052949340)
# ExtraTreeClassifier(random_state=1322904761)
# ExtraTreeClassifier(random_state=165338510)
# ExtraTreeClassifier(random_state=1133316631)
# ExtraTreeClassifier(random_state=4812360)
# ExtraTreeClassifier(random_state=372560217)
# ExtraTreeClassifier(random_state=309457262)
# ExtraTreeClassifier(random_state=1801189930)
# ExtraTreeClassifier(random_state=1152936666)
# ExtraTreeClassifier(random_state=68334472)
# ExtraTreeClassifier(random_state=2146978983)
# ExtraTreeClassifier(random_state=119248870)
# ExtraTreeClassifier(random_state=769786948)
# ExtraTreeClassifier(random_state=1583990192)
# ExtraTreeClassifier(random_state=1304549247)
# ExtraTreeClassifier(random_state=1420943751)
# ExtraTreeClassifier(random_state=1636129708)
# ExtraTreeClassifier(random_state=1687674368)
# ExtraTreeClassifier(random_state=283194443)
# ExtraTreeClassifier(random_state=748743479)
# ExtraTreeClassifier(random_state=1237575930)
# ExtraTreeClassifier(random_state=740097030)
# ExtraTreeClassifier(random_state=1759190803)
# ExtraTreeClassifier(random_state=833359292)
# ExtraTreeClassifier(random_state=916483116)
# ExtraTreeClassifier(random_state=1485942463)
# ExtraTreeClassifier(random_state=1941857605)
# ExtraTreeClassifier(random_state=1844809528)
# ExtraTreeClassifier(random_state=1852015768)
# ExtraTreeClassifier(random_state=1127788727)
# ExtraTreeClassifier(random_state=106941365)
# ExtraTreeClassifier(random_state=1077017712)
# ExtraTreeClassifier(random_state=431854331)
# ExtraTreeClassifier(random_state=1094761661)
# ExtraTreeClassifier(random_state=1933291456)
# ExtraTreeClassifier(random_state=1508798754)
# ExtraTreeClassifier(random_state=989143352)
# ExtraTreeClassifier(random_state=747550921)
# ExtraTreeClassifier(random_state=208262606)
# ExtraTreeClassifier(random_state=1248819750)
# ExtraTreeClassifier(random_state=1757192964)
# ExtraTreeClassifier(random_state=1879603694)
# ExtraTreeClassifier(random_state=571958409)
# ExtraTreeClassifier(random_state=1927692119)
# ExtraTreeClassifier(random_state=100556259)
# ExtraTreeClassifier(random_state=1652057283)
# ExtraTreeClassifier(random_state=1075502152)
# ExtraTreeClassifier(random_state=1535344467)
# ExtraTreeClassifier(random_state=725906352)
# ExtraTreeClassifier(random_state=830456065)
# ExtraTreeClassifier(random_state=2008983232)
# ExtraTreeClassifier(random_state=431532432)
# ExtraTreeClassifier(random_state=879820150)
# ExtraTreeClassifier(random_state=2072909727)
# ExtraTreeClassifier(random_state=2107823453)
# ExtraTreeClassifier(random_state=488352684)
# ExtraTreeClassifier(random_state=1599380060)
# ExtraTreeClassifier(random_state=1938096892)
# ExtraTreeClassifier(random_state=2050422343)
# ExtraTreeClassifier(random_state=1497897239)
# ExtraTreeClassifier(random_state=1571487242)
# ExtraTreeClassifier(random_state=1187621609)
# ExtraTreeClassifier(random_state=1451346723)
# ExtraTreeClassifier(random_state=1917728192)
# ExtraTreeClassifier(random_state=1153832253)
# ExtraTreeClassifier(random_state=1966724487)
# ExtraTreeClassifier(random_state=1348596887)
# ExtraTreeClassifier(random_state=771276892)
# ExtraTreeClassifier(random_state=311923447)
# ExtraTreeClassifier(random_state=612959456)
# ExtraTreeClassifier(random_state=1185621653)
# ExtraTreeClassifier(random_state=358664548)
# ExtraTreeClassifier(random_state=1944945571)
# ExtraTreeClassifier(random_state=202873313)
# ExtraTreeClassifier(random_state=1516030531)
# ExtraTreeClassifier(random_state=1332338555)
# ExtraTreeClassifier(random_state=676025563)
# ExtraTreeClassifier(random_state=1214271969)
# ExtraTreeClassifier(random_state=1590645779)
# ExtraTreeClassifier(random_state=1808153499)
# ExtraTreeClassifier(random_state=1971789316)
# ExtraTreeClassifier(random_state=1861190419)
# ExtraTreeClassifier(random_state=941989921)
# ExtraTreeClassifier(random_state=1798548603)
# ExtraTreeClassifier(random_state=1773786398)
# ExtraTreeClassifier(random_state=2088312505)
# ExtraTreeClassifier(random_state=1745574629)
# ExtraTreeClassifier(random_state=1260873545)
# ExtraTreeClassifier(random_state=775033821)
# ExtraTreeClassifier(random_state=1474484177)
# ExtraTreeClassifier(random_state=1035597695)
# ExtraTreeClassifier(random_state=1289946527)

# %%
# print(f"classes_        : {lf_model.estimators_samples_}")

# %%
# print(f"oob_score_ : {lf_model.oob_score_}")

# %% [markdown]
# [4] 성능 평가

# %%
train_score = lf_model.score(X_train, y_train)
test_score = lf_model.score(X_test, y_test)

# %%
print(f'train_score : {train_score}  test_score : {test_score}')
# Out:
# train_score : 0.9973061381566288  test_score : 0.8961538461538462

# %% [markdown]
# [5] 튜닝
# - RandomizedSearchCV 하이퍼파라미터 최적화 클래스
#     * 범위가 넓은 하이퍼 파라미터 설정
#     * 지정된 범위에서 지정된 횟수만큼 하이퍼 파라미터를 추출하여 조합 진행

# %%
# 모듈 로딩
from sklearn.model_selection import RandomizedSearchCV

# %%
# RandomForestClassifier 하이퍼파라미터 설정
params = {'max_depth' : range(2, 16),
          'min_samples_leaf' : range(5, 16),
          'criterion' : ['gini', 'entropy', 'log_loss']}

# %%
rf_model = ExtraTreesClassifier(n_estimators = 500, random_state = 7)

# %%
searchCV = RandomizedSearchCV(rf_model,
                              param_distributions = params,
                              n_iter = 50,
                              verbose = 4)

# %%
searchCV.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV 1/5] END criterion=gini, max_depth=5, min_samples_leaf=5;, score=0.754 total time=   0.4s
# [CV 2/5] END criterion=gini, max_depth=5, min_samples_leaf=5;, score=0.754 total time=   0.4s
# [CV 3/5] END criterion=gini, max_depth=5, min_samples_leaf=5;, score=0.755 total time=   0.4s
# [CV 4/5] END criterion=gini, max_depth=5, min_samples_leaf=5;, score=0.754 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=5, min_samples_leaf=5;, score=0.754 total time=   0.4s
# [CV 1/5] END criterion=log_loss, max_depth=9, min_samples_leaf=5;, score=0.754 total time=   0.4s
# [CV 2/5] END criterion=log_loss, max_depth=9, min_samples_leaf=5;, score=0.754 total time=   0.4s
# [CV 3/5] END criterion=log_loss, max_depth=9, min_samples_leaf=5;, score=0.755 total time=   0.4s
# [CV 4/5] END criterion=log_loss, max_depth=9, min_samples_leaf=5;, score=0.754 total time=   0.4s
# [CV 5/5] END criterion=log_loss, max_depth=9, min_samples_leaf=5;, score=0.754 total time=   0.4s
# [CV 1/5] END criterion=entropy, max_depth=2, min_samples_leaf=7;, score=0.754 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=2, min_samples_leaf=7;, score=0.754 total time=   0.4s
# [CV 3/5] END criterion=entropy, max_depth=2, min_samples_leaf=7;, score=0.755 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=2, min_samples_leaf=7;, score=0.754 total time=   0.4s
# [CV 5/5] END criterion=entropy, max_depth=2, min_samples_leaf=7;, score=0.754 total time=   0.5s
# [CV 1/5] END criterion=entropy, max_depth=4, min_samples_leaf=15;, score=0.754 total time=   0.4s
# [CV 2/5] END criterion=entropy, max_depth=4, min_samples_leaf=15;, score=0.754 total time=   0.4s
# [CV 3/5] END criterion=entropy, max_depth=4, min_samples_leaf=15;, score=0.755 total time=   0.4s
# [CV 4/5] END criterion=entropy, max_depth=4, min_samples_leaf=15;, score=0.754 total time=   0.4s
# [CV 5/5] END criterion=entropy, max_depth=4, min_samples_leaf=15;, score=0.754 total time=   0.4s
# [CV 1/5] END criterion=gini, max_depth=3, min_samples_leaf=5;, score=0.754 total time=   0.4s
# [CV 2/5] END criterion=gini, max_depth=3, min_samples_leaf=5;, score=0.754 total time=   0.4s
# [CV 3/5] END criterion=gini, max_depth=3, min_samples_leaf=5;, score=0.755 total time=   0.4s
# [CV 4/5] END criterion=gini, max_depth=3, min_samples_leaf=5;, score=0.754 total time=   0.4s
# [CV 5/5] END criterion=gini, max_depth=3, min_samples_leaf=5;, score=0.754 total time=   0.4s
# [CV 1/5] END criterion=gini, max_depth=13, min_samples_leaf=13;, score=0.754 total time=   0.4s
# [CV 2/5] END criterion=gini, max_depth=13, min_samples_leaf=13;, score=0.754 total time=   0.4s
# [CV 3/5] END criterion=gini, max_depth=13, min_samples_leaf=13;, score=0.755 total time=   0.4s
# [CV 4/5] END criterion=gini, max_depth=13, min_samples_leaf=13;, score=0.754 total time=   0.4s
# [CV 5/5] END criterion=gini, max_depth=13, min_samples_leaf=13;, score=0.754 total time=   0.4s
# [CV 1/5] END criterion=log_loss, max_depth=7, min_samples_leaf=8;, score=0.754 total time=   0.5s
# [CV 2/5] END criterion=log_loss, max_depth=7, min_samples_leaf=8;, score=0.754 total time=   0.4s
# [CV 3/5] END criterion=log_loss, max_depth=7, min_samples_leaf=8;, score=0.755 total time=   0.4s
# [CV 4/5] END criterion=log_loss, max_depth=7, min_samples_leaf=8;, score=0.754 total time=   0.4s
# [CV 5/5] END criterion=log_loss, max_depth=7, min_samples_leaf=8;, score=0.754 total time=   0.4s
# [CV 1/5] END criterion=log_loss, max_depth=9, min_samples_leaf=9;, score=0.754 total time=   0.4s
# [CV 2/5] END criterion=log_loss, max_depth=9, min_samples_leaf=9;, score=0.754 total time=   0.4s
# [CV 3/5] END criterion=log_loss, max_depth=9, min_samples_leaf=9;, score=0.755 total time=   0.4s
# [CV 4/5] END criterion=log_loss, max_depth=9, min_samples_leaf=9;, score=0.754 total time=   0.4s
# [CV 5/5] END criterion=log_loss, max_depth=9, min_samples_leaf=9;, score=0.754 total time=   0.4s
# [CV 1/5] END criterion=gini, max_depth=12, min_samples_leaf=12;, score=0.754 total time=   0.4s
# [CV 2/5] END criterion=gini, max_depth=12, min_samples_leaf=12;, score=0.754 total time=   0.4s
# [CV 3/5] END criterion=gini, max_depth=12, min_samples_leaf=12;, score=0.755 total time=   0.4s
# [CV 4/5] END criterion=gini, max_depth=12, min_samples_leaf=12;, score=0.754 total time=   0.4s
# [CV 5/5] END criterion=gini, max_depth=12, min_samples_leaf=12;, score=0.754 total time=   0.4s
# [CV 1/5] END criterion=entropy, max_depth=11, min_samples_leaf=15;, score=0.754 total time=   0.4s
# [CV 2/5] END criterion=entropy, max_depth=11, min_samples_leaf=15;, score=0.754 total time=   0.4s
# [CV 3/5] END criterion=entropy, max_depth=11, min_samples_leaf=15;, score=0.755 total time=   0.4s
# [CV 4/5] END criterion=entropy, max_depth=11, min_samples_leaf=15;, score=0.754 total time=   0.4s
# [CV 5/5] END criterion=entropy, max_depth=11, min_samples_leaf=15;, score=0.754 total time=   0.4s
# [CV 1/5] END criterion=gini, max_depth=12, min_samples_leaf=5;, score=0.754 total time=   0.4s
# [CV 2/5] END criterion=gini, max_depth=12, min_samples_leaf=5;, score=0.754 total time=   0.4s
# [CV 3/5] END criterion=gini, max_depth=12, min_samples_leaf=5;, score=0.755 total time=   0.5s
# [CV 4/5] END criterion=gini, max_depth=12, min_samples_leaf=5;, score=0.754 total time=   0.5s
# [CV 5/5] END criterion=gini, max_depth=12, min_samples_leaf=5;, score=0.754 total time=   0.5s
# [CV 1/5] END criterion=log_loss, max_depth=2, min_samples_leaf=9;, score=0.754 total time=   0.4s
# [CV 2/5] END criterion=log_loss, max_depth=2, min_samples_leaf=9;, score=0.754 total time=   0.4s
# [CV 3/5] END criterion=log_loss, max_depth=2, min_samples_leaf=9;, score=0.755 total time=   0.4s
# [CV 4/5] END criterion=log_loss, max_depth=2, min_samples_leaf=9;, score=0.754 total time=   0.4s
# [CV 5/5] END criterion=log_loss, max_depth=2, min_samples_leaf=9;, score=0.754 total time=   0.4s
# [CV 1/5] END criterion=gini, max_depth=2, min_samples_leaf=10;, score=0.754 total time=   0.4s
# [CV 2/5] END criterion=gini, max_depth=2, min_samples_leaf=10;, score=0.754 total time=   0.4s
# [CV 3/5] END criterion=gini, max_depth=2, min_samples_leaf=10;, score=0.755 total time=   0.4s
# [CV 4/5] END criterion=gini, max_depth=2, min_samples_leaf=10;, score=0.754 total time=   0.4s
# [CV 5/5] END criterion=gini, max_depth=2, min_samples_leaf=10;, score=0.754 total time=   0.4s
# [CV 1/5] END criterion=gini, max_depth=13, min_samples_leaf=10;, score=0.754 total time=   0.4s
# [CV 2/5] END criterion=gini, max_depth=13, min_samples_leaf=10;, score=0.754 total time=   0.5s
# [CV 3/5] END criterion=gini, max_depth=13, min_samples_leaf=10;, score=0.755 total time=   0.4s
# [CV 4/5] END criterion=gini, max_depth=13, min_samples_leaf=10;, score=0.754 total time=   0.4s
# [CV 5/5] END criterion=gini, max_depth=13, min_samples_leaf=10;, score=0.754 total time=   0.5s
# [CV 1/5] END criterion=entropy, max_depth=7, min_samples_leaf=12;, score=0.754 total time=   0.4s
# [CV 2/5] END criterion=entropy, max_depth=7, min_samples_leaf=12;, score=0.754 total time=   0.4s
# [CV 3/5] END criterion=entropy, max_depth=7, min_samples_leaf=12;, score=0.755 total time=   0.4s
# [CV 4/5] END criterion=entropy, max_depth=7, min_samples_leaf=12;, score=0.754 total time=   0.4s
# [CV 5/5] END criterion=entropy, max_depth=7, min_samples_leaf=12;, score=0.754 total time=   0.4s
# [CV 1/5] END criterion=log_loss, max_depth=4, min_samples_leaf=5;, score=0.754 total time=   0.4s
# [CV 2/5] END criterion=log_loss, max_depth=4, min_samples_leaf=5;, score=0.754 total time=   0.4s
# [CV 3/5] END criterion=log_loss, max_depth=4, min_samples_leaf=5;, score=0.755 total time=   0.4s
# [CV 4/5] END criterion=log_loss, max_depth=4, min_samples_leaf=5;, score=0.754 total time=   0.4s
# [CV 5/5] END criterion=log_loss, max_depth=4, min_samples_leaf=5;, score=0.754 total time=   0.5s
# [CV 1/5] END criterion=gini, max_depth=8, min_samples_leaf=9;, score=0.754 total time=   0.4s
# [CV 2/5] END criterion=gini, max_depth=8, min_samples_leaf=9;, score=0.754 total time=   0.5s
# [CV 3/5] END criterion=gini, max_depth=8, min_samples_leaf=9;, score=0.755 total time=   0.5s
# [CV 4/5] END criterion=gini, max_depth=8, min_samples_leaf=9;, score=0.754 total time=   0.4s
# [CV 5/5] END criterion=gini, max_depth=8, min_samples_leaf=9;, score=0.754 total time=   0.5s
# [CV 1/5] END criterion=entropy, max_depth=13, min_samples_leaf=9;, score=0.754 total time=   0.6s
# [CV 2/5] END criterion=entropy, max_depth=13, min_samples_leaf=9;, score=0.754 total time=   0.6s
# [CV 3/5] END criterion=entropy, max_depth=13, min_samples_leaf=9;, score=0.755 total time=   0.6s
# [CV 4/5] END criterion=entropy, max_depth=13, min_samples_leaf=9;, score=0.754 total time=   0.6s
# [CV 5/5] END criterion=entropy, max_depth=13, min_samples_leaf=9;, score=0.754 total time=   0.7s
# [CV 1/5] END criterion=entropy, max_depth=15, min_samples_leaf=14;, score=0.754 total time=   0.7s
# [CV 2/5] END criterion=entropy, max_depth=15, min_samples_leaf=14;, score=0.754 total time=   0.6s
# [CV 3/5] END criterion=entropy, max_depth=15, min_samples_leaf=14;, score=0.755 total time=   0.7s
# [CV 4/5] END criterion=entropy, max_depth=15, min_samples_leaf=14;, score=0.754 total time=   0.7s
# [CV 5/5] END criterion=entropy, max_depth=15, min_samples_leaf=14;, score=0.754 total time=   0.7s
# [CV 1/5] END criterion=log_loss, max_depth=11, min_samples_leaf=14;, score=0.754 total time=   0.6s
# [CV 2/5] END criterion=log_loss, max_depth=11, min_samples_leaf=14;, score=0.754 total time=   0.7s
# [CV 3/5] END criterion=log_loss, max_depth=11, min_samples_leaf=14;, score=0.755 total time=   0.7s
# [CV 4/5] END criterion=log_loss, max_depth=11, min_samples_leaf=14;, score=0.754 total time=   0.7s
# [CV 5/5] END criterion=log_loss, max_depth=11, min_samples_leaf=14;, score=0.754 total time=   0.7s
# [CV 1/5] END criterion=log_loss, max_depth=9, min_samples_leaf=10;, score=0.754 total time=   0.6s
# [CV 2/5] END criterion=log_loss, max_depth=9, min_samples_leaf=10;, score=0.754 total time=   0.7s
# [CV 3/5] END criterion=log_loss, max_depth=9, min_samples_leaf=10;, score=0.755 total time=   0.7s
# [CV 4/5] END criterion=log_loss, max_depth=9, min_samples_leaf=10;, score=0.754 total time=   0.7s
# [CV 5/5] END criterion=log_loss, max_depth=9, min_samples_leaf=10;, score=0.754 total time=   0.7s
# [CV 1/5] END criterion=gini, max_depth=8, min_samples_leaf=5;, score=0.754 total time=   0.7s
# [CV 2/5] END criterion=gini, max_depth=8, min_samples_leaf=5;, score=0.754 total time=   0.7s
# [CV 3/5] END criterion=gini, max_depth=8, min_samples_leaf=5;, score=0.755 total time=   0.7s
# [CV 4/5] END criterion=gini, max_depth=8, min_samples_leaf=5;, score=0.754 total time=   0.7s
# [CV 5/5] END criterion=gini, max_depth=8, min_samples_leaf=5;, score=0.754 total time=   0.7s
# [CV 1/5] END criterion=entropy, max_depth=2, min_samples_leaf=11;, score=0.754 total time=   0.7s
# [CV 2/5] END criterion=entropy, max_depth=2, min_samples_leaf=11;, score=0.754 total time=   0.6s
# [CV 3/5] END criterion=entropy, max_depth=2, min_samples_leaf=11;, score=0.755 total time=   0.6s
# [CV 4/5] END criterion=entropy, max_depth=2, min_samples_leaf=11;, score=0.754 total time=   0.6s
# [CV 5/5] END criterion=entropy, max_depth=2, min_samples_leaf=11;, score=0.754 total time=   0.7s
# [CV 1/5] END criterion=entropy, max_depth=10, min_samples_leaf=14;, score=0.754 total time=   0.7s
# [CV 2/5] END criterion=entropy, max_depth=10, min_samples_leaf=14;, score=0.754 total time=   0.7s
# [CV 3/5] END criterion=entropy, max_depth=10, min_samples_leaf=14;, score=0.755 total time=   0.7s
# [CV 4/5] END criterion=entropy, max_depth=10, min_samples_leaf=14;, score=0.754 total time=   0.7s
# [CV 5/5] END criterion=entropy, max_depth=10, min_samples_leaf=14;, score=0.754 total time=   0.7s
# [CV 1/5] END criterion=entropy, max_depth=4, min_samples_leaf=13;, score=0.754 total time=   0.6s
# [CV 2/5] END criterion=entropy, max_depth=4, min_samples_leaf=13;, score=0.754 total time=   0.6s
# [CV 3/5] END criterion=entropy, max_depth=4, min_samples_leaf=13;, score=0.755 total time=   0.7s
# [CV 4/5] END criterion=entropy, max_depth=4, min_samples_leaf=13;, score=0.754 total time=   0.6s
# [CV 5/5] END criterion=entropy, max_depth=4, min_samples_leaf=13;, score=0.754 total time=   0.6s
# [CV 1/5] END criterion=entropy, max_depth=15, min_samples_leaf=5;, score=0.754 total time=   0.7s
# [CV 2/5] END criterion=entropy, max_depth=15, min_samples_leaf=5;, score=0.754 total time=   0.8s
# [CV 3/5] END criterion=entropy, max_depth=15, min_samples_leaf=5;, score=0.755 total time=   0.7s
# [CV 4/5] END criterion=entropy, max_depth=15, min_samples_leaf=5;, score=0.754 total time=   0.8s
# [CV 5/5] END criterion=entropy, max_depth=15, min_samples_leaf=5;, score=0.754 total time=   0.8s
# [CV 1/5] END criterion=log_loss, max_depth=7, min_samples_leaf=15;, score=0.754 total time=   0.7s
# [CV 2/5] END criterion=log_loss, max_depth=7, min_samples_leaf=15;, score=0.754 total time=   0.7s
# [CV 3/5] END criterion=log_loss, max_depth=7, min_samples_leaf=15;, score=0.755 total time=   0.7s
# [CV 4/5] END criterion=log_loss, max_depth=7, min_samples_leaf=15;, score=0.754 total time=   0.7s
# [CV 5/5] END criterion=log_loss, max_depth=7, min_samples_leaf=15;, score=0.754 total time=   0.7s
# [CV 1/5] END criterion=entropy, max_depth=6, min_samples_leaf=7;, score=0.754 total time=   0.7s
# [CV 2/5] END criterion=entropy, max_depth=6, min_samples_leaf=7;, score=0.754 total time=   0.6s
# [CV 3/5] END criterion=entropy, max_depth=6, min_samples_leaf=7;, score=0.755 total time=   0.7s
# [CV 4/5] END criterion=entropy, max_depth=6, min_samples_leaf=7;, score=0.754 total time=   0.7s
# [CV 5/5] END criterion=entropy, max_depth=6, min_samples_leaf=7;, score=0.754 total time=   0.7s
# [CV 1/5] END criterion=gini, max_depth=14, min_samples_leaf=7;, score=0.754 total time=   0.7s
# [CV 2/5] END criterion=gini, max_depth=14, min_samples_leaf=7;, score=0.754 total time=   0.7s
# [CV 3/5] END criterion=gini, max_depth=14, min_samples_leaf=7;, score=0.755 total time=   0.7s
# [CV 4/5] END criterion=gini, max_depth=14, min_samples_leaf=7;, score=0.754 total time=   0.8s
# [CV 5/5] END criterion=gini, max_depth=14, min_samples_leaf=7;, score=0.754 total time=   0.7s
# [CV 1/5] END criterion=gini, max_depth=12, min_samples_leaf=9;, score=0.754 total time=   0.7s
# [CV 2/5] END criterion=gini, max_depth=12, min_samples_leaf=9;, score=0.754 total time=   0.7s
# [CV 3/5] END criterion=gini, max_depth=12, min_samples_leaf=9;, score=0.755 total time=   0.7s
# [CV 4/5] END criterion=gini, max_depth=12, min_samples_leaf=9;, score=0.754 total time=   0.7s
# [CV 5/5] END criterion=gini, max_depth=12, min_samples_leaf=9;, score=0.754 total time=   0.8s
# [CV 1/5] END criterion=gini, max_depth=13, min_samples_leaf=7;, score=0.754 total time=   0.7s
# [CV 2/5] END criterion=gini, max_depth=13, min_samples_leaf=7;, score=0.754 total time=   0.7s
# [CV 3/5] END criterion=gini, max_depth=13, min_samples_leaf=7;, score=0.755 total time=   0.7s
# [CV 4/5] END criterion=gini, max_depth=13, min_samples_leaf=7;, score=0.754 total time=   0.7s
# [CV 5/5] END criterion=gini, max_depth=13, min_samples_leaf=7;, score=0.754 total time=   0.7s
# [CV 1/5] END criterion=log_loss, max_depth=12, min_samples_leaf=14;, score=0.754 total time=   0.5s
# [CV 2/5] END criterion=log_loss, max_depth=12, min_samples_leaf=14;, score=0.754 total time=   0.6s
# [CV 3/5] END criterion=log_loss, max_depth=12, min_samples_leaf=14;, score=0.755 total time=   0.7s
# [CV 4/5] END criterion=log_loss, max_depth=12, min_samples_leaf=14;, score=0.754 total time=   0.7s
# [CV 5/5] END criterion=log_loss, max_depth=12, min_samples_leaf=14;, score=0.754 total time=   0.7s
# [CV 1/5] END criterion=gini, max_depth=10, min_samples_leaf=9;, score=0.754 total time=   0.7s
# [CV 2/5] END criterion=gini, max_depth=10, min_samples_leaf=9;, score=0.754 total time=   0.7s
# [CV 3/5] END criterion=gini, max_depth=10, min_samples_leaf=9;, score=0.755 total time=   0.8s
# [CV 4/5] END criterion=gini, max_depth=10, min_samples_leaf=9;, score=0.754 total time=   1.0s
# [CV 5/5] END criterion=gini, max_depth=10, min_samples_leaf=9;, score=0.754 total time=   1.2s
# [CV 1/5] END criterion=log_loss, max_depth=7, min_samples_leaf=12;, score=0.754 total time=   1.1s
# [CV 2/5] END criterion=log_loss, max_depth=7, min_samples_leaf=12;, score=0.754 total time=   1.1s
# [CV 3/5] END criterion=log_loss, max_depth=7, min_samples_leaf=12;, score=0.755 total time=   1.1s
# [CV 4/5] END criterion=log_loss, max_depth=7, min_samples_leaf=12;, score=0.754 total time=   1.1s
# [CV 5/5] END criterion=log_loss, max_depth=7, min_samples_leaf=12;, score=0.754 total time=   1.1s
# [CV 1/5] END criterion=entropy, max_depth=11, min_samples_leaf=11;, score=0.754 total time=   1.2s
# [CV 2/5] END criterion=entropy, max_depth=11, min_samples_leaf=11;, score=0.754 total time=   1.1s
# [CV 3/5] END criterion=entropy, max_depth=11, min_samples_leaf=11;, score=0.755 total time=   1.1s
# [CV 4/5] END criterion=entropy, max_depth=11, min_samples_leaf=11;, score=0.754 total time=   1.2s
# [CV 5/5] END criterion=entropy, max_depth=11, min_samples_leaf=11;, score=0.754 total time=   1.2s
# [CV 1/5] END criterion=log_loss, max_depth=4, min_samples_leaf=14;, score=0.754 total time=   1.1s
# [CV 2/5] END criterion=log_loss, max_depth=4, min_samples_leaf=14;, score=0.754 total time=   1.4s
# [CV 3/5] END criterion=log_loss, max_depth=4, min_samples_leaf=14;, score=0.755 total time=   1.1s
# [CV 4/5] END criterion=log_loss, max_depth=4, min_samples_leaf=14;, score=0.754 total time=   1.1s
# [CV 5/5] END criterion=log_loss, max_depth=4, min_samples_leaf=14;, score=0.754 total time=   1.1s
# [CV 1/5] END criterion=entropy, max_depth=15, min_samples_leaf=7;, score=0.754 total time=   1.3s
# [CV 2/5] END criterion=entropy, max_depth=15, min_samples_leaf=7;, score=0.754 total time=   1.3s
# [CV 3/5] END criterion=entropy, max_depth=15, min_samples_leaf=7;, score=0.755 total time=   1.3s
# [CV 4/5] END criterion=entropy, max_depth=15, min_samples_leaf=7;, score=0.754 total time=   1.4s
# [CV 5/5] END criterion=entropy, max_depth=15, min_samples_leaf=7;, score=0.754 total time=   1.4s
# [CV 1/5] END criterion=gini, max_depth=3, min_samples_leaf=13;, score=0.754 total time=   1.2s
# [CV 2/5] END criterion=gini, max_depth=3, min_samples_leaf=13;, score=0.754 total time=   1.2s
# [CV 3/5] END criterion=gini, max_depth=3, min_samples_leaf=13;, score=0.755 total time=   1.3s
# [CV 4/5] END criterion=gini, max_depth=3, min_samples_leaf=13;, score=0.754 total time=   1.3s
# [CV 5/5] END criterion=gini, max_depth=3, min_samples_leaf=13;, score=0.754 total time=   1.3s
# [CV 1/5] END criterion=gini, max_depth=13, min_samples_leaf=9;, score=0.754 total time=   1.4s
# [CV 2/5] END criterion=gini, max_depth=13, min_samples_leaf=9;, score=0.754 total time=   1.4s
# [CV 3/5] END criterion=gini, max_depth=13, min_samples_leaf=9;, score=0.755 total time=   1.4s
# [CV 4/5] END criterion=gini, max_depth=13, min_samples_leaf=9;, score=0.754 total time=   1.3s
# [CV 5/5] END criterion=gini, max_depth=13, min_samples_leaf=9;, score=0.754 total time=   1.2s
# [CV 1/5] END criterion=gini, max_depth=4, min_samples_leaf=10;, score=0.754 total time=   1.0s
# [CV 2/5] END criterion=gini, max_depth=4, min_samples_leaf=10;, score=0.754 total time=   0.8s
# [CV 3/5] END criterion=gini, max_depth=4, min_samples_leaf=10;, score=0.755 total time=   0.8s
# [CV 4/5] END criterion=gini, max_depth=4, min_samples_leaf=10;, score=0.754 total time=   0.8s
# [CV 5/5] END criterion=gini, max_depth=4, min_samples_leaf=10;, score=0.754 total time=   0.8s
# [CV 1/5] END criterion=gini, max_depth=6, min_samples_leaf=11;, score=0.754 total time=   0.8s
# [CV 2/5] END criterion=gini, max_depth=6, min_samples_leaf=11;, score=0.754 total time=   0.9s
# [CV 3/5] END criterion=gini, max_depth=6, min_samples_leaf=11;, score=0.755 total time=   0.9s
# [CV 4/5] END criterion=gini, max_depth=6, min_samples_leaf=11;, score=0.754 total time=   0.9s
# [CV 5/5] END criterion=gini, max_depth=6, min_samples_leaf=11;, score=0.754 total time=   1.0s
# [CV 1/5] END criterion=gini, max_depth=8, min_samples_leaf=12;, score=0.754 total time=   0.9s
# [CV 2/5] END criterion=gini, max_depth=8, min_samples_leaf=12;, score=0.754 total time=   0.9s
# [CV 3/5] END criterion=gini, max_depth=8, min_samples_leaf=12;, score=0.755 total time=   0.9s
# [CV 4/5] END criterion=gini, max_depth=8, min_samples_leaf=12;, score=0.754 total time=   0.8s
# [CV 5/5] END criterion=gini, max_depth=8, min_samples_leaf=12;, score=0.754 total time=   0.8s
# [CV 1/5] END criterion=gini, max_depth=12, min_samples_leaf=11;, score=0.754 total time=   0.9s
# [CV 2/5] END criterion=gini, max_depth=12, min_samples_leaf=11;, score=0.754 total time=   0.9s
# [CV 3/5] END criterion=gini, max_depth=12, min_samples_leaf=11;, score=0.755 total time=   0.9s
# [CV 4/5] END criterion=gini, max_depth=12, min_samples_leaf=11;, score=0.754 total time=   1.1s
# [CV 5/5] END criterion=gini, max_depth=12, min_samples_leaf=11;, score=0.754 total time=   1.5s
# [CV 1/5] END criterion=entropy, max_depth=7, min_samples_leaf=10;, score=0.754 total time=   1.3s
# [CV 2/5] END criterion=entropy, max_depth=7, min_samples_leaf=10;, score=0.754 total time=   2.0s
# [CV 3/5] END criterion=entropy, max_depth=7, min_samples_leaf=10;, score=0.755 total time=   2.3s
# [CV 4/5] END criterion=entropy, max_depth=7, min_samples_leaf=10;, score=0.754 total time=   2.1s
# [CV 5/5] END criterion=entropy, max_depth=7, min_samples_leaf=10;, score=0.754 total time=   1.8s
# [CV 1/5] END criterion=entropy, max_depth=8, min_samples_leaf=11;, score=0.754 total time=   1.5s
# [CV 2/5] END criterion=entropy, max_depth=8, min_samples_leaf=11;, score=0.754 total time=   1.5s
# [CV 3/5] END criterion=entropy, max_depth=8, min_samples_leaf=11;, score=0.755 total time=   1.4s
# [CV 4/5] END criterion=entropy, max_depth=8, min_samples_leaf=11;, score=0.754 total time=   1.5s
# [CV 5/5] END criterion=entropy, max_depth=8, min_samples_leaf=11;, score=0.754 total time=   1.3s
# [CV 1/5] END criterion=log_loss, max_depth=8, min_samples_leaf=7;, score=0.754 total time=   1.3s
# [CV 2/5] END criterion=log_loss, max_depth=8, min_samples_leaf=7;, score=0.754 total time=   1.2s
# [CV 3/5] END criterion=log_loss, max_depth=8, min_samples_leaf=7;, score=0.755 total time=   1.2s
# [CV 4/5] END criterion=log_loss, max_depth=8, min_samples_leaf=7;, score=0.754 total time=   1.2s
# [CV 5/5] END criterion=log_loss, max_depth=8, min_samples_leaf=7;, score=0.754 total time=   1.1s
# [CV 1/5] END criterion=log_loss, max_depth=13, min_samples_leaf=15;, score=0.754 total time=   1.1s
# [CV 2/5] END criterion=log_loss, max_depth=13, min_samples_leaf=15;, score=0.754 total time=   1.0s
# [CV 3/5] END criterion=log_loss, max_depth=13, min_samples_leaf=15;, score=0.755 total time=   1.0s
# [CV 4/5] END criterion=log_loss, max_depth=13, min_samples_leaf=15;, score=0.754 total time=   1.0s
# [CV 5/5] END criterion=log_loss, max_depth=13, min_samples_leaf=15;, score=0.754 total time=   1.1s
# [CV 1/5] END criterion=log_loss, max_depth=6, min_samples_leaf=11;, score=0.754 total time=   0.9s
# [CV 2/5] END criterion=log_loss, max_depth=6, min_samples_leaf=11;, score=0.754 total time=   1.0s
# [CV 3/5] END criterion=log_loss, max_depth=6, min_samples_leaf=11;, score=0.755 total time=   0.9s
# [CV 4/5] END criterion=log_loss, max_depth=6, min_samples_leaf=11;, score=0.754 total time=   0.9s
# [CV 5/5] END criterion=log_loss, max_depth=6, min_samples_leaf=11;, score=0.754 total time=   0.9s
# [CV 1/5] END criterion=log_loss, max_depth=14, min_samples_leaf=6;, score=0.754 total time=   1.0s
# [CV 2/5] END criterion=log_loss, max_depth=14, min_samples_leaf=6;, score=0.754 total time=   1.0s
# [CV 3/5] END criterion=log_loss, max_depth=14, min_samples_leaf=6;, score=0.755 total time=   1.0s
# [CV 4/5] END criterion=log_loss, max_depth=14, min_samples_leaf=6;, score=0.754 total time=   0.9s
# [CV 5/5] END criterion=log_loss, max_depth=14, min_samples_leaf=6;, score=0.754 total time=   1.0s
# [CV 1/5] END criterion=gini, max_depth=9, min_samples_leaf=13;, score=0.754 total time=   0.9s
# [CV 2/5] END criterion=gini, max_depth=9, min_samples_leaf=13;, score=0.754 total time=   0.8s
# [CV 3/5] END criterion=gini, max_depth=9, min_samples_leaf=13;, score=0.755 total time=   0.9s
# [CV 4/5] END criterion=gini, max_depth=9, min_samples_leaf=13;, score=0.754 total time=   0.9s
# [CV 5/5] END criterion=gini, max_depth=9, min_samples_leaf=13;, score=0.754 total time=   0.9s
# RandomizedSearchCV(estimator=ExtraTreesClassifier(n_estimators=500,
#                                                   random_state=7),
#                    n_iter=50,
#                    param_distributions={'criterion': ['gini', 'entropy',
#                                                       'log_loss'],
#                                         'max_depth': range(2, 16),
#                                         'min_samples_leaf': range(5, 16)},
#                    verbose=4)

# %%
# 모델 파라미터
print(f'[ searchCV.best_score_ ] {searchCV.best_score_}')
print(f'[ searchCV.best_params_ ] {searchCV.best_params_}')
print(f'[ searchCV.best_estimator_ ] {searchCV.best_estimator_}')

cv_resultDF = pd.DataFrame(searchCV.cv_results_)
cv_resultDF
# Out:
# [ searchCV.best_score_ ] 0.75389649811209
# [ searchCV.best_params_ ] {'min_samples_leaf': 5, 'max_depth': 5, 'criterion': 'gini'}
# [ searchCV.best_estimator_ ] ExtraTreesClassifier(max_depth=5, min_samples_leaf=5, n_estimators=500,
#                      random_state=7)
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.423308      0.013354         0.042420        0.001624
# 1        0.441369      0.010023         0.048161        0.004445
# 2        0.434805      0.053853         0.042975        0.001535
# 3        0.458907      0.012023         0.043112        0.002499
# 4        0.426630      0.006361         0.044299        0.002560
# 5        0.458890      0.018579         0.046797        0.003727
# 6        0.487316      0.025920         0.045971        0.002563
# 7        0.461051      0.020976         0.045789        0.002024
# 8        0.468163      0.013834         0.047612        0.001530
# 9        0.457516      0.019930         0.045062        0.002051
# 10       0.496364      0.015906         0.051801        0.004306
# 11       0.437013      0.010224         0.042163        0.002523
# 12       0.438821      0.012021         0.042377        0.002214
# 13       0.497436      0.027644         0.047902        0.002516
# 14       0.466065      0.015361         0.046143        0.001754
# 15       0.471851      0.016126         0.046694        0.005639
# 16       0.529294      0.046267         0.054022        0.009830
# 17       0.653668      0.048836         0.068664        0.003961
# 18       0.698105      0.024675         0.067990        0.005165
# 19       0.700557      0.023738         0.067514        0.004994
# 20       0.707263      0.025581         0.072297        0.006286
# 21       0.727834      0.025076         0.070626        0.010638
# 22       0.671134      0.014594         0.065216        0.009104
# 23       0.724941      0.022036         0.073673        0.005524
# 24       0.664862      0.020251         0.067603        0.006593
# 25       0.780591      0.021020         0.077584        0.009687
# 26       0.710437      0.012545         0.075964        0.008129
# 27       0.710554      0.033272         0.071597        0.007664
# 28       0.759039      0.020028         0.074838        0.009419
# 29       0.751611      0.032534         0.074063        0.004933
# 30       0.755151      0.013714         0.074911        0.007326
# 31       0.675481      0.075711         0.067818        0.010333
# 32       0.886169      0.156027         0.091636        0.020156
# 33       1.081077      0.012666         0.105497        0.003711
# 34       1.141977      0.029135         0.112305        0.002654
# 35       1.159458      0.091934         0.108323        0.011280
# 36       1.300939      0.056132         0.132742        0.008219
# 37       1.245103      0.027570         0.120795        0.011574
# 38       1.317603      0.083080         0.135959        0.010247
# 39       0.861781      0.047123         0.091822        0.004172
# 40       0.917200      0.076108         0.087558        0.009312
# 41       0.882162      0.021082         0.084246        0.007691
# 42       1.038835      0.213706         0.112053        0.021530
# 43       1.815856      0.309583         0.188012        0.051979
# 44       1.391598      0.063615         0.150421        0.040311
# 45       1.173869      0.041495         0.113831        0.008462
# 46       1.047133      0.019223         0.103847        0.003985
# 47       0.951044      0.006031         0.093640        0.002850
# 48       1.001598      0.040023         0.094477        0.002606
# 49       0.867788      0.011639         0.087500        0.006006
#
#    param_min_samples_leaf param_max_depth param_criterion  \
# 0                       5               5            gini
# 1                       5               9        log_loss
# 2                       7               2         entropy
# 3                      15               4         entropy
# 4                       5               3            gini
# 5                      13              13            gini
# 6                       8               7        log_loss
# 7                       9               9        log_loss
# 8                      12              12            gini
# 9                      15              11         entropy
# 10                      5              12            gini
# 11                      9               2        log_loss
# 12                     10               2            gini
# 13                     10              13            gini
# 14                     12               7         entropy
# 15                      5               4        log_loss
# 16                      9               8            gini
# 17                      9              13         entropy
# 18                     14              15         entropy
# 19                     14              11        log_loss
# 20                     10               9        log_loss
# 21                      5               8            gini
# 22                     11               2         entropy
# 23                     14              10         entropy
# 24                     13               4         entropy
# 25                      5              15         entropy
# 26                     15               7        log_loss
# 27                      7               6         entropy
# 28                      7              14            gini
# 29                      9              12            gini
# 30                      7              13            gini
# 31                     14              12        log_loss
# 32                      9              10            gini
# 33                     12               7        log_loss
# 34                     11              11         entropy
# 35                     14               4        log_loss
# 36                      7              15         entropy
# 37                     13               3            gini
# 38                      9              13            gini
# 39                     10               4            gini
# 40                     11               6            gini
# 41                     12               8            gini
# 42                     11              12            gini
# 43                     10               7         entropy
# 44                     11               8         entropy
# 45                      7               8        log_loss
# 46                     15              13        log_loss
# 47                     11               6        log_loss
# 48                      6              14        log_loss
# 49                     13               9            gini
#
#                                                params  split0_test_score  \
# 0   {'min_samples_leaf': 5, 'max_depth': 5, 'crite...           0.753846
# 1   {'min_samples_leaf': 5, 'max_depth': 9, 'crite...           0.753846
# 2   {'min_samples_leaf': 7, 'max_depth': 2, 'crite...           0.753846
# 3   {'min_samples_leaf': 15, 'max_depth': 4, 'crit...           0.753846
# 4   {'min_samples_leaf': 5, 'max_depth': 3, 'crite...           0.753846
# 5   {'min_samples_leaf': 13, 'max_depth': 13, 'cri...           0.753846
# 6   {'min_samples_leaf': 8, 'max_depth': 7, 'crite...           0.753846
# 7   {'min_samples_leaf': 9, 'max_depth': 9, 'crite...           0.753846
# 8   {'min_samples_leaf': 12, 'max_depth': 12, 'cri...           0.753846
# 9   {'min_samples_leaf': 15, 'max_depth': 11, 'cri...           0.753846
# 10  {'min_samples_leaf': 5, 'max_depth': 12, 'crit...           0.753846
# 11  {'min_samples_leaf': 9, 'max_depth': 2, 'crite...           0.753846
# 12  {'min_samples_leaf': 10, 'max_depth': 2, 'crit...           0.753846
# 13  {'min_samples_leaf': 10, 'max_depth': 13, 'cri...           0.753846
# 14  {'min_samples_leaf': 12, 'max_depth': 7, 'crit...           0.753846
# 15  {'min_samples_leaf': 5, 'max_depth': 4, 'crite...           0.753846
# 16  {'min_samples_leaf': 9, 'max_depth': 8, 'crite...           0.753846
# 17  {'min_samples_leaf': 9, 'max_depth': 13, 'crit...           0.753846
# 18  {'min_samples_leaf': 14, 'max_depth': 15, 'cri...           0.753846
# 19  {'min_samples_leaf': 14, 'max_depth': 11, 'cri...           0.753846
# 20  {'min_samples_leaf': 10, 'max_depth': 9, 'crit...           0.753846
# 21  {'min_samples_leaf': 5, 'max_depth': 8, 'crite...           0.753846
# 22  {'min_samples_leaf': 11, 'max_depth': 2, 'crit...           0.753846
# 23  {'min_samples_leaf': 14, 'max_depth': 10, 'cri...           0.753846
# 24  {'min_samples_leaf': 13, 'max_depth': 4, 'crit...           0.753846
# 25  {'min_samples_leaf': 5, 'max_depth': 15, 'crit...           0.753846
# 26  {'min_samples_leaf': 15, 'max_depth': 7, 'crit...           0.753846
# 27  {'min_samples_leaf': 7, 'max_depth': 6, 'crite...           0.753846
# 28  {'min_samples_leaf': 7, 'max_depth': 14, 'crit...           0.753846
# 29  {'min_samples_leaf': 9, 'max_depth': 12, 'crit...           0.753846
# 30  {'min_samples_leaf': 7, 'max_depth': 13, 'crit...           0.753846
# 31  {'min_samples_leaf': 14, 'max_depth': 12, 'cri...           0.753846
# 32  {'min_samples_leaf': 9, 'max_depth': 10, 'crit...           0.753846
# 33  {'min_samples_leaf': 12, 'max_depth': 7, 'crit...           0.753846
# 34  {'min_samples_leaf': 11, 'max_depth': 11, 'cri...           0.753846
# 35  {'min_samples_leaf': 14, 'max_depth': 4, 'crit...           0.753846
# 36  {'min_samples_leaf': 7, 'max_depth': 15, 'crit...           0.753846
# 37  {'min_samples_leaf': 13, 'max_depth': 3, 'crit...           0.753846
# 38  {'min_samples_leaf': 9, 'max_depth': 13, 'crit...           0.753846
# 39  {'min_samples_leaf': 10, 'max_depth': 4, 'crit...           0.753846
# 40  {'min_samples_leaf': 11, 'max_depth': 6, 'crit...           0.753846
# 41  {'min_samples_leaf': 12, 'max_depth': 8, 'crit...           0.753846
# 42  {'min_samples_leaf': 11, 'max_depth': 12, 'cri...           0.753846
# 43  {'min_samples_leaf': 10, 'max_depth': 7, 'crit...           0.753846
# 44  {'min_samples_leaf': 11, 'max_depth': 8, 'crit...           0.753846
# 45  {'min_samples_leaf': 7, 'max_depth': 8, 'crite...           0.753846
# 46  {'min_samples_leaf': 15, 'max_depth': 13, 'cri...           0.753846
# 47  {'min_samples_leaf': 11, 'max_depth': 6, 'crit...           0.753846
# 48  {'min_samples_leaf': 6, 'max_depth': 14, 'crit...           0.753846
# 49  {'min_samples_leaf': 13, 'max_depth': 9, 'crit...           0.753846
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.753846           0.754572           0.753609
# 1            0.753846           0.754572           0.753609
# 2            0.753846           0.754572           0.753609
# 3            0.753846           0.754572           0.753609
# 4            0.753846           0.754572           0.753609
# 5            0.753846           0.754572           0.753609
# 6            0.753846           0.754572           0.753609
# 7            0.753846           0.754572           0.753609
# 8            0.753846           0.754572           0.753609
# 9            0.753846           0.754572           0.753609
# 10           0.753846           0.754572           0.753609
# 11           0.753846           0.754572           0.753609
# 12           0.753846           0.754572           0.753609
# 13           0.753846           0.754572           0.753609
# 14           0.753846           0.754572           0.753609
# 15           0.753846           0.754572           0.753609
# 16           0.753846           0.754572           0.753609
# 17           0.753846           0.754572           0.753609
# 18           0.753846           0.754572           0.753609
# 19           0.753846           0.754572           0.753609
# 20           0.753846           0.754572           0.753609
# 21           0.753846           0.754572           0.753609
# 22           0.753846           0.754572           0.753609
# 23           0.753846           0.754572           0.753609
# 24           0.753846           0.754572           0.753609
# 25           0.753846           0.754572           0.753609
# 26           0.753846           0.754572           0.753609
# 27           0.753846           0.754572           0.753609
# 28           0.753846           0.754572           0.753609
# 29           0.753846           0.754572           0.753609
# 30           0.753846           0.754572           0.753609
# 31           0.753846           0.754572           0.753609
# 32           0.753846           0.754572           0.753609
# 33           0.753846           0.754572           0.753609
# 34           0.753846           0.754572           0.753609
# 35           0.753846           0.754572           0.753609
# 36           0.753846           0.754572           0.753609
# 37           0.753846           0.754572           0.753609
# 38           0.753846           0.754572           0.753609
# 39           0.753846           0.754572           0.753609
# 40           0.753846           0.754572           0.753609
# 41           0.753846           0.754572           0.753609
# 42           0.753846           0.754572           0.753609
# 43           0.753846           0.754572           0.753609
# 44           0.753846           0.754572           0.753609
# 45           0.753846           0.754572           0.753609
# 46           0.753846           0.754572           0.753609
# 47           0.753846           0.754572           0.753609
# 48           0.753846           0.754572           0.753609
# 49           0.753846           0.754572           0.753609
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.753609         0.753896        0.000354                1
# 1            0.753609         0.753896        0.000354                1
# 2            0.753609         0.753896        0.000354                1
# 3            0.753609         0.753896        0.000354                1
# 4            0.753609         0.753896        0.000354                1
# 5            0.753609         0.753896        0.000354                1
# 6            0.753609         0.753896        0.000354                1
# 7            0.753609         0.753896        0.000354                1
# 8            0.753609         0.753896        0.000354                1
# 9            0.753609         0.753896        0.000354                1
# 10           0.753609         0.753896        0.000354                1
# 11           0.753609         0.753896        0.000354                1
# 12           0.753609         0.753896        0.000354                1
# 13           0.753609         0.753896        0.000354                1
# 14           0.753609         0.753896        0.000354                1
# 15           0.753609         0.753896        0.000354                1
# 16           0.753609         0.753896        0.000354                1
# 17           0.753609         0.753896        0.000354                1
# 18           0.753609         0.753896        0.000354                1
# 19           0.753609         0.753896        0.000354                1
# 20           0.753609         0.753896        0.000354                1
# 21           0.753609         0.753896        0.000354                1
# 22           0.753609         0.753896        0.000354                1
# 23           0.753609         0.753896        0.000354                1
# 24           0.753609         0.753896        0.000354                1
# 25           0.753609         0.753896        0.000354                1
# 26           0.753609         0.753896        0.000354                1
# 27           0.753609         0.753896        0.000354                1
# 28           0.753609         0.753896        0.000354                1
# 29           0.753609         0.753896        0.000354                1
# 30           0.753609         0.753896        0.000354                1
# 31           0.753609         0.753896        0.000354                1
# 32           0.753609         0.753896        0.000354                1
# 33           0.753609         0.753896        0.000354                1
# 34           0.753609         0.753896        0.000354                1
# 35           0.753609         0.753896        0.000354                1
# 36           0.753609         0.753896        0.000354                1
# 37           0.753609         0.753896        0.000354                1
# 38           0.753609         0.753896        0.000354                1
# 39           0.753609         0.753896        0.000354                1
# 40           0.753609         0.753896        0.000354                1
# 41           0.753609         0.753896        0.000354                1
# 42           0.753609         0.753896        0.000354                1
# 43           0.753609         0.753896        0.000354                1
# 44           0.753609         0.753896        0.000354                1
# 45           0.753609         0.753896        0.000354                1
# 46           0.753609         0.753896        0.000354                1
# 47           0.753609         0.753896        0.000354                1
# 48           0.753609         0.753896        0.000354                1
# 49           0.753609         0.753896        0.000354                1
