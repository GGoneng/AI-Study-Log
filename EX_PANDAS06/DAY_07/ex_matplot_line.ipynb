# %% [markdown]
# #### [Matplotlib 활용한 시각화]
# - matplotlib.pyplot 모듈을 사용
# - 다양한 그래프 관련 함수들 & 클래스들 존재

# %%
# [1] 모듈 로딩
# - 패키지명.모듈명
import matplotlib.pyplot as plt

# %%
# [2] 그래프 그리기
plt.plot([1, 2, 3, 4])
plt.xlabel("DATA")
plt.ylabel("RESULT")
plt.show()

# %%
a, b = 10, 20

# %%
a
b
# Out:
# 20
