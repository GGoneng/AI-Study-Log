# %%
import catboost as cb

import optuna

from mordred import Calculator, descriptors

import numpy as np
import pandas as pd

from tqdm import tqdm

from MapLight import *

from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import cross_val_score

# %%
X_TRAIN_PATH = "./combined_features.csv"
TRAIN_PATH = "./data/train.csv"
TEST_PATH = "./data/test.csv"
SUBMISSION_PATH = "./data/sample_submission.csv"

# %%
X_train = pd.read_csv(X_TRAIN_PATH, header = None)
train_df = pd.read_csv(TRAIN_PATH)
test_df = pd.read_csv(TEST_PATH)
submission_df = pd.read_csv(SUBMISSION_PATH)

# %%
RDLogger.DisableLog('rdApp.*')

smiles = test_df["Canonical_Smiles"]

transformer = PretrainedDGLTransformer(kine = "gin_supervised_masking", dtype = float)
mordred_calc = Calculator(descriptors, ignore_3D=True)

mordred_list = []
avalon_list = []
morgan_list = []
# erg_list = []
# rdkit_list = []
gin_list = []

for smile in tqdm(smiles):
    mol = Chem.MolFromSmiles(smile)
    
    avalon_list.append(avalon_fingerprint(mol).ToList())
    morgan_list.append(morgan_fingerprint(mol).ToList())
    # erg_list.append(erg_fingerprint(mol).tolist())
    # rdkit_list.append(rdkit_features(mol))
    gin_list.append(gin_supervised_masking(transformer, mol).tolist())
    mordred_list.append(mordred_calc(mol))

avalon_list = np.array(avalon_list)
morgan_list = np.array(morgan_list)
# erg_list = np.array(erg_list)
# rdkit_list = np.array(rdkit_list)
gin_list = np.squeeze(np.array(gin_list), axis = 1)
mordred_list = np.array(mordred_list)

print(avalon_list.shape, morgan_list.shape, gin_list.shape, mordred_list.shape)

test_combined = pd.DataFrame(np.concatenate((avalon_list, morgan_list, gin_list, mordred_list), axis = 1), index = None)

np.savetxt("test_combined_features.csv", test_combined, delimiter=",")

print(test_combined.shape)
# Out:
# 100%|██████████| 100/100 [00:13<00:00,  7.30it/s]
# (100, 1024) (100, 1024) (100, 300) (100, 1613)
# (100, 3961)

# %%
X_train = pd.read_csv("train_features.csv", header = None)
X_test = pd.read_csv("test_features.csv", header = None)

print(X_train.shape, X_test.shape)

y_scaler = scaler(log = False)
y_scaler.fit(train_df["Inhibition"].values)
train_df["Inhibition"] = y_scaler.transform(train_df["Inhibition"].values)

y_train = train_df["Inhibition"]

def map_objective(trial):
    param = {
        "loss_function": "RMSE",
        "iterations": trial.suggest_int("iterations", 50, 450),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3, log=True),
        "depth": trial.suggest_int("depth", 3, 10),
        "l2_leaf_reg": trial.suggest_float("l2_leaf_reg", 1.0, 10.0),
        "bagging_temperature": trial.suggest_float("bagging_temperature", 0.0, 1.0),
        "random_strength": trial.suggest_float("random_strength", 0.001, 10.0, log=True),
        "border_count": trial.suggest_int("border_count", 32, 64),
        "random_seed": trial.suggest_int("random_seed", 1, 6),
        "task_type": "GPU",  # or "CPU"
        "devices": "0"
    }

    cat_model = cb.CatBoostRegressor(**param, verbose = 0)

    scores = cross_val_score(cat_model, X_train, y_train, cv = 5, scoring = 'neg_mean_absolute_error')
    
    mae = -scores.mean()

    # MAE 평균 값 반환
    return mae
# Out:
# (1681, 6309) (100, 6309)

# %%
# Optuna Log 설정
optuna.logging.set_verbosity(optuna.logging.WARNING)

# Optuna를 통한 학습 시작
study = optuna.create_study(direction = "minimize")
study.optimize(map_objective, n_trials = 500, show_progress_bar = True)

# 최적 하이퍼파라미터 출력
print("Best hyperparameters:", study.best_params)
best_param = study.best_params
# Out:
# Best trial: 476. Best value: 0.720998: 100%|██████████| 500/500 [2:57:13<00:00, 21.27s/it]
# Best hyperparameters: {'iterations': 312, 'learning_rate': 0.0966870841349988, 'depth': 3, 'l2_leaf_reg': 7.441180742851243, 'bagging_temperature': 0.9230579523694196, 'random_strength': 9.955007188400462, 'border_count': 53, 'random_seed': 6}

# %%
final_cat_model = cb.CatBoostRegressor(**best_param)

final_cat_model.fit(X_train, y_train)

y_pred = y_scaler.inverse_transform(final_cat_model.predict(X_train).reshape(-1, 1)).reshape(-1)

y_test_pred = y_scaler.inverse_transform(final_cat_model.predict(X_test).reshape(-1, 1)).reshape(-1)

print(f"MAE Loss : {mean_absolute_error(y_scaler.inverse_transform(np.array(y_train).reshape(-1, 1)), y_pred):.2f}")
# Out:
# 0:	learn: 0.9998686	total: 35.9ms	remaining: 11.2s
# 1:	learn: 0.9931641	total: 70ms	remaining: 10.8s
# 2:	learn: 0.9892954	total: 104ms	remaining: 10.7s
# 3:	learn: 0.9878985	total: 136ms	remaining: 10.5s
# 4:	learn: 0.9866804	total: 172ms	remaining: 10.5s
# 5:	learn: 0.9838764	total: 208ms	remaining: 10.6s
# 6:	learn: 0.9826817	total: 245ms	remaining: 10.7s
# 7:	learn: 0.9799214	total: 291ms	remaining: 11s
# 8:	learn: 0.9771449	total: 327ms	remaining: 11s
# 9:	learn: 0.9734756	total: 360ms	remaining: 10.9s
# 10:	learn: 0.9700214	total: 395ms	remaining: 10.8s
# 11:	learn: 0.9694466	total: 428ms	remaining: 10.7s
# 12:	learn: 0.9653238	total: 462ms	remaining: 10.6s
# 13:	learn: 0.9624768	total: 512ms	remaining: 10.9s
# 14:	learn: 0.9621217	total: 545ms	remaining: 10.8s
# 15:	learn: 0.9597944	total: 582ms	remaining: 10.8s
# 16:	learn: 0.9577895	total: 616ms	remaining: 10.7s
# 17:	learn: 0.9554077	total: 649ms	remaining: 10.6s
# 18:	learn: 0.9538703	total: 683ms	remaining: 10.5s
# 19:	learn: 0.9532113	total: 726ms	remaining: 10.6s
# 20:	learn: 0.9519603	total: 762ms	remaining: 10.6s
# 21:	learn: 0.9506574	total: 794ms	remaining: 10.5s
# 22:	learn: 0.9498334	total: 827ms	remaining: 10.4s
# 23:	learn: 0.9491105	total: 858ms	remaining: 10.3s
# 24:	learn: 0.9456691	total: 890ms	remaining: 10.2s
# 25:	learn: 0.9453941	total: 926ms	remaining: 10.2s
# 26:	learn: 0.9445754	total: 964ms	remaining: 10.2s
# 27:	learn: 0.9434174	total: 1.01s	remaining: 10.2s
# 28:	learn: 0.9402443	total: 1.05s	remaining: 10.3s
# 29:	learn: 0.9392361	total: 1.09s	remaining: 10.3s
# 30:	learn: 0.9381753	total: 1.14s	remaining: 10.3s
# 31:	learn: 0.9370296	total: 1.18s	remaining: 10.3s
# 32:	learn: 0.9363922	total: 1.21s	remaining: 10.3s
# 33:	learn: 0.9330970	total: 1.25s	remaining: 10.2s
# 34:	learn: 0.9323237	total: 1.29s	remaining: 10.2s
# 35:	learn: 0.9321695	total: 1.32s	remaining: 10.1s
# 36:	learn: 0.9302049	total: 1.35s	remaining: 10.1s
# 37:	learn: 0.9297185	total: 1.39s	remaining: 10s
# 38:	learn: 0.9290379	total: 1.43s	remaining: 9.98s
# 39:	learn: 0.9287461	total: 1.46s	remaining: 9.94s
# 40:	learn: 0.9278759	total: 1.5s	remaining: 9.88s
# 41:	learn: 0.9272719	total: 1.53s	remaining: 9.83s
# 42:	learn: 0.9266069	total: 1.56s	remaining: 9.77s
# 43:	learn: 0.9263343	total: 1.6s	remaining: 9.74s
# 44:	learn: 0.9260842	total: 1.63s	remaining: 9.68s
# 45:	learn: 0.9260299	total: 1.67s	remaining: 9.65s
# 46:	learn: 0.9245692	total: 1.7s	remaining: 9.6s
# 47:	learn: 0.9243838	total: 1.74s	remaining: 9.54s
# 48:	learn: 0.9241628	total: 1.77s	remaining: 9.5s
# 49:	learn: 0.9237798	total: 1.81s	remaining: 9.46s
# 50:	learn: 0.9208487	total: 1.84s	remaining: 9.42s
# 51:	learn: 0.9199713	total: 1.87s	remaining: 9.37s
# 52:	learn: 0.9195649	total: 1.91s	remaining: 9.34s
# 53:	learn: 0.9195015	total: 1.94s	remaining: 9.28s
# 54:	learn: 0.9181249	total: 1.98s	remaining: 9.23s
# 55:	learn: 0.9171409	total: 2.01s	remaining: 9.21s
# 56:	learn: 0.9157763	total: 2.05s	remaining: 9.16s
# 57:	learn: 0.9147538	total: 2.08s	remaining: 9.12s
# 58:	learn: 0.9132762	total: 2.12s	remaining: 9.09s
# 59:	learn: 0.9128694	total: 2.15s	remaining: 9.03s
# 60:	learn: 0.9122894	total: 2.18s	remaining: 8.99s
# 61:	learn: 0.9118949	total: 2.22s	remaining: 8.95s
# 62:	learn: 0.9115915	total: 2.25s	remaining: 8.91s
# 63:	learn: 0.9112606	total: 2.29s	remaining: 8.87s
# 64:	learn: 0.9108101	total: 2.32s	remaining: 8.83s
# 65:	learn: 0.9095874	total: 2.36s	remaining: 8.79s
# 66:	learn: 0.9093170	total: 2.39s	remaining: 8.75s
# 67:	learn: 0.9085040	total: 2.43s	remaining: 8.71s
# 68:	learn: 0.9070945	total: 2.46s	remaining: 8.67s
# 69:	learn: 0.9066851	total: 2.5s	remaining: 8.65s
# 70:	learn: 0.9059543	total: 2.54s	remaining: 8.61s
# 71:	learn: 0.9055511	total: 2.57s	remaining: 8.57s
# 72:	learn: 0.9048336	total: 2.61s	remaining: 8.54s
# 73:	learn: 0.9029750	total: 2.64s	remaining: 8.5s
# 74:	learn: 0.9024198	total: 2.67s	remaining: 8.45s
# 75:	learn: 0.9013912	total: 2.72s	remaining: 8.44s
# 76:	learn: 0.8992648	total: 2.75s	remaining: 8.4s
# 77:	learn: 0.8983698	total: 2.79s	remaining: 8.37s
# 78:	learn: 0.8976048	total: 2.83s	remaining: 8.36s
# 79:	learn: 0.8970054	total: 2.86s	remaining: 8.31s
# 80:	learn: 0.8963297	total: 2.9s	remaining: 8.27s
# 81:	learn: 0.8954764	total: 2.93s	remaining: 8.22s
# 82:	learn: 0.8952204	total: 2.97s	remaining: 8.19s
# 83:	learn: 0.8937247	total: 3.01s	remaining: 8.16s
# 228:	learn: 0.6486412	total: 8.11s	remaining: 2.94s
# 229:	learn: 0.6475610	total: 8.14s	remaining: 2.9s
# 230:	learn: 0.6464455	total: 8.18s	remaining: 2.87s
# 231:	learn: 0.6452626	total: 8.21s	remaining: 2.83s
# 232:	learn: 0.6442342	total: 8.24s	remaining: 2.79s
# 233:	learn: 0.6430282	total: 8.28s	remaining: 2.76s
# 234:	learn: 0.6419014	total: 8.31s	remaining: 2.72s
# 235:	learn: 0.6405374	total: 8.35s	remaining: 2.69s
# 236:	learn: 0.6396386	total: 8.38s	remaining: 2.65s
# 237:	learn: 0.6387710	total: 8.42s	remaining: 2.62s
# 238:	learn: 0.6377611	total: 8.45s	remaining: 2.58s
# 239:	learn: 0.6366390	total: 8.49s	remaining: 2.55s
# 240:	learn: 0.6353290	total: 8.52s	remaining: 2.51s
# 241:	learn: 0.6342821	total: 8.56s	remaining: 2.48s
# 242:	learn: 0.6333023	total: 8.59s	remaining: 2.44s
# 243:	learn: 0.6326335	total: 8.62s	remaining: 2.4s
# 244:	learn: 0.6315959	total: 8.66s	remaining: 2.37s
# 245:	learn: 0.6312060	total: 8.7s	remaining: 2.33s
# 246:	learn: 0.6306136	total: 8.73s	remaining: 2.3s
# 247:	learn: 0.6292086	total: 8.77s	remaining: 2.26s
# 248:	learn: 0.6280769	total: 8.8s	remaining: 2.23s
# 249:	learn: 0.6274648	total: 8.83s	remaining: 2.19s
# 250:	learn: 0.6261978	total: 8.87s	remaining: 2.16s
# 251:	learn: 0.6248267	total: 8.91s	remaining: 2.12s
# 252:	learn: 0.6241078	total: 8.96s	remaining: 2.09s
# 253:	learn: 0.6231184	total: 9.02s	remaining: 2.06s
# 254:	learn: 0.6216859	total: 9.06s	remaining: 2.03s
# 255:	learn: 0.6205105	total: 9.11s	remaining: 1.99s
# 256:	learn: 0.6196977	total: 9.15s	remaining: 1.96s
# 257:	learn: 0.6183647	total: 9.18s	remaining: 1.92s
# 258:	learn: 0.6171098	total: 9.21s	remaining: 1.89s
# 259:	learn: 0.6161007	total: 9.25s	remaining: 1.85s
# 260:	learn: 0.6150755	total: 9.28s	remaining: 1.81s
# 261:	learn: 0.6136451	total: 9.32s	remaining: 1.78s
# 262:	learn: 0.6124040	total: 9.35s	remaining: 1.74s
# 263:	learn: 0.6116941	total: 9.39s	remaining: 1.71s
# 264:	learn: 0.6103114	total: 9.42s	remaining: 1.67s
# 265:	learn: 0.6092936	total: 9.46s	remaining: 1.64s
# 266:	learn: 0.6078713	total: 9.49s	remaining: 1.6s
# 267:	learn: 0.6068266	total: 9.52s	remaining: 1.56s
# 268:	learn: 0.6057879	total: 9.55s	remaining: 1.53s
# 269:	learn: 0.6056102	total: 9.59s	remaining: 1.49s
# 270:	learn: 0.6043236	total: 9.63s	remaining: 1.46s
# 271:	learn: 0.6032705	total: 9.66s	remaining: 1.42s
# 272:	learn: 0.6021724	total: 9.69s	remaining: 1.38s
# 273:	learn: 0.6010291	total: 9.73s	remaining: 1.35s
# 274:	learn: 0.5999617	total: 9.76s	remaining: 1.31s
# 275:	learn: 0.5994370	total: 9.79s	remaining: 1.28s
# 276:	learn: 0.5985811	total: 9.83s	remaining: 1.24s
# 277:	learn: 0.5973198	total: 9.87s	remaining: 1.21s
# 278:	learn: 0.5969937	total: 9.9s	remaining: 1.17s
# 279:	learn: 0.5956853	total: 9.94s	remaining: 1.14s
# 280:	learn: 0.5946069	total: 9.97s	remaining: 1.1s
# 281:	learn: 0.5932618	total: 10s	remaining: 1.06s
# 282:	learn: 0.5918704	total: 10s	remaining: 1.03s
# 283:	learn: 0.5910125	total: 10.1s	remaining: 993ms
# 284:	learn: 0.5900897	total: 10.1s	remaining: 958ms
# 285:	learn: 0.5895716	total: 10.1s	remaining: 922ms
# 286:	learn: 0.5888331	total: 10.2s	remaining: 886ms
# 287:	learn: 0.5886845	total: 10.2s	remaining: 850ms
# 288:	learn: 0.5876672	total: 10.2s	remaining: 815ms
# 289:	learn: 0.5867171	total: 10.3s	remaining: 779ms
# 290:	learn: 0.5865613	total: 10.3s	remaining: 744ms
# 291:	learn: 0.5856145	total: 10.3s	remaining: 709ms
# 292:	learn: 0.5846340	total: 10.4s	remaining: 673ms
# 293:	learn: 0.5841507	total: 10.4s	remaining: 637ms
# 294:	learn: 0.5839958	total: 10.4s	remaining: 602ms
# 295:	learn: 0.5836797	total: 10.5s	remaining: 566ms
# 296:	learn: 0.5823696	total: 10.5s	remaining: 531ms
# 297:	learn: 0.5822317	total: 10.5s	remaining: 495ms
# 298:	learn: 0.5813492	total: 10.6s	remaining: 460ms
# 299:	learn: 0.5810157	total: 10.6s	remaining: 424ms
# 300:	learn: 0.5797622	total: 10.6s	remaining: 389ms
# 301:	learn: 0.5783484	total: 10.7s	remaining: 354ms
# 302:	learn: 0.5772489	total: 10.7s	remaining: 318ms
# 303:	learn: 0.5767107	total: 10.7s	remaining: 283ms
# 304:	learn: 0.5756436	total: 10.8s	remaining: 248ms
# 305:	learn: 0.5745847	total: 10.8s	remaining: 212ms
# 306:	learn: 0.5733215	total: 10.9s	remaining: 177ms
# 307:	learn: 0.5725907	total: 10.9s	remaining: 142ms
# 308:	learn: 0.5719863	total: 10.9s	remaining: 106ms
# 309:	learn: 0.5706336	total: 11s	remaining: 70.8ms
# 310:	learn: 0.5699958	total: 11s	remaining: 35.4ms
# 311:	learn: 0.5690613	total: 11s	remaining: 0us
# MAE Loss : 0.47

# %%
submission_df["Inhibition"] = y_test_pred

submission_df.to_csv('maplight_submission.csv', index = False)

# %%
importances = final_cat_model.get_feature_importance(type='PredictionValuesChange')

feature_sizes = [1024, 300, 1613, 300, 2048]
block_names = ['Avalon', 'Gin', 'Mordred', 'Mol2Vec', 'Circular']

start = 0
block_importances = []

for size in feature_sizes:
    block_imp = np.sum(importances[start:start + size])
    block_importances.append(block_imp)
    start += size

# 정규화 (전체 비중으로 보기 위해 %로 변환)
block_importances = np.array(block_importances)
block_importances_percent = block_importances / block_importances.sum() * 100

for name, imp in zip(block_names, block_importances_percent):
    print(f"{name}: {imp:.2f}%")
# Out:
# Avalon: 11.43%
# Gin: 0.34%
# Mordred: 50.42%
# Mol2Vec: 7.31%
# Circular: 30.50%

# %%
# Standard Scaler - 6.83
# Not Standard Scaler = 6.83

# HyperParameter Tuning -
