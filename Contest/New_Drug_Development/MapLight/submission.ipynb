# %%
import catboost as cb

import optuna

from mordred import Calculator, descriptors

import numpy as np
import pandas as pd

from tqdm import tqdm

from MapLight import *

from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import cross_val_score

# %%
X_TRAIN_PATH = "./combined_features.csv"
TRAIN_PATH = "./data/train.csv"
TEST_PATH = "./data/test.csv"
SUBMISSION_PATH = "./data/sample_submission.csv"

# %%
X_train = pd.read_csv(X_TRAIN_PATH, header = None)
train_df = pd.read_csv(TRAIN_PATH)
test_df = pd.read_csv(TEST_PATH)
submission_df = pd.read_csv(SUBMISSION_PATH)

# %%
RDLogger.DisableLog('rdApp.*')

smiles = test_df["Canonical_Smiles"]

transformer = PretrainedDGLTransformer(kine = "gin_supervised_masking", dtype = float)
mordred_calc = Calculator(descriptors, ignore_3D=True)

mordred_list = []
avalon_list = []
morgan_list = []
# erg_list = []
rdkit_list = []
gin_list = []

for smile in tqdm(smiles):
    mol = Chem.MolFromSmiles(smile)
    
    avalon_list.append(avalon_fingerprint(mol).ToList())
    morgan_list.append(morgan_fingerprint(mol).ToList())
    # erg_list.append(erg_fingerprint(mol).tolist())
    rdkit_list.append(rdkit_features(mol))
    gin_list.append(gin_supervised_masking(transformer, mol).tolist())
    mordred_list.append(mordred_calc(mol))

avalon_list = np.array(avalon_list)
morgan_list = np.array(morgan_list)
# erg_list = np.array(erg_list)
rdkit_list = np.array(rdkit_list)
gin_list = np.squeeze(np.array(gin_list), axis = 1)
mordred_list = np.array(mordred_list)

print(avalon_list.shape, morgan_list.shape, rdkit_list.shape, gin_list.shape, mordred_list.shape)

test_combined = pd.DataFrame(np.concatenate((avalon_list, morgan_list, rdkit_list, gin_list, mordred_list), axis = 1), index = None)

print(test_combined.shape)
# Out:
# 100%|██████████| 100/100 [00:13<00:00,  7.28it/s]
# (100, 1024) (100, 1024) (100, 200) (100, 300) (100, 1613)
# (100, 4161)

# %%
X_test = test_combined

y_scaler = scaler(log = False)
y_scaler.fit(train_df["Inhibition"].values)
train_df["Inhibition"] = y_scaler.transform(train_df["Inhibition"].values)

y_train = train_df["Inhibition"]

def map_objective(trial):
    param = {
        "loss_function": "RMSE",
        "iterations": trial.suggest_int("iterations", 50, 700),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3, log=True),
        "depth": trial.suggest_int("depth", 3, 10),
        "l2_leaf_reg": trial.suggest_float("l2_leaf_reg", 1.0, 10.0),
        "bagging_temperature": trial.suggest_float("bagging_temperature", 0.0, 1.0),
        "random_strength": trial.suggest_float("random_strength", 0.001, 10.0, log=True),
        "border_count": trial.suggest_int("border_count", 32, 64),
        "random_seed": trial.suggest_int("random_seed", 1, 6),
        "task_type": "GPU",  # or "CPU"
        "devices": "0"
    }

    cat_model = cb.CatBoostRegressor(**param, verbose = 0)

    scores = cross_val_score(cat_model, X_train, y_train, cv = 5, scoring = 'neg_mean_absolute_error')
    
    mae = -scores.mean()

    # MAE 평균 값 반환
    return mae

# %%
# Optuna Log 설정
optuna.logging.set_verbosity(optuna.logging.WARNING)

# Optuna를 통한 학습 시작
study = optuna.create_study(direction = "minimize")
study.optimize(map_objective, n_trials = 300, show_progress_bar = True)

# 최적 하이퍼파라미터 출력
print("Best hyperparameters:", study.best_params)
best_param = study.best_params
# Out:
# Best trial: 8. Best value: 0.728209:  10%|▉         | 29/300 [44:44<3:13:37, 42.87s/it]

# %%
final_cat_model = cb.CatBoostRegressor(**best_param)

final_cat_model.fit(X_train, y_train)

y_pred = y_scaler.inverse_transform(final_cat_model.predict(X_train).reshape(-1, 1)).reshape(-1)

y_test_pred = y_scaler.inverse_transform(final_cat_model.predict(X_test).reshape(-1, 1)).reshape(-1)

print(f"MAE Loss : {mean_absolute_error(y_scaler.inverse_transform(np.array(y_train).reshape(-1, 1)), y_pred):.2f}")
# Out:
# 0:	learn: 0.9791990	total: 30.1ms	remaining: 8.1s
# 1:	learn: 0.9627693	total: 40.6ms	remaining: 5.43s
# 2:	learn: 0.9484678	total: 49.8ms	remaining: 4.43s
# 3:	learn: 0.9354621	total: 60.6ms	remaining: 4.03s
# 4:	learn: 0.9256396	total: 71ms	remaining: 3.77s
# 5:	learn: 0.9160786	total: 80.8ms	remaining: 3.56s
# 6:	learn: 0.9074439	total: 103ms	remaining: 3.87s
# 7:	learn: 0.9000996	total: 113ms	remaining: 3.69s
# 8:	learn: 0.8920691	total: 123ms	remaining: 3.58s
# 9:	learn: 0.8856254	total: 134ms	remaining: 3.47s
# 10:	learn: 0.8796539	total: 148ms	remaining: 3.48s
# 11:	learn: 0.8736952	total: 161ms	remaining: 3.46s
# 12:	learn: 0.8680036	total: 173ms	remaining: 3.42s
# 13:	learn: 0.8623263	total: 183ms	remaining: 3.35s
# 14:	learn: 0.8583116	total: 194ms	remaining: 3.29s
# 15:	learn: 0.8524638	total: 204ms	remaining: 3.25s
# 16:	learn: 0.8471981	total: 214ms	remaining: 3.19s
# 17:	learn: 0.8429170	total: 224ms	remaining: 3.14s
# 18:	learn: 0.8395072	total: 234ms	remaining: 3.08s
# 19:	learn: 0.8353034	total: 244ms	remaining: 3.05s
# 20:	learn: 0.8313666	total: 254ms	remaining: 3.01s
# 21:	learn: 0.8271372	total: 265ms	remaining: 2.99s
# 22:	learn: 0.8232071	total: 276ms	remaining: 2.97s
# 23:	learn: 0.8198626	total: 286ms	remaining: 2.93s
# 24:	learn: 0.8160038	total: 296ms	remaining: 2.9s
# 25:	learn: 0.8116999	total: 306ms	remaining: 2.88s
# 26:	learn: 0.8092804	total: 316ms	remaining: 2.84s
# 27:	learn: 0.8063788	total: 327ms	remaining: 2.82s
# 28:	learn: 0.8038218	total: 336ms	remaining: 2.8s
# 29:	learn: 0.8001117	total: 347ms	remaining: 2.78s
# 30:	learn: 0.7967625	total: 357ms	remaining: 2.75s
# 31:	learn: 0.7935129	total: 366ms	remaining: 2.72s
# 32:	learn: 0.7900513	total: 377ms	remaining: 2.7s
# 33:	learn: 0.7863981	total: 386ms	remaining: 2.68s
# 34:	learn: 0.7836316	total: 398ms	remaining: 2.67s
# 35:	learn: 0.7807842	total: 411ms	remaining: 2.67s
# 36:	learn: 0.7775148	total: 422ms	remaining: 2.66s
# 37:	learn: 0.7739038	total: 434ms	remaining: 2.65s
# 38:	learn: 0.7715244	total: 445ms	remaining: 2.63s
# 39:	learn: 0.7697261	total: 455ms	remaining: 2.61s
# 40:	learn: 0.7665500	total: 465ms	remaining: 2.6s
# 41:	learn: 0.7628451	total: 477ms	remaining: 2.59s
# 90:	learn: 0.6577779	total: 1.03s	remaining: 2.03s
# 91:	learn: 0.6559109	total: 1.04s	remaining: 2.01s
# 92:	learn: 0.6539204	total: 1.05s	remaining: 2s
# 93:	learn: 0.6522133	total: 1.07s	remaining: 2s
# 94:	learn: 0.6501070	total: 1.08s	remaining: 1.98s
# 95:	learn: 0.6480707	total: 1.09s	remaining: 1.97s
# 96:	learn: 0.6456421	total: 1.1s	remaining: 1.96s
# 97:	learn: 0.6435534	total: 1.11s	remaining: 1.95s
# 98:	learn: 0.6422196	total: 1.12s	remaining: 1.94s
# 99:	learn: 0.6405158	total: 1.13s	remaining: 1.93s
# 100:	learn: 0.6398742	total: 1.14s	remaining: 1.91s
# 101:	learn: 0.6379144	total: 1.15s	remaining: 1.9s
# 102:	learn: 0.6359990	total: 1.16s	remaining: 1.89s
# 103:	learn: 0.6347187	total: 1.17s	remaining: 1.87s
# 104:	learn: 0.6324724	total: 1.19s	remaining: 1.86s
# 105:	learn: 0.6308300	total: 1.21s	remaining: 1.87s
# 106:	learn: 0.6293628	total: 1.22s	remaining: 1.86s
# 107:	learn: 0.6278083	total: 1.23s	remaining: 1.85s
# 108:	learn: 0.6268045	total: 1.24s	remaining: 1.83s
# 109:	learn: 0.6247268	total: 1.25s	remaining: 1.82s
# 110:	learn: 0.6234924	total: 1.26s	remaining: 1.81s
# 111:	learn: 0.6212920	total: 1.27s	remaining: 1.79s
# 112:	learn: 0.6195869	total: 1.28s	remaining: 1.78s
# 113:	learn: 0.6177650	total: 1.29s	remaining: 1.77s
# 114:	learn: 0.6154374	total: 1.3s	remaining: 1.75s
# 115:	learn: 0.6140916	total: 1.31s	remaining: 1.74s
# 116:	learn: 0.6129376	total: 1.32s	remaining: 1.73s
# 117:	learn: 0.6121015	total: 1.33s	remaining: 1.72s
# 118:	learn: 0.6106193	total: 1.34s	remaining: 1.7s
# 119:	learn: 0.6095668	total: 1.35s	remaining: 1.69s
# 120:	learn: 0.6086641	total: 1.36s	remaining: 1.68s
# 121:	learn: 0.6063692	total: 1.37s	remaining: 1.66s
# 122:	learn: 0.6050978	total: 1.38s	remaining: 1.65s
# 123:	learn: 0.6033661	total: 1.39s	remaining: 1.64s
# 124:	learn: 0.6015170	total: 1.4s	remaining: 1.63s
# 125:	learn: 0.6003806	total: 1.41s	remaining: 1.61s
# 126:	learn: 0.5985312	total: 1.42s	remaining: 1.6s
# 127:	learn: 0.5972809	total: 1.43s	remaining: 1.59s
# 128:	learn: 0.5962007	total: 1.44s	remaining: 1.58s
# 129:	learn: 0.5956862	total: 1.46s	remaining: 1.57s
# 130:	learn: 0.5949727	total: 1.47s	remaining: 1.56s
# 131:	learn: 0.5937343	total: 1.48s	remaining: 1.55s
# 132:	learn: 0.5921260	total: 1.5s	remaining: 1.55s
# 133:	learn: 0.5905532	total: 1.52s	remaining: 1.54s
# 134:	learn: 0.5891182	total: 1.53s	remaining: 1.53s
# 135:	learn: 0.5876719	total: 1.54s	remaining: 1.52s
# 136:	learn: 0.5857096	total: 1.55s	remaining: 1.5s
# 137:	learn: 0.5840200	total: 1.56s	remaining: 1.49s
# 138:	learn: 0.5823523	total: 1.57s	remaining: 1.48s
# 139:	learn: 0.5803136	total: 1.58s	remaining: 1.47s
# 140:	learn: 0.5789936	total: 1.59s	remaining: 1.46s
# 141:	learn: 0.5784757	total: 1.6s	remaining: 1.45s
# 142:	learn: 0.5771458	total: 1.62s	remaining: 1.44s
# 143:	learn: 0.5756207	total: 1.63s	remaining: 1.42s
# 144:	learn: 0.5736737	total: 1.64s	remaining: 1.41s
# 145:	learn: 0.5720739	total: 1.65s	remaining: 1.4s
# 146:	learn: 0.5718106	total: 1.66s	remaining: 1.39s
# 147:	learn: 0.5702354	total: 1.67s	remaining: 1.38s
# 148:	learn: 0.5695314	total: 1.68s	remaining: 1.36s
# 149:	learn: 0.5678758	total: 1.69s	remaining: 1.35s
# 150:	learn: 0.5655936	total: 1.7s	remaining: 1.34s
# 151:	learn: 0.5651078	total: 1.71s	remaining: 1.33s
# 152:	learn: 0.5630441	total: 1.72s	remaining: 1.32s
# 153:	learn: 0.5616965	total: 1.73s	remaining: 1.3s
# 154:	learn: 0.5608876	total: 1.74s	remaining: 1.29s
# 155:	learn: 0.5592090	total: 1.75s	remaining: 1.28s
# 156:	learn: 0.5588419	total: 1.76s	remaining: 1.27s
# 157:	learn: 0.5575885	total: 1.77s	remaining: 1.26s
# 158:	learn: 0.5566370	total: 1.78s	remaining: 1.25s
# 159:	learn: 0.5547938	total: 1.8s	remaining: 1.24s
# 160:	learn: 0.5531546	total: 1.81s	remaining: 1.22s
# 161:	learn: 0.5514820	total: 1.82s	remaining: 1.21s
# 162:	learn: 0.5500245	total: 1.83s	remaining: 1.2s
# 163:	learn: 0.5498611	total: 1.84s	remaining: 1.19s
# 164:	learn: 0.5484078	total: 1.85s	remaining: 1.18s
# 165:	learn: 0.5479913	total: 1.86s	remaining: 1.16s
# 166:	learn: 0.5465406	total: 1.87s	remaining: 1.15s
# 167:	learn: 0.5452457	total: 1.88s	remaining: 1.14s
# 168:	learn: 0.5450203	total: 1.89s	remaining: 1.13s
# 169:	learn: 0.5433154	total: 1.9s	remaining: 1.12s
# 170:	learn: 0.5417558	total: 1.91s	remaining: 1.11s
# 171:	learn: 0.5404872	total: 1.92s	remaining: 1.09s
# 172:	learn: 0.5399574	total: 1.93s	remaining: 1.08s
# 173:	learn: 0.5393723	total: 1.94s	remaining: 1.07s
# 174:	learn: 0.5378905	total: 1.95s	remaining: 1.06s
# 175:	learn: 0.5370989	total: 1.96s	remaining: 1.05s
# 176:	learn: 0.5363613	total: 1.97s	remaining: 1.04s
# 177:	learn: 0.5348458	total: 1.99s	remaining: 1.03s
# 178:	learn: 0.5341121	total: 2s	remaining: 1.01s
# 179:	learn: 0.5328257	total: 2.01s	remaining: 1s
# 180:	learn: 0.5308695	total: 2.02s	remaining: 992ms
# 181:	learn: 0.5295130	total: 2.03s	remaining: 982ms
# 182:	learn: 0.5278655	total: 2.04s	remaining: 970ms
# 183:	learn: 0.5265775	total: 2.05s	remaining: 959ms
# 184:	learn: 0.5249807	total: 2.06s	remaining: 947ms
# 185:	learn: 0.5247507	total: 2.07s	remaining: 935ms
# 235:	learn: 0.4744689	total: 2.63s	remaining: 378ms
# 236:	learn: 0.4734201	total: 2.64s	remaining: 367ms
# 237:	learn: 0.4724193	total: 2.65s	remaining: 356ms
# 238:	learn: 0.4708354	total: 2.66s	remaining: 345ms
# 239:	learn: 0.4697367	total: 2.67s	remaining: 334ms
# 240:	learn: 0.4691979	total: 2.69s	remaining: 323ms
# 241:	learn: 0.4680097	total: 2.7s	remaining: 312ms
# 242:	learn: 0.4664841	total: 2.71s	remaining: 301ms
# 243:	learn: 0.4654401	total: 2.72s	remaining: 290ms
# 244:	learn: 0.4643869	total: 2.73s	remaining: 279ms
# 245:	learn: 0.4633800	total: 2.74s	remaining: 268ms
# 246:	learn: 0.4625650	total: 2.76s	remaining: 257ms
# 247:	learn: 0.4613234	total: 2.77s	remaining: 246ms
# 248:	learn: 0.4609774	total: 2.78s	remaining: 235ms
# 249:	learn: 0.4601963	total: 2.79s	remaining: 223ms
# 250:	learn: 0.4598229	total: 2.8s	remaining: 212ms
# 251:	learn: 0.4592339	total: 2.81s	remaining: 201ms
# 252:	learn: 0.4589923	total: 2.82s	remaining: 190ms
# 253:	learn: 0.4579708	total: 2.83s	remaining: 179ms
# 254:	learn: 0.4564863	total: 2.85s	remaining: 167ms
# 255:	learn: 0.4552251	total: 2.86s	remaining: 156ms
# 256:	learn: 0.4540619	total: 2.87s	remaining: 145ms
# 257:	learn: 0.4533726	total: 2.88s	remaining: 134ms
# 258:	learn: 0.4531710	total: 2.89s	remaining: 123ms
# 259:	learn: 0.4522099	total: 2.9s	remaining: 112ms
# 260:	learn: 0.4507342	total: 2.91s	remaining: 100ms
# 261:	learn: 0.4497490	total: 2.92s	remaining: 89.2ms
# 262:	learn: 0.4480633	total: 2.93s	remaining: 78ms
# 263:	learn: 0.4468112	total: 2.94s	remaining: 66.8ms
# 264:	learn: 0.4452978	total: 2.95s	remaining: 55.7ms
# 265:	learn: 0.4438335	total: 2.96s	remaining: 44.5ms
# 266:	learn: 0.4427086	total: 2.97s	remaining: 33.4ms
# 267:	learn: 0.4416599	total: 2.98s	remaining: 22.3ms
# 268:	learn: 0.4412449	total: 2.99s	remaining: 11.1ms
# 269:	learn: 0.4400593	total: 3s	remaining: 0us
# MAE Loss : 9.61

# %%
submission_df["Inhibition"] = y_test_pred

submission_df.to_csv('maplight_submission.csv', index = False)

# %%
importances = final_cat_model.get_feature_importance(type='PredictionValuesChange')

feature_sizes = [1024, 1024, 200, 300, 1613]
block_names = ['block1', 'block2', 'block3', 'block4', 'block5']

start = 0
block_importances = []

for size in feature_sizes:
    block_imp = np.sum(importances[start:start + size])
    block_importances.append(block_imp)
    start += size

# 정규화 (전체 비중으로 보기 위해 %로 변환)
block_importances = np.array(block_importances)
block_importances_percent = block_importances / block_importances.sum() * 100

for name, imp in zip(block_names, block_importances_percent):
    print(f"{name}: {imp:.2f}%")
# Out:
# block1: 9.73%
# block2: 6.04%
# block3: 2.61%
# block4: 8.52%
# block5: 34.02%

# %%
# Standard Scaler - 6.83
# Not Standard Scaler = 6.83

# HyperParameter Tuning -
