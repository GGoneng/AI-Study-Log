# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
import os
import numpy as np

import torch
import torch.nn as nn
import torch.optim as optim
from torch_optimizer import Lookahead
import torch.nn.functional as F
import torch.optim.lr_scheduler as lr_scheduler
from torch.utils.data import Dataset, DataLoader
from torchmetrics.classification import BinaryF1Score

from sklearn.model_selection import train_test_split
from gensim.models import Word2Vec

# %%
DATA_PATH = './Data/'

train_df = pd.read_csv(DATA_PATH + 'train.csv')
test_df = pd.read_csv(DATA_PATH + 'test.csv')
submission_df = pd.read_csv(DATA_PATH + 'sample_submission.csv')

# %%
train_df.head(30)
# Out:
#                ID                                                URL  label
# 0   TRAIN_0000000                           poznan[.]wuoz[.]gov[.]pl      0
# 1   TRAIN_0000001                          vill[.]okawa[.]kochi[.]jp      0
# 2   TRAIN_0000002                          nationalfinance[.]co[.]om      0
# 3   TRAIN_0000003                       town[.]ozora[.]hokkaido[.]jp      0
# 4   TRAIN_0000004              open24[.]ie-news[.]irish/online/Login      1
# 5   TRAIN_0000005                             93fm[.]radio[.]br/file      1
# 6   TRAIN_0000006  ps[.]com[.]vu/wp-config/wp-incluides/soft/ursn...      1
# 7   TRAIN_0000007                                       rih[.]p[.]se      0
# 8   TRAIN_0000008                                   microsoft[.]ltda      0
# 9   TRAIN_0000009                165[.]232[.]173[.]145/mobile[.]html      1
# 10  TRAIN_0000010                             [.]www[.]vanylven[.]no      0
# 11  TRAIN_0000011                                 pref[.]kagawa[.]jp      0
# 12  TRAIN_0000012                                      apollo[.]baby      1
# 13  TRAIN_0000013                                  adonis[.]holdings      0
# 14  TRAIN_0000014                                jalawave[.]net[.]id      1
# 15  TRAIN_0000015                                     hiroshima[.]jp      0
# 16  TRAIN_0000016                       town[.]hiroo[.]hokkaido[.]jp      0
# 17  TRAIN_0000017                                      nic[.]weather      0
# 18  TRAIN_0000018                                    nsa[.]community      1
# 19  TRAIN_0000019                                  allegro[.]tm[.]pl      1
# 20  TRAIN_0000020                       championsleague[.]basketball      0
# 21  TRAIN_0000021                              cmsjm[.]rj[.]gov[.]br      1
# 22  TRAIN_0000022                                wcape[.]school[.]za      0
# 23  TRAIN_0000023                    town[.]yugawara[.]kanagawa[.]jp      0
# 24  TRAIN_0000024   global[.]net[.]pg/diocese_of_aitape/aitape[.]htm      0
# 25  TRAIN_0000025                        vill[.]ogimi[.]okinawa[.]jp      0
# 26  TRAIN_0000026                                  oldham[.]sch[.]uk      0
# 27  TRAIN_0000027                  city[.]makinohara[.]shizuoka[.]jp      0
# 28  TRAIN_0000028                                     kagoshima[.]jp      0
# 29  TRAIN_0000029                     vill[.]sekikawa[.]niigata[.]jp      0

# %%
test_df.head()
# Out:
#              ID                                            URL
# 0  TEST_0000000               niquelarte[.]blogspot[.]com[.]es
# 1  TEST_0000001                    northernmetalproducts[.]com
# 2  TEST_0000002                                        ga[.]de
# 3  TEST_0000003  florawww[.]eeb[.]uconn[.]edu/199300089[.]html
# 4  TEST_0000004                            activecity[.]moscow

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6995056 entries, 0 to 6995055
# Data columns (total 3 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   ID      object
#  1   URL     object
#  2   label   int64
# dtypes: int64(1), object(2)
# memory usage: 160.1+ MB

# %%
train_df[train_df['URL'].isna()]
# Out:
# Empty DataFrame
# Columns: [ID, URL, label]
# Index: []

# %%
train_df[train_df['label'].isna()]
# Out:
# Empty DataFrame
# Columns: [ID, URL, label]
# Index: []

# %%
fig, ax = plt.subplots(figsize = (12, 8))
sns.barplot(x = train_df['label'].value_counts().index,
            y = train_df['label'].value_counts().values,
            palette = 'Set3',
            ax = ax)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\PNC\AppData\Local\Temp\ipykernel_15044\1986079669.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = train_df['label'].value_counts().index,

# %%
train_df[train_df['label'] == 1]
# Out:
#                     ID                                                URL  \
# 4        TRAIN_0000004              open24[.]ie-news[.]irish/online/Login
# 5        TRAIN_0000005                             93fm[.]radio[.]br/file
# 6        TRAIN_0000006  ps[.]com[.]vu/wp-config/wp-incluides/soft/ursn...
# 9        TRAIN_0000009                165[.]232[.]173[.]145/mobile[.]html
# 12       TRAIN_0000012                                      apollo[.]baby
# ...                ...                                                ...
# 6995033  TRAIN_6995033                posts-8012419782[.]smarttechno[.]hr
# 6995044  TRAIN_6995044                                        rthe[.]top/
# 6995047  TRAIN_6995047                        www2[.]ml[.]meiceaord[.]com
# 6995050  TRAIN_6995050                      10rtggdoffice[.]duckdns[.]org
# 6995053  TRAIN_6995053  employeesalaryschedule70[.]000webhostapp[.]com...
#
#          label
# 4            1
# 5            1
# 6            1
# 9            1
# 12           1
# ...        ...
# 6995033      1
# 6995044      1
# 6995047      1
# 6995050      1
# 6995053      1
#
# [1564897 rows x 3 columns]

# %%
train_df['URL'] = train_df['URL'].apply(lambda x: x.replace('[.]', '.'))
test_df['URL'] = test_df['URL'].apply(lambda x: x.replace('[.]', '.'))

# %%
## 새로운 변수 생성
# URL 길이
train_df['length'] = train_df['URL'].str.len()
test_df['length'] = test_df['URL'].str.len()

# 서브도메인 개수
train_df['subdomain_count'] = train_df['URL'].str.split('.').apply(lambda x: len(x) - 2)
test_df['subdomain_count'] = test_df['URL'].str.split('.').apply(lambda x: len(x) - 2)

# 특수 문자('-', '_', '/') 개수
train_df['special_char_count'] = train_df['URL'].apply(lambda x: sum(1 for c in x if c in '-_/'))
test_df['special_char_count'] = test_df['URL'].apply(lambda x: sum(1 for c in x if c in '-_/'))

# %%
train_df
# Out:
#                     ID                                                URL  \
# 0        TRAIN_0000000                                 poznan.wuoz.gov.pl
# 1        TRAIN_0000001                                vill.okawa.kochi.jp
# 2        TRAIN_0000002                              nationalfinance.co.om
# 3        TRAIN_0000003                             town.ozora.hokkaido.jp
# 4        TRAIN_0000004                  open24.ie-news.irish/online/Login
# ...                ...                                                ...
# 6995051  TRAIN_6995051                                         ddht.co.kr
# 6995052  TRAIN_6995052                               www.upstartepoxy.com
# 6995053  TRAIN_6995053  employeesalaryschedule70.000webhostapp.com/adb...
# 6995054  TRAIN_6995054                                     dekalbtool.com
# 6995055  TRAIN_6995055                                 helpinganimals.com
#
#          label  length  subdomain_count  special_char_count
# 0            0      18                2                   0
# 1            0      19                2                   0
# 2            0      21                1                   0
# 3            0      22                2                   0
# 4            1      33                1                   3
# ...        ...     ...              ...                 ...
# 6995051      0      10                1                   0
# 6995052      0      20                1                   0
# 6995053      1      50                1                   2
# 6995054      0      14                0                   0
# 6995055      0      18                0                   0
#
# [6995056 rows x 6 columns]

# %%
def tokenize_url(url):
    tokens = re.split(r'[\W_]+', url)
    return [t.lower() for t in tokens]

train_url = train_df['URL']
train_url = [tokenize_url(url) for url in train_url]

test_url = test_df['URL']
test_url = [tokenize_url(url) for url in test_url]

train_url
# Out:
# [['poznan', 'wuoz', 'gov', 'pl'],
#  ['vill', 'okawa', 'kochi', 'jp'],
#  ['nationalfinance', 'co', 'om'],
#  ['town', 'ozora', 'hokkaido', 'jp'],
#  ['open24', 'ie', 'news', 'irish', 'online', 'login'],
#  ['93fm', 'radio', 'br', 'file'],
#  ['ps', 'com', 'vu', 'wp', 'config', 'wp', 'incluides', 'soft', 'ursnbxmmvd'],
#  ['rih', 'p', 'se'],
#  ['microsoft', 'ltda'],
#  ['165', '232', '173', '145', 'mobile', 'html'],
#  ['', 'www', 'vanylven', 'no'],
#  ['pref', 'kagawa', 'jp'],
#  ['apollo', 'baby'],
#  ['adonis', 'holdings'],
#  ['jalawave', 'net', 'id'],
#  ['hiroshima', 'jp'],
#  ['town', 'hiroo', 'hokkaido', 'jp'],
#  ['nic', 'weather'],
#  ['nsa', 'community'],
#  ['allegro', 'tm', 'pl'],
#  ['championsleague', 'basketball'],
#  ['cmsjm', 'rj', 'gov', 'br'],
#  ['wcape', 'school', 'za'],
#  ['town', 'yugawara', 'kanagawa', 'jp'],
#  ['global', 'net', 'pg', 'diocese', 'of', 'aitape', 'aitape', 'htm'],
#  ['vill', 'ogimi', 'okinawa', 'jp'],
#  ['oldham', 'sch', 'uk'],
#  ['city', 'makinohara', 'shizuoka', 'jp'],
#  ['kagoshima', 'jp'],
#  ['vill', 'sekikawa', 'niigata', 'jp'],
#  ['city', 'komaki', 'aichi', 'jp'],
#  ['grans', 'naturbruksgymn', 'se'],
#  ['provincia', 'cremona', 'it'],
#  ['parma', 'it'],
#  ['musikcity', 'mus', 'br', 'lojas', 'ipiranga', 'html'],
#  ['xn', 'mgbbfkcz5khe9b', 'xn', 'ngbc5azd'],
#  ['foerderverein', 'kinderhospiz', 'saarland'],
#  ['crm', 'dynamics', 'schwarz'],
#  ['mediaoffice', 'abudhabi'],
#  ['pref', 'kanagawa', 'jp'],
#  ['quipianura', 'bg', 'it', ''],
#  ['bestcases', 'life'],
#  ['stjohns', 'stoke', 'sch', 'uk'],
#  ['nic', 'xn', 'fzys8d69uvgm'],
#  ['microsoft', 'tires'],
#  ['capebreton', 'vacations'],
#  ['durham', 'sch', 'uk'],
#  ['city', 'numata', 'gunma', 'jp'],
#  ['social', 'innovation', 'hitachi'],
#  ['town', 'masaki', 'ehime', 'jp'],
#  ['city', 'kakogawa', 'hyogo', 'jp'],
#  ['www', 'edarah', 'com', 'eg'],
#  ['health', 'nz'],
#  ['town', 'kanan', 'osaka', 'jp'],
#  ['softter', 'wiki', 'br', ''],
#  ['juegosvestir', 'juegos'],
#  ['', 'geodeta', 'kartuzy', 'pl'],
#  ['town', 'matsuno', 'ehime', 'jp'],
#  ['52',
#   '20',
#   '22',
#   '249',
#   '8080',
#   'bannertool',
#   'htmlpages',
#   'welcome',
#   'jsp'],
#  ['ulssasolo', 'ven', 'it'],
#  ['relay', 'immo'],
#  ['kirken', 'trondheim', 'no'],
#  ['comune', 'vercelli', 'it'],
#  ['bk', 'tegner', 's', 'se'],
#  ['robertlaffont', 'quebec'],
#  ['fortius', 'foundation'],
#  ['spm',
#   'gov',
#   'cm',
#   'showdoc',
#   'php',
#   'rubr',
#   '6000',
#   'amp',
#   'srubr',
#   '6106',
#   'amp',
#   'lang',
#   'en',
#   'amp',
#   'tpl',
#   '2'],
#  ['town', 'esashi', 'hokkaido', 'jp'],
#  ['matera', 'it'],
#  ['city', 'omihachiman', 'shiga', 'jp'],
#  ['www', 'graduatestudies', 'uc', 'edu', 'kh'],
#  ['town', 'ando', 'nara', 'jp'],
#  ['city', 'nagareyama', 'chiba', 'jp'],
#  ['random', 'convenzioni', 'genova', 'it', ''],
#  ['idhs', 'vic', 'gov', 'au', 'paypal', ''],
#  ['trafford', 'sch', 'uk'],
#  ['45', '43', '60', '140', ''],
#  ['huddersfield', 'exposed'],
#  ['freemasonry', 'london', 'museum'],
#  ['parasporin', 'fitc', 'pref', 'fukuoka', 'jp'],
#  ['www', '1010', 'archi'],
#  ['nic', 'insurance'],
#  ['cename', 'gt'],
#  ['dpmteabanhnet', 'org', 'kh'],
#  ['avellino', 'it'],
#  ['grpvrtual',
#   'actv',
#   'waw',
#   'pl',
#   '443',
#   'mua',
#   'user',
#   'scis',
#   'j6unvhzsitlyrxstpnfun4tssjgejkn7dldp6fxsjfxo',
#   '3d',
#   'no',
#   'back',
#   'button',
#   ''],
#  ['api', 'motoka', 'com', 'bn'],
#  ['city', 'kaminoyama', 'yamagata', 'jp'],
#  ['tokushima', 'jp'],
#  ['short', 'wu', 'ac', 'at', '97qb'],
#  ['town', 'taiji', 'wakayama', 'jp'],
#  ['mln', 'lib', 'ma', 'us', 'info', 'mtida', 'htm'],
#  ['nic', 'cipriani'],
#  ['city', 'itabashi', 'tokyo', 'jp'],
#  ['city', 'kuji', 'iwate', 'jp'],
#  ['net', 'ai', 'precolumbian', 'html'],
#  ['microsofteducation', 'courses'],
#  ['suffolk', 'sch', 'uk'],
#  ['town', 'oharu', 'aichi', 'jp'],
#  ['mail', 'dewa', 'kitchen'],
#  ['camaraareial', 'pb', 'gov', 'br'],
#  ['kch', 'kagoshima', 'kagoshima', 'jp'],
#  ['goonline', 'bnppnrailbas', 'gives', ''],
#  ['krakow', 'witd', 'gov', 'pl'],
#  ['nic', 'vig'],
#  ['sfx', 'liverpool', 'sch', 'uk'],
#  ['ambc', 'mil', 'do', 'includes', 'itauonline', 'isp', ''],
#  ['town', 'tone', 'ibaraki', 'jp'],
#  ['nic', 'mtn'],
#  ['ndl', 'ethernet', 'edu', 'et'],
#  ['city', 'otake', 'hiroshima', 'jp'],
#  ['34', '120', '64', '173', 'accounts', 'login'],
#  ['bsb', 'br'],
#  ['mrc', 'org', 'mu'],
#  ['penryn',
#   'college',
#   'cornwall',
#   'sch',
#   'uk',
#   '20',
#   '21',
#   '05',
#   '16',
#   'login',
#   'php',
#   'email',
#   'protected',
#   ''],
#  ['k12', 'nh', 'us'],
#  ['natcom', 'com', 'ht'],
#  ['91', '212', '121', '39', ''],
#  ['lambeth', 'sch', 'uk'],
#  ['www', 'effizienz', 'coach'],
#  ['nic', 'ott'],
#  ['mod', 'mil', 'iq'],
#  ['dev', 'xatanet', 'zp', 'ua'],
#  ['digital', 'hermes'],
#  ['nic', 'voting'],
#  ['bcc', 'com', 'uz'],
#  ['mester', 'info', 'hu'],
#  ['nic', 'amica'],
#  ['yahoo'],
#  ['hymers', 'hull', 'sch', 'uk'],
#  ['115', '78', '226', '68', '8080', 'das', 'php'],
#  ['hospital', 'isesaki', 'gunma', 'jp'],
#  ['ejercito', 'mil', 'uy'],
#  ['doncaster', 'sch', 'uk'],
#  ['city', 'tamba', 'hyogo', 'jp'],
#  ['pakistan', 'web', 'pk'],
#  ['town', 'kibichuo', 'okayama', 'jp'],
#  ['', 'staswiny', 'szkola', 'pl'],
#  ['hia', 'edu', 'au', 'tmscustomers'],
#  ['spidol', 'webcam'],
#  ['shop', 'hu'],
#  ['omanairports', 'co', 'om'],
#  ['sopac', 'org', 'py'],
#  ['www', 'comunidad', 'madrid'],
#  ['nic', 'target'],
#  ['vill', 'nozawaonsen', 'nagano', 'jp'],
#  ['hoelters', 'edu', 'ar'],
#  ['city', 'obihiro', 'hokkaido', 'jp'],
#  ['global', 'toyota'],
#  ['archives', 'nm', 'cn'],
#  ['westcoastflorida',
#   'realtor',
#   'wp',
#   'admin',
#   'includes',
#   'cn',
#   'amencn',
#   '1',
#   'index',
#   'php',
#   'email',
#   'itm',
#   'uk',
#   'dbk',
#   'group',
#   'com'],
#  ['nic', 'yamaxun'],
#  ['facebook', 'mominov', 'com', 'az', ''],
#  ['nic', 'cruise'],
#  ['google', 'feedback'],
#  ['chicken', 'ab', 'ca'],
#  ['ip6', 'servers', 'arpa'],
#  ['town', 'toyosato', 'shiga', 'jp'],
#  ['barcode', 'mt', 'css', 'css', 'html'],
#  ['mail', 'twinlakes', 'net', 'ph'],
#  ['town', 'yoshino', 'nara', 'jp'],
#  ['rfmf', 'mil', 'fj'],
#  ['kinniyacentral', 'sch', 'lk'],
#  ['216', '172', '187', '13', ''],
#  ['vault', 'insurance'],
#  ['proxima', 'alt', 'za'],
#  ['challengermode', 'luxe', 'steam', 'html'],
#  ['djupdalen', 'molde', 'no'],
#  ['ustomerokolur', 'website', 'fk', 'f2', 'php'],
#  ['geometri', 'verbania', 'it'],
#  ['nic', 'homegoods'],
#  ['ada', 'org', 'mz', 'ch', 'paket'],
#  ['sportschuetzen', 'feld', 'meilen', 'ch', 'tf'],
#  ['japanese', 'bukgu', 'ulsan', 'kr'],
#  ['city', 'koshigaya', 'saitama', 'jp'],
#  ['bhtechnicalcollege', 'edu', 'zm'],
#  ['town', 'nakai', 'kanagawa', 'jp'],
#  ['seminarski', 'diplomski', 'co', 'rs'],
#  ['city', 'hino', 'tokyo', 'jp'],
#  ['nic', 'ibm'],
#  ['pahcakecwap', 'markets'],
#  ['lib', 'ks', 'us'],
#  ['town', 'yaotsu', 'gifu', 'jp'],
#  ['nic', 'ollo'],
#  ['mazowsze', 'pl'],
#  ['town', 'yaese', 'okinawa', 'jp'],
#  ['liceonaval', 'mil', 'ec'],
#  ['city', 'iwaki', 'fukushima', 'jp'],
#  ['nic', 'joy'],
#  ['recruitment', 'praxi'],
#  ['getteamfix', 'cab'],
#  ['city', 'suzaka', 'nagano', 'jp'],
#  ['braveart', 'scot'],
#  ['skinbid', 'biz', 'pl'],
#  ['www', 'masset', 'paris'],
#  ['dsn', 'diamonds', 'index', 'html'],
#  ['nic', 'ford'],
#  ['governmentofbelize',
#   'gov',
#   'bz',
#   'ministry',
#   'details',
#   'php',
#   'ministry',
#   'id',
#   '1'],
#  ['town', 'hidaka', 'wakayama', 'jp'],
#  ['naha', 'kokusaidori', 'okinawa'],
#  ['nic', 'tires'],
#  ['city', 'kushima', 'miyazaki', 'jp'],
#  ['town', 'oe', 'yamagata', 'jp'],
#  ['ganardineroenvenezuela', 'net', 've'],
#  ['cmt', 'frosinone', 'it'],
#  ['workspace', 'access', 'total'],
#  ['iwrm', 'namibia', 'info', 'na'],
#  ['agora', 'imb', 'br'],
#  ['mie',
#   'edu',
#   'mw',
#   'wp',
#   'content',
#   'plugins',
#   'tngzhofxxn',
#   'cc',
#   'index',
#   'html'],
#  ['nao', 'gov', 'lr'],
#  ['veneto', 'it'],
#  ['gloucs', 'sch', 'uk'],
#  ['ferrara', 'it'],
#  ['www', 'evisa', 'gov', 'ss'],
#  ['town', 'arai', 'shizuoka', 'jp'],
#  ['nic', 'seek'],
#  ['tribunale', 'macerata', 'it'],
#  ['iz', 'hr'],
#  ['city', 'saku', 'nagano', 'jp'],
#  ['ucb', 'edu', 'pr'],
#  ['podcast', 'beer'],
#  ['good', 'com', 'mo', 'images', 'cartabcc', ''],
#  ['microsoft', 'navy'],
#  ['acuavalle', 'gov', 'co'],
#  ['ysrf', 'org', 'ye'],
#  ['studio', 'seasons', 'nom', 'br'],
#  ['isxzz', 'exclusiverewards', '0307', 'pics'],
#  ['kankou', 'town', 'tatsuno', 'nagano', 'jp'],
#  ['runescape', 'com', 'so', ''],
#  ['2007', 'changchun', 'jl', 'cn'],
#  ['20', '89', '19', '232', ''],
#  ['amaro', 'shop', 'pl', ''],
#  ['city', 'yanagawa', 'fukuoka', 'jp'],
#  ['wenus', 'bytom', 'pl'],
#  ['vill', 'samegawa', 'fukushima', 'jp'],
#  ['city', 'ojiya', 'niigata', 'jp'],
#  ['rambach', 'video', 'wp', 'admin2', 'f'],
#  ['cals', 'lib', 'ar', 'us', 'focal', 'index', 'html'],
#  ['town', 'meiwa', 'mie', 'jp', 'romantic', 'kids', ''],
#  ['bag', 'org', 'gt', 'graph', 'aol', ''],
#  ['nic', 'stada'],
#  ['collections', 'naval', 'aviation', 'museum'],
#  ['allegro', 'priv', 'pl'],
#  ['town', 'shisui', 'chiba', 'jp'],
#  ['city', 'takahama', 'aichi', 'jp'],
#  ['larenarde', 'immo'],
#  ['www2', 'city', 'otsu', 'shiga', 'jp', 'kids', ''],
#  ['comune', 'borgosesia', 'vercelli', 'it'],
#  ['mancave', 'vet', 'dr', 'scan', 'php'],
#  ['um', 'nowaruda', 'pl'],
#  ['rwandaveterinarycouncil', 'rw'],
#  ['welcome', 'helsinki'],
#  ['consiglio', 'regione', 'lazio', 'it'],
#  ['nic', 'sca'],
#  ['polaris', 'dance'],
#  ['tosyokan', 'city', 'katsuyama', 'fukui', 'jp'],
#  ['vill', 'higashiyoshino', 'nara', 'jp'],
#  ['nic', 'obi'],
#  ['bee', 'net', 'tn'],
#  ['miras', 'lr'],
#  ['ciudadmcy', 'info', 've'],
#  ['quipianura', 'bg', 'it', 'ft', ''],
#  ['pref', 'fukushima', 'jp'],
#  ['nic', 'sfr'],
#  ['city', 'chita', 'aichi', 'jp'],
#  ['town', 'niki', 'hokkaido', 'jp'],
#  ['rogue', 'pizza'],
#  ['fpn', 'bg', 'ac', 'rs'],
#  ['ipef', 'edu', 'pa'],
#  ['hospital', 'hakodate', 'hokkaido', 'jp'],
#  ['city', 'nanto', 'toyama', 'jp'],
#  ['manchester', 'rent', 'jsr', 'new1'],
#  ['habari', 'ne', 'tz'],
#  ['interessen', 'kaufen', 'mobile', 'de', 'id27072', 'email'],
#  ['mail', 'sudafast', 'edu', 'sd'],
#  ['nic', 'stcgroup'],
#  ['cliniclowns', 'cw'],
#  ['bashkiaberat', 'gov', 'al', 'recovery', 'htm'],
#  ['masvingocity', 'gov', 'zw'],
#  ['k12', 'ma', 'us'],
#  ['omantel', 'net', 'om'],
#  ['city', 'kikugawa', 'shizuoka', 'jp'],
#  ['meino', 'ingegneri', 'chieti', 'it'],
#  ['case', 'tm', 'lawschool', 'lawschool', 'html'],
#  ['friend', 'com', 'kp'],
#  ['pielgrzymka', 'diecezja', 'elk', 'pl'],
#  ['zielonyraj', 'mielno', 'pl'],
#  ['arezzo', 'it'],
#  ['bury', 'sch', 'uk'],
#  ['nic', 'walter'],
#  ['aglcybersolutions', 'mw'],
#  ['town', 'kunimi', 'fukushima', 'jp'],
#  ['ostrowiec', 'pl'],
#  ['can', 'town', 'kamikawa', 'hyogo', 'jp'],
#  ['vill', 'noda', 'iwate', 'jp'],
#  ['masenoschool', 'sc', 'ke'],
#  ['iqraa', 'edu', 'ye', 'wp', 'includes', 'kagoya', 'kagoya', 'net'],
#  ['103', '155', '93', '52', 'load', 'html'],
#  ['wakaba', 'toyonaka', 'osaka', 'jp', 'tate', 'index', 'e', 'shtml'],
#  ['fb', 'ali', 'laifa', 'xin'],
#  ['nic', 'ferrero'],
#  ['vill', 'ginoza', 'okinawa', 'jp'],
#  ['veterinaire', 'fr'],
#  ['nic', 'mint'],
#  ['nrw', 'diebasis', 'nrw'],
#  ['miyazaki', 'jp'],
#  ['investornews', 'vanguard'],
#  ['comwoman', 'chintai'],
#  ['town', 'toyotomi', 'hokkaido', 'jp'],
#  ['town', 'aizubange', 'fukushima', 'jp'],
#  ['raimondobruschi', 'sgush', 'cards'],
#  ['nieruchomosci', 'pl'],
#  ['rizzo', 'cnt', 'br'],
#  ['landandsea', 'vacations'],
#  ['glasgow', 'sch', 'uk'],
#  ['bialystok', 'sa', 'gov', 'pl'],
#  ['thenews', 'com', 'lr'],
#  ['vill', 'otoineppu', 'hokkaido', 'jp'],
#  ['ru', 'shell'],
#  ['city', 'gotemba', 'shizuoka', 'jp'],
#  ['nic', 'zuerich'],
#  ['town', 'rebun', 'hokkaido', 'jp'],
#  ['krakow', 'rzgw', 'gov', 'pl'],
#  ['mtc', 'tarawa', 'edu', 'ki'],
#  ['city', 'gujo', 'gifu', 'jp'],
#  ['town', 'ama', 'shimane', 'jp'],
#  ['vccslitonline', 'cc', 'va', 'us'],
#  ['non', 'nom', 'es', 'oficina'],
#  ['pozzallo', 'rg', 'it'],
#  ['nic', 'americanexpress'],
#  ['tonocontrole', 'app', 'tce', 'ro', 'gov', 'br'],
#  ['ed', 'city', 'odawara', 'kanagawa', 'jp', 'kids', ''],
#  ['nic', 'compare'],
#  ['prescoll', 'edu', 'tt', 'jub', 'seascouts', 'html'],
#  ['google', 'com', 'sl'],
#  ['nic', 'lotto'],
#  ['ewer', 'roberts', 'flowers'],
#  ['history', 'museum'],
#  ['city', 'nagaokakyo', 'kyoto', 'jp'],
#  ['gefert', 'zachpomor', 'pl'],
#  ['powiat', 'pl'],
#  ['sassari', 'it'],
#  ['kingston', 'sch', 'uk'],
#  ['revista', 'agulha', 'nom', 'br'],
#  ['haygroup', 'azure'],
#  ['competitividad', 'org', 'do'],
#  ['thewell', 'coach'],
#  ['city', 'hakui', 'ishikawa', 'jp'],
#  ['strike', 'net', 'nz'],
#  ['noc', 'net', 'er'],
#  ['stren', 'ind', 'tn', 'download', 'php', 'id', '27326581'],
#  ['nic', 'aaa'],
#  ['nic', 'xn', 'p1acf'],
#  ['maak', 'org', 'mk'],
#  ['signin', 'eday', 'ws', 'or', 'at'],
#  ['amidsystem', 'ks', 'ua'],
#  ['des', 'jardins', 'fpscu', 'org', 'fj', 'desj', 'login', 'php'],
#  ['city', 'otake', 'hiroshima', 'jp', 'kids', ''],
#  ['vsf', 'org', 'es', 'modules', 'blog', 'drive', 'docs', 'php'],
#  ['nic', 'select'],
#  ['city', 'takasago', 'hyogo', 'jp'],
#  ['drzafar', 'surgery'],
#  ['town', 'tawaramoto', 'nara', 'jp'],
#  ['city', 'semboku', 'akita', 'jp'],
#  ['hen', 'ne', 'ke'],
#  ['sex', 'pl'],
#  ['town', 'sobetsu', 'hokkaido', 'jp'],
#  ['vientianetimes', 'org', 'la'],
#  ['holdings', 'panasonic'],
#  ['town', 'moseushi', 'hokkaido', 'jp'],
#  ['nsw', 'edu', 'au'],
#  ['city', 'tokushima', 'tokushima', 'jp'],
#  ['cidadao', 'lucasdorioverde', 'mt', 'gov', 'br'],
#  ['att', 'glass'],
#  ['city', 'noshiro', 'akita', 'jp'],
#  ['tv', 'bo'],
#  ['lycee', 'iles', 'loina', 'wf'],
#  ['tpdf', 'mil', 'tz'],
#  ['skibotn', 'gs', 'tr', 'no'],
#  ['shop', 'memories', 'kharkiv', 'ua'],
#  ['town', 'koori', 'fukushima', 'jp'],
#  ['vill', 'kawaba', 'gunma', 'jp'],
#  ['town', 'kushimoto', 'wakayama', 'jp'],
#  ['town', 'shimogo', 'fukushima', 'jp'],
#  ['cultura', 'trentino', 'it'],
#  ['nic', 'xn', 'vhquv'],
#  ['city', 'nemuro', 'hokkaido', 'jp'],
#  ['sim', 'floripa', 'br'],
#  ['nic', 'beats'],
#  ['town', 'murata', 'miyagi', 'jp'],
#  ['hhxx', 'cmjy', 'sh', 'cn', 'admin', 'img', 'thumbs', 'asp'],
#  ['mail', 'cbc', 'sh', 'cn'],
#  ['nic', 'hyatt'],
#  ['town', 'wakasa', 'tottori', 'jp'],
#  ['apps', 'wireless', 'radio'],
#  ['k12', 'dc', 'us'],
#  ['tour', 'milan', 'it'],
#  ['bgsg', 'bury', 'sch', 'uk'],
#  ['emilia', 'romagna', 'it'],
#  ['borundur', 'gov', 'mn', 'images', 'fb', ''],
#  ['marca', 'web', 've'],
#  ['lapcamera', 'net', 'vn'],
#  ['town', 'isen', 'kagoshima', 'jp'],
#  ['nic', 'pccw'],
#  ['nyxt', 'atlas', 'engineer'],
#  ['check', 'japan', 'update', 'japan', 'yahoo', 'net', 'cm'],
#  ['bousai', 'sch', 'kawaguchi', 'saitama', 'jp'],
#  ['far', 'east', 'net', 'tw'],
#  ['nic', 'dish'],
#  ['themovingpicturewrites', 'pictures'],
#  ['bc3', 'cc', 'pa', 'us', ''],
#  ['nic', 'save'],
#  ['madlove', '1337', 'pictures', ''],
#  ['radios', 'co', 'ni'],
#  ['ternopil', 'ua'],
#  ['stamp', '183', 'ha', 'cn'],
#  ['omadhina', 'co', 'na'],
#  ['city', 'wakayama', 'wakayama', 'jp'],
#  ['sspeterandpauls', 'redbridge', 'sch', 'uk'],
#  ['co', 'hotmail'],
#  ['evisa', 'zambiaimmigration', 'gov', 'zm'],
#  ['ma', 'cuisinella'],
#  ['www', 'ip', 'sb'],
#  ['kirken', 'stavanger', 'no'],
#  ['comune', 'viterbo', 'it'],
#  ['nic', 'lifeinsurance'],
#  ['mie', 'edu', 'mw'],
#  ['alcon', 'gifu', 'jp'],
#  ['eduone',
#   'edu',
#   'sg',
#   'resources',
#   'questionbank',
#   'gce',
#   '20a',
#   '20level',
#   'h2',
#   '20mathematics',
#   'equations',
#   '20and',
#   '20inequalities',
#   'structured',
#   '20question',
#   'ch',
#   'c',
#   'php'],
#  ['alcaldiamatiguas', 'gob', 'ni'],
#  ['apartment', 'hotel', 'hu'],
#  ['vill', 'minamidaito', 'okinawa', 'jp'],
#  ['acom', 'org', 'sb'],
#  ['damodareventcinemas', 'com', 'fj'],
#  ['roblox', 'com', 'mg'],
#  ['20', '25', '18', '237', ''],
#  ['town', 'horonobe', 'hokkaido', 'jp'],
#  ['city', 'moka', 'tochigi', 'jp'],
#  ['perugia', 'it'],
#  ['comune', 'chitignano', 'arezzo', 'it'],
#  ['town', 'hiji', 'oita', 'jp'],
#  ['frddh', 'org', 'ht'],
#  ['smartsolutions', 'lighting', 'contractdocs', 'ture', 'login', 'login'],
#  ['devon', 'sch', 'uk'],
#  ['google', 'com', 'pg'],
#  ['mail', 'ispan', 'net', 'np'],
#  ['beskidy', 'pl'],
#  ['agenzialavoro', 'emr', 'it'],
#  ['lismore', 'vic', 'au'],
#  ['gibraltarheritagetrust', 'org', 'gi'],
#  ['cambs', 'sch', 'uk'],
#  ['nic', 'fiat'],
#  ['town', 'kumejima', 'okinawa', 'jp'],
#  ['uppsala4h', 'c', 'se'],
#  ['dpnr', 'vi', 'gov', 'home', ''],
#  ['mortgageeducators', 'courses'],
#  ['lib', 'city', 'kasaoka', 'okayama', 'jp'],
#  ['city', 'ryugasaki', 'ibaraki', 'jp'],
#  ['walsall', 'sch', 'uk'],
#  ['owc', 'org', 'mn', 'scout', ''],
#  ['mobilporno', 'xn', '3ds443g'],
#  ['44', '204', '4', '182'],
#  ['connor', 'sampa', 'br'],
#  ['icitywww', 'town', 'rokunohe', 'aomori', 'jp'],
#  ['xn', '0tr80i11eca131dda736e5v4b0duga450wha', 'xn', '55qx5d'],
#  ['city', 'kanazawa', 'ishikawa', 'jp'],
#  ['ajkassembly', 'gok', 'pk'],
#  ['town', 'ine', 'kyoto', 'jp'],
#  ['city', 'sabae', 'fukui', 'jp'],
#  ['fm200', 'info', 'tr'],
#  ['city', 'seiyo', 'ehime', 'jp'],
#  ['www', 'portaldogoverno', 'gov', 'mz'],
#  ['nic', 'lincoln'],
#  ['city', 'tsukumi', 'oita', 'jp'],
#  ['vill', 'yugawa', 'fukushima', 'jp'],
#  ['tribhuvan', 'university', 'edu', 'np'],
#  ['bgk24', 'cc'],
#  ['dbs', 'com', 'in', 'sg', '57ley'],
#  ['nic', 'philips'],
#  ['nic', 'vivo'],
#  ['mg', 'cds', 'edu', 'gt'],
#  ['sch', 'kawaguchi', 'saitama', 'jp'],
#  ['pp42', 'opole', 'pl', 'bin', 'ipn', 'php'],
#  ['town', 'misato', 'akita', 'jp'],
#  ['inta', 'gob', 'ni'],
#  ['town', 'nakayama', 'yamagata', 'jp'],
#  ['town', 'haga', 'tochigi', 'jp'],
#  ['akaki', 'odo', 'br'],
#  ['westende', 'wokingham', 'sch', 'uk'],
#  ['lugansk', 'compace', 'lg', 'ua'],
#  ['ardalagoif', 'r', 'se'],
#  ['ejaar', 'london'],
#  ['centralbank', 'gov', 'so'],
#  ['city', 'okazaki', 'aichi', 'jp'],
#  ['city', 'kazuno', 'akita', 'jp'],
#  ['zeiseiren', 'chuo', 'chiba', 'jp'],
#  ['city', 'asago', 'hyogo', 'jp'],
#  ['hp', 'chuou', 'towada', 'towada', 'aomori', 'jp'],
#  ['ksc', 'tuzla', 'edu', 'ba', 'wp', 'wp', 'content', 'apple', 'id', 'html'],
#  ['shreedharmotors', 'com', 'fj'],
#  ['lib', 'town', 'keisen', 'fukuoka', 'jp'],
#  ['lemon', 'co', 'om', 'mt', 'mail', 'ionos', 'com', 'login', 'id', '2327'],
#  ['intranet', 'monash'],
#  ['town', 'yazu', 'tottori', 'jp'],
#  ['schule', 'suedtirol', 'it'],
#  ['scouts', 'org', 'ac'],
#  ['guadeloupe', 'reiseberichte', 'reisen'],
#  ['', 'www', 'trysil', 'no'],
#  ['city', 'wakkanai', 'hokkaido', 'jp'],
#  ['city', 'miyoshi', 'hiroshima', 'jp'],
#  ['city', 'fukaya', 'saitama', 'jp'],
#  ['town', 'aizumi', 'tokushima', 'jp'],
#  ['chieti', 'it'],
#  ['hongliu', 'js', 'cn', ''],
#  ['google', 'com', 'nr'],
#  ['mindyourbusiness', 'co', 'im', 'winningteam', ''],
#  ['nic', 'aetna'],
#  ['town', 'kamifurano', 'hokkaido', 'jp'],
#  ['rarible', 'fan', 'upp', 'meta', 'import', 'php'],
#  ['town', 'moroyama', 'saitama', 'jp'],
#  ['stalker',
#   'cd',
#   'index',
#   'php',
#   'content',
#   '0',
#   'amp',
#   'lang',
#   '2',
#   'amp',
#   'pid',
#   ''],
#  ['114', '141', '253', '232', 'data', 'cache', 'css', 'net', ''],
#  ['galeriaziemowit', 'net', 'pulawy', 'pl'],
#  ['name', 'ng'],
#  ['town', 'kumano', 'hiroshima', 'jp'],
#  ['town', 'tobe', 'ehime', 'jp'],
#  ['city', 'chigasaki', 'kanagawa', 'jp'],
#  ['www3', 'city', 'toyooka', 'hyogo', 'jp'],
#  ['www', 'registeraccountants', 'amsterdam'],
#  ['momentsofinspiration', 'events'],
#  ['town', 'genkai', 'saga', 'jp'],
#  ['i', 'ng'],
#  ['e12', 've'],
#  ['emeraldsociety', 'org', 'mt', 'nbt', 'com', 'aom', ''],
#  ['library', 'city', 'oshu', 'iwate', 'jp'],
#  ['town', 'yahaba', 'iwate', 'jp'],
#  ['datascience', 'salon'],
#  ['city', 'namegata', 'ibaraki', 'jp'],
#  ['name', 'vn'],
#  ['rawa', 'maz', 'pl'],
#  ['vill', 'kosuge', 'yamanashi', 'jp'],
#  ['nic', 'safe'],
#  ['teramo', 'it'],
#  ['sex', 'hu'],
#  ['town', 'ayagawa', 'kagawa', 'jp'],
#  ['library', 'kr', 'ua', 'dc', 'dcproje', 'html'],
#  ['city', 'ritto', 'shiga', 'jp'],
#  ['lib', 'fussa', 'tokyo', 'jp'],
#  ['digiomo', 'realty'],
#  ['pngarnet', 'ac', 'pg'],
#  ['city', 'suzu', 'ishikawa', 'jp'],
#  ['city', 'ashikaga', 'tochigi', 'jp'],
#  ['osmanyildirim', 'dr', 'tr'],
#  ['town', 'kasuya', 'fukuoka', 'jp'],
#  ['fotovonal', 'org', 'hu', 'own', 'file', 'update'],
#  ['town', 'iide', 'yamagata', 'jp'],
#  ['calambamisocc', 'gov', 'ph'],
#  ['city', 'nomi', 'ishikawa', 'jp'],
#  ['foreignaffairs', 'gov', 'mw'],
#  ['google', 'co', 'uz'],
#  ['208', '82', '115', '230', 'wp', 'includes', 'css', 'en', 'error', 'php'],
#  ['serasa', 'vix', 'br'],
#  ['gk', 'org', 'vn'],
#  ['nic', 'actor'],
#  ['www', 'proteccioncivil', 'gob', 'sv'],
#  ['materials', 'sandvik'],
#  ['sch', 'ly'],
#  ['bestexchangers', 'press'],
#  ['skin', 'swatch'],
#  ['metamask', 'loans'],
#  ['dawsonfallsmountainlodge', 'kiwi', 'nz'],
#  ['autism', 'org', 'ge'],
#  ['town', 'uryu', 'hokkaido', 'jp'],
#  ['michael', 'romanenko', 'kg'],
#  ['81', '19', '136', '231', ''],
#  ['city', 'nobeoka', 'miyazaki', 'jp'],
#  ['waterdamagerestoration', 'miami'],
#  ['krzewinka', 'mazury', 'pl'],
#  ['shimane', 'jp'],
#  ['lecce', 'it'],
#  ['town', 'oji', 'nara', 'jp'],
#  ['intertelecom', 'kharkov', 'ua', 'direct', 'php'],
#  ['lobanov', 'pri', 'ee', 'eng', 'index', 'htm'],
#  ['town', 'namie', 'fukushima', 'jp'],
#  ['nic', 'oldnavy'],
#  ['city',
#   'ukiha',
#   'fukuoka',
#   'jp',
#   'hp',
#   'menu000000100',
#   'hpg000000060',
#   'htm'],
#  ['xn', 'c1avg', 'xn', '90a3ac'],
#  ['town', 'kimobetsu', 'hokkaido', 'jp'],
#  ['skyvision', 'film'],
#  ['especiaisg1', 'globo'],
#  ['stoke', 'sch', 'uk'],
#  ['vill', 'ooshika', 'nagano', 'jp'],
#  ['vill', 'toyone', 'aichi', 'jp'],
#  ['comune', 'crotone', 'it'],
#  ['shropshire', 'sch', 'uk'],
#  ['ffh', 'gov', 'mz', 'secure', 'xfinity'],
#  ['prostitutki', 'gelendzhyka', 'men'],
#  ['wsadminw41', 'cologne', 'tbg', 'yahoo', 'image', 'htm'],
#  ['city', 'tsubame', 'niigata', 'jp'],
#  ['eun', 'eg', 'docs', 'n', 'index', 'ee', 'php'],
#  ['conasevi', 'gob', 'sv'],
#  ['smallbusiness', 'bingo'],
#  ['town', 'shirahama', 'wakayama', 'jp'],
#  ['city', 'itoman', 'okinawa', 'jp'],
#  ['town', 'tsukigata', 'hokkaido', 'jp'],
#  ['simbanet', 'co', 'mw'],
#  ['heu', 'nom', 'br'],
#  ['olhodaguadocasado', 'al', 'gov', 'br', 'smt', ''],
#  ['damarcerrahi', 'com', 'az'],
#  ['nic', 'jmp'],
#  ['town', 'aya', 'miyazaki', 'jp'],
#  ['town', 'shimoichi', 'nara', 'jp'],
#  ['mielno', 'pl'],
#  ['city', 'shinjo', 'yamagata', 'jp'],
#  ['wsa', 'gov', 'pl'],
#  ['city', 'kodaira', 'tokyo', 'jp'],
#  ['town', 'shikaoi', 'hokkaido', 'jp'],
#  ['town', 'kin', 'okinawa', 'jp'],
#  ['chukan', 'ac', 'jp'],
#  ['s', 'lanark', 'sch', 'uk'],
#  ['alcon',
#   'gifu',
#   'jp',
#   'editdirecttt',
#   'images',
#   'wp',
#   'update',
#   'wp',
#   'swiftcopy',
#   'adobecloud',
#   'error',
#   'php'],
#  ['provincia', 'potenza', 'it'],
#  ['datacenter', 'hello', 'global', 'ntt'],
#  ['nordhordland', 'fhs', 'no'],
#  ['town', 'aisho', 'shiga', 'jp'],
#  ['ketrzyn', 'pl'],
#  ['szentendre', 'media', 'hu'],
#  ['nic', 'pnc'],
#  ['ram', 'org', 'bo'],
#  ['town', 'minamisanriku', 'miyagi', 'jp'],
#  ['www', 'research', 'youtube'],
#  ['bologna', 'it'],
#  ['nic', 'latrobe'],
#  ['town', 'tosa', 'kochi', 'jp'],
#  ['cootelser', 'coop', 'ar'],
#  ['deliveroo', 'arab'],
#  ['linkedin', 'com', 'pr', 'slink', 'code', 'dqtegm6'],
#  ['com', 'onion'],
#  ['town', 'nagatoro', 'saitama', 'jp'],
#  ['neumann', 'szczecin', 'pl'],
#  ['town', 'keisen', 'fukuoka', 'jp'],
#  ['pref', 'ibaraki', 'jp'],
#  ['itsecurity', 'ku', 'edu', 'kw', 'confirm', 'php'],
#  ['nic', 'bestbuy'],
#  ['library', 'etajima', 'hiroshima', 'jp'],
#  ['city', 'ayase', 'kanagawa', 'jp'],
#  ['', 'www', 'usembassy', 'ye'],
#  ['town', 'nanae', 'hokkaido', 'jp'],
#  ['venezia', 'it'],
#  ['ahu', 'edu', 'jo'],
#  ['town', 'sakai', 'ibaraki', 'jp'],
#  ['town', 'kawanishi', 'yamagata', 'jp'],
#  ['tayomotor', 'gd', 'cn', '404', 'html'],
#  ['city', 'unzen', 'nagasaki', 'jp'],
#  ['kujawy', 'psp', 'gov', 'pl'],
#  ['city', 'habikino', 'osaka', 'jp'],
#  ['topnet', 'rio', 'br'],
#  ['andrebarbosa', 'eti', 'br', 'simuplc', '20eng'],
#  ['main', 'omanobserver', 'om'],
#  ['leics', 'sch', 'uk'],
#  ['iomcollege', 'ac', 'im'],
#  ['ulss13mirano', 'ven', 'it'],
#  ['www', 'ehs', 'co', 'zw'],
#  ['www', 'solomonbusinessregistry', 'gov', 'sb'],
#  ['radio', 'co', 'ci'],
#  ['town', 'hidaka', 'hokkaido', 'jp'],
#  ['ci', 'keene', 'nh', 'us', 'police', 'technophilia', 'html'],
#  ['startlife', 'arts', 'ro', 'hotmail', 'htm'],
#  ['nic', 'ss'],
#  ['xiezi', 'xz', 'cn'],
#  ['city', 'yamaga', 'kumamoto', 'jp'],
#  ['192', '241', '148', '134', 'login', ''],
#  ['coronavirus', 'schule'],
#  ['cobra', 'pages', 'nom', 'br'],
#  ['daressalaamarchdiocese', 'or', 'tz'],
#  ['blogspot', 'com', 'ee'],
#  ['smbc', 'co', 'gy', 'jp2', 'index', 'php'],
#  ['revista', 'criterio', 'nom', 'br'],
#  ['linkin', 'bi', 'o', 'po', 'statement'],
#  ['catsconvention', 'kred'],
#  ['bieszczady', 'pl'],
#  ['pomorze', 'pl'],
#  ['polnometrazhnoe', 'porno', 'video'],
#  ['allegro', 'targi', 'pl', 'product', 'id', '2837465904'],
#  ['campinas', 'br'],
#  ['city', 'obu', 'aichi', 'jp'],
#  ['city', 'hyuga', 'miyazaki', 'jp'],
#  ['gothic', 'bc', 'ca', 'sincity', ''],
#  ['pleszew', 'starostwo', 'gov', 'pl'],
#  ['jsdistribuidora', 'far', 'br'],
#  ['bussa', 'asn', 'au'],
#  ['194', '124', '216', '252'],
#  ['jasiggi', 'jetzt'],
#  ['harrow', 'sch', 'uk'],
#  ['ordre', 'pharmacien', 'fr'],
#  ['', 'trsosh', 'edu', 'tm'],
#  ['podlasie', 'pl'],
#  ['professorwaltertadeu', 'mat', 'br'],
#  ['city', 'kishiwada', 'osaka', 'jp'],
#  ['corporate', 'epson'],
#  ['nic', 'gallup'],
#  ['city', 'himi', 'toyama', 'jp'],
#  ['kherson', 'ua'],
#  ['city', 'okinawa', 'okinawa', 'jp'],
#  ['logisticsofthings', 'dhl'],
#  ['l33t', 'engineer', 'netflix', 'home', 'login', 'php'],
#  ['city', 'kofu', 'yamanashi', 'jp'],
#  ['nic', 'richardli'],
#  ['colabpi', 'pro', 'ec'],
#  ['nikolaev', 'ua'],
#  ['city', 'yamagata', 'gifu', 'jp'],
#  ['alimela', 'co', 'ls'],
#  ['town', 'taiwa', 'miyagi', 'jp'],
#  ['gikai', 'city', 'edogawa', 'tokyo', 'jp'],
#  ['111', '90', '150', '126', ''],
#  ['city', 'amakusa', 'kumamoto', 'jp'],
#  ['ed', 'city', 'hioki', 'kagoshima', 'jp'],
#  ['pin', 'up', 'aviator', 'com', 'kz'],
#  ['city', 'nagaoka', 'niigata', 'jp'],
#  ['courconstitutionnelle', 'gov', 'gn'],
#  ['asb', 'rio', 'nom', 'br'],
#  ['town', 'toyo', 'kochi', 'jp'],
#  ['convention', 'tirol'],
#  ['motorsport', 'vlaanderen'],
#  ['city', 'iwata', 'shizuoka', 'jp'],
#  ['staffs', 'sch', 'uk'],
#  ['nic', 'xn', 'bck1b9a5dre4c'],
#  ['coronavirusfed', 'loans'],
#  ['macclesfield', 'silk', 'museum', ''],
#  ['town', 'echizen', 'fukui', 'jp'],
#  ['52', '206', '159', '80', 'tpl', 'assets', 'html', 'paypal', 'html'],
#  ['city', 'ube', 'yamaguchi', 'jp'],
#  ['37', '221', '92', '116', 'login', 'html'],
#  ['school', 'city', 'akune', 'kagoshima', 'jp'],
#  ['www', 'foodforest', 'garden'],
#  ['op', 'healthcare'],
#  ['ghodaghodi', 'info', 'np'],
#  ['adsl', 'pool', 'sx', 'cn'],
#  ['comiteparalimpicoangolano', 'co', 'ao'],
#  ['biologia', 'uem', 'mz'],
#  ['town', 'nakatombetsu', 'hokkaido', 'jp'],
#  ['city', 'otsu', 'shiga', 'jp'],
#  ['nic', 'ltda'],
#  ['city', 'nago', 'okinawa', 'jp'],
#  ['nic', 'kids'],
#  ['uz', 'ac', 'zw', 'science', 'maths', ''],
#  ['stelar', 'xlm', 'net'],
#  ['openintegration', 'inc'],
#  ['city', 'matsumoto', 'nagano', 'jp'],
#  ['city', 'nakano', 'nagano', 'jp'],
#  ['patrick', 'op', 'het', 'net', 'je', 'wire', ''],
#  ['nic', 'agakhan'],
#  ['archive', 'macaudailytimes', 'com', 'mo'],
#  ['actc', 'army', 'mil', 'za'],
#  ['osframa', 'ong', 'br'],
#  ['city', 'nankoku', 'kochi', 'jp'],
#  ['nic', 'mini'],
#  ['town', 'showa', 'yamanashi', 'jp'],
#  ['pref', 'tokushima', 'jp'],
#  ['town', 'wakuya', 'miyagi', 'jp'],
#  ['hundspann', 'z', 'se'],
#  ['nic', 'auspost'],
#  ['lazyweb', 'club', 'tw', 'dhl', 'dhl', 'info', 'php'],
#  ['online', 'campaning', 'camp'],
#  ['town', 'rankoshi', 'hokkaido', 'jp'],
#  ['city', 'hatsukaichi', 'hiroshima', 'jp'],
#  ['nic', 'calvinklein'],
#  ['notapotiguar', 'set', 'rn', 'gov', 'br'],
#  ['town', 'takahata', 'yamagata', 'jp'],
#  ['malawi',
#   'gov',
#   'mw',
#   'foreign',
#   '20affairs',
#   'home',
#   '20foreignaffairs',
#   'htm'],
#  ['43', '156', '237', '181', ''],
#  ['trash', 'spotter', 'green'],
#  ['msb', 'ac', 'zw', 'plugin', 'ws1', 'php'],
#  ['islamicsummit', 'org', 'sa', 'en', 'default', 'aspx'],
#  ['sicrediseguranca', 'digital', ''],
#  ['www', 'premalex', 'lundbeck'],
#  ['nic', 'data'],
#  ['nic', 'open'],
#  ['adeneng', 'faculty', 'edu', 'ye'],
#  ['thanjuprimary', 'sc', 'ke'],
#  ['8', '210', '244', '33', ''],
#  ['www', 'barbadoslawcourts', 'gov', 'bb'],
#  ['swr', 'gloucs', 'sch', 'uk'],
#  ['savona', 'it'],
#  ['nic', 'fresenius'],
#  ['isabellaescortfrance', 'gallery'],
#  ['haugeskule', 'gs', 'sf', 'no'],
#  ['ouropreto', 'ourtoworld', 'jor', 'br'],
#  ['hereford', 'sch', 'uk'],
#  ['walbrzych', 'pl'],
#  ['tplearn', 'edu', 'sl'],
#  ['nic', 'dell'],
#  ['barcaldine', 'argyll', 'bute', 'sch', 'uk'],
#  ['library', 'town', 'mimata', 'miyazaki', 'jp'],
#  ['town', 'kozaki', 'chiba', 'jp'],
#  ['city', 'ohtawara', 'tochigi', 'jp'],
#  ['scitec', 'uwichill', 'edu', 'bb'],
#  ['firenze', 'it'],
#  ['macc', 'cc', 'mo', 'us', 'athletic', ''],
#  ['was', 'bdren', 'net', 'bd'],
#  ['elaudo', 'agr', 'br'],
#  ['antigonishgolfclub', 'ns', 'ca', 'zdx', 'aq', ''],
#  ['vaxjo', 'ok', 'g', 'se'],
#  ['kanagawa', 'jp'],
#  ['city', 'yokkaichi', 'mie', 'jp'],
#  ['bialarawska', 'rawa', 'maz', 'pl'],
#  ['town', 'ryuoh', 'shiga', 'jp'],
#  ['gramadoinesquecivel', 'tur', 'br'],
#  ['trysil', 'no'],
#  ['alsheharymedical', 'com', 'ye'],
#  ['wandsworth', 'sch', 'uk'],
#  ['celac2015', 'go', 'cr', 'login', 'update', ''],
#  ['nic', 'dtv'],
#  ['nic', 'xn', '1ck2e1b'],
#  ['city', 'yabu', 'hyogo', 'jp'],
#  ['allegro', 'pc', 'pl', 'product', 'id', '423897423', 'thumb', '8'],
#  ['np', 'ac', 'rs', 'modules', 'mod', 'bcp', ''],
#  ['town', 'fujisato', 'akita', 'jp'],
#  ['ipaypall', 'tk'],
#  ['opensea', 'io', 'offer', 'coleraine', 'vic', 'au'],
#  ['pref', 'oita', 'jp', 'kids', ''],
#  ['www', 'textiledirectory', 'com', 'mm'],
#  ['gizycko', 'pup', 'gov', 'pl'],
#  ['cim', 'br'],
#  ['city', 'shobara', 'hiroshima', 'jp'],
#  ['print', 'corp', 'co', 'ls'],
#  ['town', 'naie', 'hokkaido', 'jp'],
#  ['8', '129', '211', '188', '10003', 'mitid', 'php'],
#  ['city', 'shiroishi', 'miyagi', 'jp'],
#  ['marmoresegranitosdonorte', 'co', 'mz'],
#  ['whatsapp', 'covid19', 'et'],
#  ['squ', 'edu', 'om', 'mainlibrary', 'tabid', '1337', 'default', 'aspx'],
#  ['cor', 'sp', 'cw'],
#  ['images', 'google', 'co', 'uz'],
#  ['155', '94', '197', '38', 'beon', 'client', 'index', 'pc', 'php'],
#  ['vespa', 'bh'],
#  ['socialdemokraterna', 'aland', 'fi'],
#  ['number9', 'dj', 'account', 'html'],
#  ['northumberland', 'sch', 'uk'],
#  ['tvbatistasiao', 'cng', 'br', 'home', 'index', 'html'],
#  ['greenbank', 'sefton', 'sch', 'uk'],
#  ['uca', 'edu', 'sv', 'ingles', 'index', 'html'],
#  ['fmo', 'krsu', 'edu', 'kg', 'logs', 'bb', ''],
#  ['apolitecnica', 'ac', 'mz'],
#  ['coronacola', 'cricket'],
#  ['allianceassurances', 'com', 'dz'],
#  ['city', 'toki', 'gifu', 'jp'],
#  ['fshn', 'edu', 'al', 'english', 'kimi', 'per', 'htm'],
#  ['comune', 'ferrara', 'it'],
#  ['town', 'kujukuri', 'chiba', 'jp'],
#  ['tmth', 'edu', 'gr', 'en', 'aet', '6', '21', 'html'],
#  ['ragusa', 'it'],
#  ['vill', 'achi', 'nagano', 'jp'],
#  ['ciicla', 'ucr', 'ac', 'cr', ''],
#  ['vill', 'higashichichibu', 'saitama', 'jp'],
#  ['build', 'landrover'],
#  ['messina', 'it'],
#  ['nic', 'farmers'],
#  ['town', 'kaneyama', 'yamagata', 'jp'],
#  ['utap', 'org', 'tn', 'wp', 'includes', 'rnds', 'db', 'box', ''],
#  ['town', 'higashiizu', 'shizuoka', 'jp'],
#  ['town', 'nanporo', 'hokkaido', 'jp'],
#  ['bbc', 'net', 'ph'],
#  ['kolobrzeg', 'pl'],
#  ['tourism', 'org', 'fk', 'people', 'htm'],
#  ['orange', 'com', 'lr'],
#  ['city', 'beppu', 'oita', 'jp'],
#  ['cts', 'milton', 'keynes', 'sch', 'uk'],
#  ['nic', 'homedepot'],
#  ['updatemy', 'computer'],
#  ['verbania', 'it'],
#  ['town', 'kawagoe', 'mie', 'jp'],
#  ['nic', 'silk'],
#  ['jasiggi', 'jetzt', 'tesco', 'html'],
#  ['dekalb', 'public', 'lib', 'ga', 'us', 'friends', 'friends', 'htm'],
#  ['opensea', 'com', 'bz'],
#  ['zgorzelec', 'pl'],
#  ['podhale', 'pl'],
#  ['www', 'nrb', 'co', 'zm'],
#  ['reisl', 'uac', 'bj'],
#  ['nybble', 'h', 'se'],
#  ['43', '134', '233', '26', ''],
#  ['edu', 'mg'],
#  ['museum', 'city', 'ena', 'gifu', 'jp'],
#  ['avira', 'fashion'],
#  ['town', 'nakanoto', 'ishikawa', 'jp'],
#  ['xn', 'wlqp2mxohjvqglieigu14d', 'xn', 'g2xx48c'],
#  ['pref',
#   'yamagata',
#   'jp',
#   'ou',
#   'sogoshicho',
#   'mogami',
#   '314002',
#   'watasitachinokurasitozeikin',
#   'html'],
#  ['sc', 'city', 'takahashi', 'okayama', 'jp'],
#  ['foto', 'bieszczady', 'pl'],
#  ['porto', 'monfalcone', 'gorizia', 'it'],
#  ['metrored', 'med', 'ec'],
#  ['sinainsurance', 'co', 'ir'],
#  ['nic', 'redumbrella'],
#  ['heritagebankofcommerce', 'bank'],
#  ['nic', 'xn', 'kcrx77d1x4a'],
#  ['interessen', 'kaufen'],
#  ['canzon', 'milan', 'it'],
#  ['nic', 'mortgage'],
#  ['town', 'ichinohe', 'iwate', 'jp'],
#  ['joel', 'pasquier', 'nom', 'fr'],
#  ['xn', 'z1aac', 'xn', 'p1ai'],
#  ['xnxx', 'biz', 'id'],
#  ['town', 'kikonai', 'hokkaido', 'jp'],
#  ['amhub', 'aiesec', 'org', 'pa'],
#  ['city', 'tendo', 'yamagata', 'jp'],
#  ['nla', 'gov', 'lr', 'info', ''],
#  ['icsa', 'ac', 'ci', ''],
#  ['yamanashi', 'jp'],
#  ['canvas', 'apps', 'chrome'],
#  ['sherubtse', 'edu', 'bt'],
#  ['news', 'te', 'ua'],
#  ['www', 'presidence', 'gov', 'bi'],
#  ['library', 'city', 'izu', 'shizuoka', 'jp'],
#  ['www', '4sansquatre', 'holdings'],
#  ['searchandprint', 'cdn', 'recipes'],
#  ['kugikai', 'city', 'chiyoda', 'tokyo', 'jp'],
#  ['town', 'tohnosho', 'chiba', 'jp'],
#  ['nic', 'dunlop'],
#  ['comune', 'varese', 'it'],
#  ['city', 'machida', 'tokyo', 'jp', 'kids', ''],
#  ['pref', 'nagasaki', 'jp'],
#  ['lib', 'nc', 'us'],
#  ['town', 'kyotamba', 'kyoto', 'jp'],
#  ['takehome', 'cafe'],
#  ['town', 'bandai', 'fukushima', 'jp'],
#  ['comune', 'pistoia', 'it'],
#  ['mainpageinfo', 'reviews'],
#  ['trollhattan', 'fh', 'se'],
#  ['city', 'nerima', 'tokyo', 'jp', 'gikai', 'kids', 'html'],
#  ['packedwithpurpose', 'gifts'],
#  ['alit', 'city', 'iruma', 'saitama', 'jp'],
#  ['mtn', 'net', 'sy'],
#  ['city', 'yokosuka', 'kanagawa', 'jp'],
#  ['town', 'oiso', 'kanagawa', 'jp'],
#  ['documents', 'windhoekcc', 'org', 'na'],
#  ['recruit', 'partners'],
#  ['wiki', 'media', 'hu'],
#  ['wilden', 'beds', 'sch', 'uk'],
#  ['town', 'nagi', 'okayama', 'jp'],
#  ['nic', 'xn', '9krt00a'],
#  ['town', 'sera', 'hiroshima', 'jp'],
#  ['xn', 'ngbd3cxb44c', 'xn', 'mgbab2bd'],
#  ['library', 'yachimata', 'chiba', 'jp'],
#  ['shop', 'pl'],
#  ['google', 'com', 'gi', ''],
#  ['redbridge', 'sch', 'uk'],
#  ['tvbatistasiao', 'cng', 'br'],
#  ['cook', 'islands', 'gov', 'ck'],
#  ['poalim', 'circles', 'eco'],
#  ['lfpa', 'org', 'lb', 'jp', 'login', 'php'],
#  ['sberbank', 'online', 'space'],
#  ['tosho', 'city', 'miura', 'kanagawa', 'jp'],
#  ['region', 'martinique', 'mq'],
#  ['nic', 'taobao'],
#  ['info', 'city', 'tsu', 'mie', 'jp'],
#  ['privacy', 'pfirrmann', 'industries'],
#  ['enterprise', 'maceio', 'br'],
#  ['nic', 'like'],
#  ['ww1', 'city', 'asakuchi', 'okayama', 'jp'],
#  ['okayama', 'jp'],
#  ['sanbatdongsanhanoi', 'info', 'vn'],
#  ['hackney', 'sch', 'uk'],
#  ['city', 'yamanashi', 'yamanashi', 'jp'],
#  ['e', 'access', 'att', 'associates'],
#  ['town', 'anan', 'nagano', 'jp'],
#  ['', 'voentv', 'mil', 'by'],
#  ['edbrooks', 'graphics', 'dither', ''],
#  ['ziv', 'jerusalem', 'k12', 'il', 'engtime', 'html'],
#  ['werbisci', 'parafia', 'nysa', 'pl'],
#  ['cci', 'kani', 'gifu', 'jp'],
#  ['city', 'nagahama', 'shiga', 'jp'],
#  ['town', 'yoshioka', 'gunma', 'jp'],
#  ['home', 'design', 'schmidt'],
#  ['arctos', 'database', 'museum'],
#  ['jacferreira', 'arq', 'br'],
#  ['korem051wk', 'tniad', 'mil', 'id'],
#  ['airkiribati', 'com', 'ki'],
#  ['resellerhosting', 'cheap'],
#  ['43', '128', '92', '128', ''],
#  ['city', 'miyako', 'iwate', 'jp'],
#  ['city', 'shibata', 'niigata', 'jp'],
#  ['town', 'shimokawa', 'hokkaido', 'jp'],
#  ['nic', 'moi'],
#  ['town', 'ikeda', 'gifu', 'jp'],
#  ['city', 'tono', 'iwate', 'jp'],
#  ['nic', 'smile'],
#  ['town', 'yoshinogari', 'saga', 'jp'],
#  ['city', 'hosp', 'naka', 'hiroshima', 'jp'],
#  ['metro', 'daejeon', 'kr'],
#  ['town', 'togitsu', 'nagasaki', 'jp'],
#  ['town', 'hino', 'tottori', 'jp'],
#  ['abcrede', 'tec', 'br'],
#  ['dzkk', 'tsk', 'mil', 'tr'],
#  ['town', 'noheji', 'aomori', 'jp'],
#  ['konskowola', 'pl'],
#  ['ckcc', 'coffee'],
#  ['smbc', 'beauty', ''],
#  ['daa', 'org', 'et'],
#  ['securitydata', 'net', 'ec'],
#  ...]

# %%
def url_to_vector(url, model):
    vectors = [model.wv[token] for token in url if token in model.wv]  # Word2Vec에서 벡터 찾기
    if vectors:
        return np.mean(vectors, axis = 0)  # 여러 단어의 평균 벡터
    else:
        return np.zeros(model.vector_size)  # 단어가 없으면 0 벡터 반환

# %%
word2vec_model = Word2Vec(sentences = train_url, vector_size = 100, window = 5, min_count = 1, sg = 1, workers = 5)

train_url = [url_to_vector(url, word2vec_model) for url in train_url]  # Train 데이터를 벡터로 변환
test_url = [url_to_vector(url, word2vec_model) for url in test_url]

# %%
train_url
# Out:
# [array([ 0.13135266, -0.06107245,  0.5958538 ,  0.6274008 ,  0.8170607 ,
#          0.09341195,  0.21845645,  2.0975432 ,  0.4977639 , -1.8008783 ,
#         -1.8947928 , -1.601408  , -1.0048351 ,  0.38474107,  0.46286175,
#          0.7783929 , -1.1907865 , -0.3380547 , -0.12595764,  0.02678368,
#          0.03385144, -0.04209061, -0.29197967,  1.3204038 ,  1.0719638 ,
#          1.690496  , -0.21261995, -1.0029043 , -0.0390327 ,  0.6162011 ,
#         -1.4225178 ,  0.95801216, -0.06108247, -1.3966124 ,  0.81675464,
#          1.1861869 ,  0.36635166, -0.5061809 , -1.3934982 , -0.34759766,
#         -0.12019032,  0.17517813, -1.715378  ,  0.23410738, -0.05851361,
#         -1.5359557 ,  0.28875092, -0.2955672 , -1.031297  ,  0.79950416,
#         -0.23541534, -0.64490795, -0.90471995,  1.5033228 , -0.8217929 ,
#          0.88569844, -1.4058931 , -0.75157726, -0.77188957, -0.280756  ,
#         -0.20389792,  0.177928  ,  1.0781124 ,  0.5924175 ,  0.56089413,
#          0.73760736, -1.0110824 ,  0.62767637, -0.7010111 ,  1.4488668 ,
#          1.6203787 ,  1.6745124 , -0.42821744, -1.0092038 ,  1.160768  ,
#         -0.562677  ,  0.08855495,  0.19209042,  0.5445609 ,  0.99820995,
#          0.24853438, -1.218307  ,  0.46054435, -1.0536232 , -0.8084028 ,
#         -0.4151014 ,  1.1754    , -0.7845504 ,  0.44080988, -0.17411652,
#          0.9364153 , -0.7436121 , -0.06857538, -1.1526548 ,  1.0606441 ,
#         -0.14507964, -0.4910457 ,  0.34464025,  0.12881677,  0.12737024],
#        dtype=float32),
#  array([ 0.93706965, -0.6680596 ,  1.4621677 , -0.5238884 ,  0.77597857,
#          0.96383923, -0.24069645,  1.1725297 ,  0.68540317, -0.3450259 ,
#         -0.11223992, -1.2241497 , -1.0349442 ,  0.13728973,  0.56975746,
#          0.11994781,  0.47869954, -0.31106192, -0.2359621 , -0.38412908,
#         -0.41235873, -0.7724025 ,  0.34389907,  0.52929187, -0.18086806,
#          0.7857779 , -0.26891118, -1.065075  ,  0.19236517, -0.04663926,
#         -1.305042  ,  0.40162322, -0.5309742 ,  0.30696923,  0.19543749,
#         -0.22989322, -0.70585215, -1.3511527 , -0.74835503, -0.17273788,
#         -0.735896  ,  0.2682485 ,  0.04247722,  0.34942144, -0.7094122 ,
#         -0.5538348 ,  1.3564308 , -0.12310459, -0.04447202,  0.80392575,
#         -0.41956297, -1.4680927 , -0.55944407, -0.05634382,  0.45712343,
#          3.5091880e-01, -4.0667844e-01,  1.4847517e+00,  1.0446119e+00,
#          2.3158611e-01, -1.0235865e+00,  9.8406750e-01,  4.7139931e-01,
#         -4.1363248e-01, -8.7887096e-01,  7.5723045e-03,  2.3072009e-01],
#        dtype=float32),
#  array([ 0.6735702 , -0.040709  ,  0.4502335 , -0.35405335,  1.191634  ,
#          0.20873113,  0.27153882,  1.3869524 ,  0.5362329 ,  0.2403969 ,
#         -0.5091425 , -0.4279432 , -0.4021015 ,  0.8739519 , -0.0251574 ,
#         -0.20928538, -0.7355055 ,  0.44342563,  0.41172695, -0.77357274,
#         -0.37456563, -0.41483614,  0.10062281,  0.7780382 ,  0.6006978 ,
#          0.88626117, -0.5904329 , -0.8195984 , -1.0128931 ,  0.7198844 ,
#          0.5913393 ,  0.44696173,  0.1326716 , -0.87578344,  0.25019896,
#         -0.70046383, -0.8263361 , -0.083583  , -0.5619615 , -0.5111878 ,
#         -0.07886786,  0.5313649 , -1.0843302 ,  0.54793775,  0.2584448 ,
#          0.07900608,  0.13737184,  0.28450865,  0.00877464,  0.40776512,
#          0.31773087,  0.15890612,  0.42880163,  0.51114994, -0.68099874,
#          1.1519226 , -0.17321837, -0.1489665 , -0.02844638, -0.58710915,
#         -0.12926905, -0.9942468 ,  0.08119857,  1.455866  , -0.70023185,
#          0.5668058 ,  0.511391  ,  0.18245916,  0.06329072,  1.0356727 ,
#          0.85152644,  0.60147566,  1.29356   ,  0.03024589,  0.31436387,
#          0.06853589,  0.29495516,  0.76211494,  0.08899031, -0.71376485,
#         -0.36117777,  0.06118127,  0.5128264 , -0.18898411, -1.1335698 ,
#         -0.15273927,  0.10895173, -0.05929371,  0.0562987 , -0.45485225,
#          0.864474  , -0.42013422,  0.16698217, -1.5218092 ,  1.3527406 ,
#         -0.26141986, -0.8707237 , -0.7687893 , -0.39089414,  1.1304361 ],
#        dtype=float32),
#  ...]

# %%
test_df['label'] = None

test_df.head()
# Out:
#              ID                                    URL  length  \
# 0  TEST_0000000             niquelarte.blogspot.com.es      26
# 1  TEST_0000001              northernmetalproducts.com      25
# 2  TEST_0000002                                  ga.de       5
# 3  TEST_0000003  florawww.eeb.uconn.edu/199300089.html      37
# 4  TEST_0000004                      activecity.moscow      17
#
#    subdomain_count  special_char_count label
# 0                2                   0  None
# 1                0                   0  None
# 2                0                   0  None
# 3                3                   1  None
# 4                0                   0  None

# %%
test_df['label'] is not None
# Out:
# True

# %%
test_df = test_df.drop('label', axis = 1)

# %%
test_df
# Out:
#                    ID                                    URL  length  \
# 0        TEST_0000000             niquelarte.blogspot.com.es      26
# 1        TEST_0000001              northernmetalproducts.com      25
# 2        TEST_0000002                                  ga.de       5
# 3        TEST_0000003  florawww.eeb.uconn.edu/199300089.html      37
# 4        TEST_0000004                      activecity.moscow      17
# ...               ...                                    ...     ...
# 1747684  TEST_1747684                     culliganlaredo.com      18
# 1747685  TEST_1747685                       tenzidetailer.pl      16
# 1747686  TEST_1747686              club-hippique-neubourg.fr      25
# 1747687  TEST_1747687                            smbcyt.com/      11
# 1747688  TEST_1747688                      schule-am-ried.de      17
#
#          subdomain_count  special_char_count
# 0                      2                   0
# 1                      0                   0
# 2                      0                   0
# 3                      3                   1
# 4                      0                   0
# ...                  ...                 ...
# 1747684                0                   0
# 1747685                0                   0
# 1747686                0                   2
# 1747687                0                   1
# 1747688                0                   2
#
# [1747689 rows x 5 columns]

# %%
class TextDataset(Dataset):
    def __init__(self, df):
        self.df = df.reset_index(drop=True)
        self.url = df["URL"].values 
        self.extra_features = df[["length", "subdomain_count", "special_char_count"]].values
        self.label = df.get("label")
        

    def __len__(self):
        return len(self.url)
    
    def __getitem__(self, index):
        if self.label is not None:
            return (torch.tensor(self.url[index], dtype = torch.float),
                    torch.tensor(self.extra_features[index], dtype = torch.float),
                    torch.tensor(self.df.label[index], dtype = torch.long))
        else:
            return (torch.tensor(self.url[index], dtype = torch.float),
                    torch.tensor(self.extra_features[index], dtype = torch.float))

# %%
train_df = train_df.drop('ID', axis = 1)
test_df = test_df.drop('ID', axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 train_df = train_df.drop('ID', axis = 1)
#       2 test_df = test_df.drop('ID', axis = 1)
#
# File c:\Users\PNC\anaconda3\envs\Project_38\lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# File c:\Users\PNC\anaconda3\envs\Project_38\lib\site-packages\pandas\core\generic.py:4549, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547 for axis, labels in axes.items():
#    4548     if labels is not None:
# -> 4549         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4551 if inplace:
#    4552     self._update_inplace(obj)
#
# File c:\Users\PNC\anaconda3\envs\Project_38\lib\site-packages\pandas\core\generic.py:4591, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4589         new_axis = axis.drop(labels, level=level, errors=errors)
#    4590     else:
# -> 4591         new_axis = axis.drop(labels, errors=errors)
#    4592     indexer = axis.get_indexer(new_axis)
#    4594 # Case for non-unique axis
#    4595 else:
#
# File c:\Users\PNC\anaconda3\envs\Project_38\lib\site-packages\pandas\core\indexes\base.py:6699, in Index.drop(self, labels, errors)
#    6697 if mask.any():
#    6698     if errors != "ignore":
# -> 6699         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6700     indexer = indexer[~mask]
#    6701 return self.delete(indexer)
#
# KeyError: "['ID'] not found in axis"

# %%
train_df['URL'] = train_url
test_df['URL'] = test_url

# %%
train_df['URL']
# Out:
# 0          [0.13135266, -0.061072446, 0.5958538, 0.627400...
# 1          [0.93706965, -0.6680596, 1.4621677, -0.5238884...
# 2          [0.67947, -0.46105328, 1.5709811, -0.07041367,...
# 3          [1.0482985, -0.618968, 1.7091038, -0.6645212, ...
# 4          [0.51732117, 0.10888648, 0.99268764, -0.023409...
#                                  ...
# 6995051    [1.1164757, -1.2810155, 2.0713985, -0.1134207,...
# 6995052    [0.55901456, -0.3796811, 0.7280678, -0.4327218...
# 6995053    [-0.016048867, 0.20505588, 0.292058, 0.5491625...
# 6995054    [-0.111685924, -0.11088974, 0.38968402, 0.2676...
# 6995055    [-0.11832186, -0.11325248, 0.3921224, 0.275769...
# Name: URL, Length: 6995056, dtype: object

# %%
train_data, val_data = train_test_split(
                                    train_df,
                                    test_size = 0.2, 
                                    random_state = 7
                                )

train_dataset = TextDataset(train_data)
val_dataset = TextDataset(val_data)
test_dataset = TextDataset(test_df)

train_loader = DataLoader(train_dataset, batch_size = 256, shuffle = True)
val_loader = DataLoader(val_dataset, batch_size = 256, shuffle = False)
test_loader = DataLoader(test_dataset, batch_size = 256, shuffle = False)

# %%
class URLClassifier(nn.Module):
    def __init__(self, in_in, in_extra, in_out, out_out, dropout_prob, h_ins = [], h_outs = []):
        super().__init__()

        self.in_layer = nn.Linear(in_in, h_ins[0] if len(h_ins) else in_out)
        self.in_ln = nn.LayerNorm(h_ins[0] if len(h_ins) else in_out)
        self.dropout = nn.Dropout(dropout_prob)
        self.gelu = nn.GELU()
        
        self.h_layers = nn.ModuleList()
        for idx in range(len(h_ins) - 1):
            self.h_layers.append(nn.Linear(h_ins[idx] + 32, h_outs[idx + 1] + 32))
            self.h_layers.append(nn.LayerNorm(h_outs[idx + 1] + 32))
            self.h_layers.append(nn.GELU())
            self.h_layers.append(nn.Dropout(dropout_prob))

        self.extra_layer = nn.Sequential(
        nn.Linear(in_extra, 32),  # 작은 차원으로 변환
        nn.ReLU(),
        nn.Dropout(dropout_prob)
        )

        self.out_layer = nn.Linear(h_outs[-1] + 32 if len(h_outs) else in_out + 32, out_out)

    def forward(self, url_vector, extra_features):
    
        url = self.gelu(self.in_ln(self.in_layer(url_vector)))
        url = self.dropout(url)

        extra_features = self.extra_layer(extra_features)

        y = torch.cat((url, extra_features), dim=1)

        for linear in self.h_layers:
            y = linear(y)
        return F.sigmoid(self.out_layer(y))

# %%
in_in = 100
in_extra = 3
in_out = 100
out_out = 1
h_inouts = [128, 256, 256, 256, 128]
dropout = 0.1

DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'


model = URLClassifier(in_in = in_in, in_extra = 3, in_out = in_out, 
                      out_out = out_out, dropout_prob = dropout,
                      h_ins = h_inouts, h_outs = h_inouts).to(DEVICE)

EPOCH = 300
LR = 0.001

BCEloss = nn.BCELoss()

base_optimizer = optim.Adam(model.parameters(), lr = LR)
optimizer = Lookahead(base_optimizer, k = 5, alpha = 0.5)
scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, mode = 'max', patience = 10, verbose = True)

# %%
def testing(test_loader):
    model.eval()
    test_loss, test_f1 = 0, 0

    with torch.no_grad():
        for test_url, test_extra_features, test_label in test_loader:
            test_url, test_extra_features, test_label = (test_url.to(DEVICE), test_extra_features.to(DEVICE), test_label.to(DEVICE))
            pre_y = model(test_url, test_extra_features)

            test_label = test_label.reshape(-1, 1).float()

            loss = BCEloss(pre_y, test_label)
            test_loss += loss.item()

            score = BinaryF1Score().to(DEVICE)(pre_y, test_label)
            test_f1 += score.item()

    avg_test_loss = test_loss / len(test_loader)
    avg_test_f1 = test_f1 / len(test_loader)

    return avg_test_loss, avg_test_f1

# %%
SAVE_PATH = './saved_models/'
os.makedirs(SAVE_PATH, exist_ok = True)

def training(train_loader, test_loader):
    BREAK_CNT_LOSS = 0
    BREAK_CNT_SCORE = 0
    LIMIT_VALUE = 30

    LOSS_HISTORY, SCORE_HISTORY = [[], []], [[], []]

    for epoch in range(EPOCH):

        model.train()

        SAVE_MODEL = os.path.join(SAVE_PATH, f'model_{epoch}.pth')
        SAVE_FILE = os.path.join(SAVE_PATH, f'model_weights_{epoch}.pth')

        loss_total, score_total = 0, 0

        for train_url, train_extra_features, train_label in train_loader:
            train_url, train_extra_features, train_label = (train_url.to(DEVICE), train_extra_features.to(DEVICE), train_label.to(DEVICE))

            pre_y = model(train_url, train_extra_features)
            train_label = train_label.reshape(-1, 1).float()

            loss = BCEloss(pre_y, train_label)
            loss_total += loss.item()

            score = BinaryF1Score().to(DEVICE)(pre_y, train_label)
            
            score_total += score.item()

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        if epoch % 10 == 0:  # 예시로 10 epoch마다 출력
            for name, param in model.named_parameters():
                if param.grad is not None:
                    print(f'Epoch {epoch + 1}, Gradient for {name}: {param.grad.abs().mean().item()}')


        test_loss, test_f1 = testing(test_loader)

        LOSS_HISTORY[1].append(test_loss)
        SCORE_HISTORY[1].append(test_f1)

        LOSS_HISTORY[0].append(loss_total / len(train_loader))
        SCORE_HISTORY[0].append(score_total / len(train_loader))

        print(f"[{epoch + 1}/{EPOCH}]\n - TRAIN LOSS : {LOSS_HISTORY[0][-1]} TRAIN F1 : {SCORE_HISTORY[0][-1]}")
        print(f"- TEST LOSS : {LOSS_HISTORY[1][-1]} TEST F1 : {SCORE_HISTORY[1][-1]}")

        scheduler.step(test_f1)

            # 학습 진행 모니터링/스케쥴링 - 검증 DS 기준
        # Score 기준
        if len(SCORE_HISTORY[1]) >= 2:
            if SCORE_HISTORY[1][-1] <= SCORE_HISTORY[1][-2]: BREAK_CNT_SCORE += 1

        # 성능이 좋은 학습 가중치 저장

        if len(SCORE_HISTORY[1]) == 1:
            # 첫 번째라서 무조건 모델 파라미터 저장
            torch.save(model.state_dict(), SAVE_FILE)

        else:
            if SCORE_HISTORY[1][-1] > max(SCORE_HISTORY[1][:-1]):
                torch.save(model.state_dict(), SAVE_FILE)

        if BREAK_CNT_SCORE > LIMIT_VALUE:
            print(f'성능 및 손실 개선이 없어서 {epoch} EPOCH에 학습 중단')
            break

    return LOSS_HISTORY, SCORE_HISTORY

# %%
loss, f1 = training(train_loader, val_loader)
# Out:
# Epoch 1, Gradient for in_layer.weight: 0.002278628060594201
# Epoch 1, Gradient for in_layer.bias: 0.006043784320354462
# Epoch 1, Gradient for in_ln.weight: 0.000976785086095333
# Epoch 1, Gradient for in_ln.bias: 0.0014033832121640444
# Epoch 1, Gradient for h_layers.0.weight: 0.0002278510364703834
# Epoch 1, Gradient for h_layers.0.bias: 0.0005781951476819813
# Epoch 1, Gradient for h_layers.1.weight: 0.00037323441938497126
# Epoch 1, Gradient for h_layers.1.bias: 0.0004572452453430742
# Epoch 1, Gradient for h_layers.4.weight: 5.4652715334668756e-05
# Epoch 1, Gradient for h_layers.4.bias: 0.00013459523324854672
# Epoch 1, Gradient for h_layers.5.weight: 0.00016064629016909748
# Epoch 1, Gradient for h_layers.5.bias: 0.00022017899027559906
# Epoch 1, Gradient for h_layers.8.weight: 1.8838281903299503e-05
# Epoch 1, Gradient for h_layers.8.bias: 4.355840792413801e-05
# Epoch 1, Gradient for h_layers.9.weight: 0.0001144846246461384
# Epoch 1, Gradient for h_layers.9.bias: 0.00012470678484532982
# Epoch 1, Gradient for h_layers.12.weight: 2.0710764147224836e-05
# Epoch 1, Gradient for h_layers.12.bias: 3.401028516236693e-05
# Epoch 1, Gradient for h_layers.13.weight: 0.00018971224199049175
# Epoch 1, Gradient for h_layers.13.bias: 0.00021137172007001936
# Epoch 1, Gradient for extra_layer.0.weight: 0.006654819007962942
# Epoch 1, Gradient for extra_layer.0.bias: 0.0010471622226759791
# Epoch 1, Gradient for out_layer.weight: 0.002419708063825965
# Epoch 1, Gradient for out_layer.bias: 0.0017524417489767075
# [1/300]
#  - TRAIN LOSS : 0.15596673873535205 TRAIN F1 : 0.8767775123258958
# - TEST LOSS : 0.14252672731017477 TEST F1 : 0.8835406640965461
# [2/300]
#  - TRAIN LOSS : 0.13833883271705144 TRAIN F1 : 0.8924639703288388
# - TEST LOSS : 0.1318687020525786 TEST F1 : 0.8987931866767968
# [3/300]
#  - TRAIN LOSS : 0.1332183514306729 TRAIN F1 : 0.897033541805681
# - TEST LOSS : 0.12872864684023555 TEST F1 : 0.9010795144018293
# [4/300]
#  - TRAIN LOSS : 0.13028289921656727 TRAIN F1 : 0.8994763632460897
# - TEST LOSS : 0.12637469499676138 TEST F1 : 0.9026982846002675
# [5/300]
#  - TRAIN LOSS : 0.12833371509176705 TRAIN F1 : 0.9010559726421263
# - TEST LOSS : 0.12501414833421676 TEST F1 : 0.9043734371280409
# [6/300]
#  - TRAIN LOSS : 0.12683911005789986 TRAIN F1 : 0.9025510611658454
# - TEST LOSS : 0.1236246276329879 TEST F1 : 0.9049107130688478
# [7/300]
#  - TRAIN LOSS : 0.1256044423672876 TRAIN F1 : 0.9034349896361386
# - TEST LOSS : 0.1558737225196608 TEST F1 : 0.8990597899093175
# [8/300]
#  - TRAIN LOSS : 0.12456373532591533 TRAIN F1 : 0.9042399517298836
# - TEST LOSS : 0.12170274839255096 TEST F1 : 0.9064826174166262
# [9/300]
#  - TRAIN LOSS : 0.12377107916280546 TRAIN F1 : 0.9051511470020527
# - TEST LOSS : 0.12082840715350084 TEST F1 : 0.9071416853440538
# [10/300]
#  - TRAIN LOSS : 0.12294911077827188 TRAIN F1 : 0.9059390484795915
# - TEST LOSS : 0.12062787378627776 TEST F1 : 0.9085090797425189
# Epoch 11, Gradient for in_layer.weight: 0.0015957349678501487
# Epoch 11, Gradient for in_layer.bias: 0.003509470261633396
# Epoch 11, Gradient for in_ln.weight: 0.0018844888545572758
# Epoch 11, Gradient for in_ln.bias: 0.0024428637698292732
# Epoch 11, Gradient for h_layers.0.weight: 0.00017627138004172593
# Epoch 11, Gradient for h_layers.0.bias: 0.0008338179322890937
# Epoch 11, Gradient for h_layers.1.weight: 0.0010197246447205544
# Epoch 11, Gradient for h_layers.1.bias: 0.0011865922715514898
# Epoch 11, Gradient for h_layers.4.weight: 5.695766594726592e-05
# Epoch 11, Gradient for h_layers.4.bias: 0.0002399995573796332
# Epoch 11, Gradient for h_layers.5.weight: 0.0006371997878886759
# Epoch 11, Gradient for h_layers.5.bias: 0.0008760951459407806
# Epoch 11, Gradient for h_layers.8.weight: 1.5467023331439123e-05
# Epoch 11, Gradient for h_layers.8.bias: 7.696790271438658e-05
# Epoch 11, Gradient for h_layers.9.weight: 0.00016864808276295662
# Epoch 11, Gradient for h_layers.9.bias: 0.00020878245413769037
# Epoch 11, Gradient for h_layers.12.weight: 1.09293578134384e-05
# Epoch 11, Gradient for h_layers.12.bias: 2.6092369807884097e-05
# Epoch 11, Gradient for h_layers.13.weight: 0.0005856246571056545
# Epoch 11, Gradient for h_layers.13.bias: 0.0008790825377218425
# Epoch 11, Gradient for extra_layer.0.weight: 0.03159163147211075
# Epoch 11, Gradient for extra_layer.0.bias: 0.00457120593637228
# Epoch 11, Gradient for out_layer.weight: 0.002860025269910693
# Epoch 11, Gradient for out_layer.bias: 0.021750807762145996
# [11/300]
#  - TRAIN LOSS : 0.12228868466402316 TRAIN F1 : 0.9063170234380462
# - TEST LOSS : 0.11931854982580052 TEST F1 : 0.9089458621758882
# [12/300]
#  - TRAIN LOSS : 0.12170315672322249 TRAIN F1 : 0.906804944428957
# - TEST LOSS : 0.11863632493355028 TEST F1 : 0.9098437498276755
# [13/300]
#  - TRAIN LOSS : 0.12110142872463452 TRAIN F1 : 0.907425775207845
# - TEST LOSS : 0.11942376432785286 TEST F1 : 0.9093318699590678
# [14/300]
#  - TRAIN LOSS : 0.12067692032508204 TRAIN F1 : 0.9078545311014258
# - TEST LOSS : 0.11746914201336832 TEST F1 : 0.9101879011461305
# [15/300]
#  - TRAIN LOSS : 0.12027461903522511 TRAIN F1 : 0.9081127890429144
# - TEST LOSS : 0.12419184109797635 TEST F1 : 0.9084292300011407
# [16/300]
#  - TRAIN LOSS : 0.11978480075174995 TRAIN F1 : 0.9084558645820574
# - TEST LOSS : 0.11863699055805953 TEST F1 : 0.9101387995923209
# [17/300]
#  - TRAIN LOSS : 0.11943999356688201 TRAIN F1 : 0.9089323859147161
# - TEST LOSS : 0.11699437626858207 TEST F1 : 0.9113548428556402
# [18/300]
#  - TRAIN LOSS : 0.11903418375312096 TRAIN F1 : 0.9093130968408855
# - TEST LOSS : 0.11712150878979324 TEST F1 : 0.9114688192936443
# [19/300]
#  - TRAIN LOSS : 0.11876095613296002 TRAIN F1 : 0.9093901781837327
# - TEST LOSS : 0.11713005505290908 TEST F1 : 0.9107417117644098
# [20/300]
#  - TRAIN LOSS : 0.11844673095286329 TRAIN F1 : 0.9096474921332514
# - TEST LOSS : 0.1169489185149421 TEST F1 : 0.9108134315304002
# Epoch 21, Gradient for in_layer.weight: 0.001404798706062138
# Epoch 21, Gradient for in_layer.bias: 0.0028937540482729673
# Epoch 21, Gradient for in_ln.weight: 0.0016909176483750343
# Epoch 21, Gradient for in_ln.bias: 0.0027992641553282738
# Epoch 21, Gradient for h_layers.0.weight: 0.00010155428026337177
# Epoch 21, Gradient for h_layers.0.bias: 0.0006222677766345441
# Epoch 21, Gradient for h_layers.1.weight: 0.0007875193259678781
# Epoch 21, Gradient for h_layers.1.bias: 0.0008071442716754973
# Epoch 21, Gradient for h_layers.4.weight: 3.5692948586074635e-05
# Epoch 21, Gradient for h_layers.4.bias: 0.00016056443564593792
# Epoch 21, Gradient for h_layers.5.weight: 0.00035630763159133494
# Epoch 21, Gradient for h_layers.5.bias: 0.0005887853913009167
# Epoch 21, Gradient for h_layers.8.weight: 8.929532668844331e-06
# Epoch 21, Gradient for h_layers.8.bias: 5.4577449191128835e-05
# Epoch 21, Gradient for h_layers.9.weight: 0.0001105477349483408
# Epoch 21, Gradient for h_layers.9.bias: 0.00021591514814645052
# Epoch 21, Gradient for h_layers.12.weight: 7.019016265985556e-06
# Epoch 21, Gradient for h_layers.12.bias: 1.6085181414382532e-05
# Epoch 21, Gradient for h_layers.13.weight: 0.00034571767901070416
# Epoch 21, Gradient for h_layers.13.bias: 0.0008087672176770866
# Epoch 21, Gradient for extra_layer.0.weight: 0.015036573633551598
# Epoch 21, Gradient for extra_layer.0.bias: 0.0020766337402164936
# Epoch 21, Gradient for out_layer.weight: 0.0008517160313203931
# Epoch 21, Gradient for out_layer.bias: 0.01627476140856743
# [21/300]
#  - TRAIN LOSS : 0.11816674397895342 TRAIN F1 : 0.9100156768515693
# - TEST LOSS : 0.1166096525217346 TEST F1 : 0.9111883066492351
# [22/300]
#  - TRAIN LOSS : 0.1179283507522758 TRAIN F1 : 0.9101651345603747
# - TEST LOSS : 0.11648329704836324 TEST F1 : 0.9119070979290236
# [23/300]
#  - TRAIN LOSS : 0.11765420698967216 TRAIN F1 : 0.9105700530241305
# - TEST LOSS : 0.11568080469666003 TEST F1 : 0.911632199344129
# [24/300]
#  - TRAIN LOSS : 0.1173372673288274 TRAIN F1 : 0.9107585037670763
# - TEST LOSS : 0.1180403862888128 TEST F1 : 0.9104054649161943
# [25/300]
#  - TRAIN LOSS : 0.1172248367215903 TRAIN F1 : 0.9108392202488785
# - TEST LOSS : 0.11561138387582003 TEST F1 : 0.9125158455430752
# [26/300]
#  - TRAIN LOSS : 0.1169620553517249 TRAIN F1 : 0.9109858230097186
# - TEST LOSS : 0.1148605902705679 TEST F1 : 0.9127314925630051
# [27/300]
#  - TRAIN LOSS : 0.11672452674447563 TRAIN F1 : 0.9112792804878127
# - TEST LOSS : 0.1157927811786546 TEST F1 : 0.9124378669621851
# [28/300]
#  - TRAIN LOSS : 0.11654614283543929 TRAIN F1 : 0.9114929276792041
# - TEST LOSS : 0.11500833116553567 TEST F1 : 0.9130031719408446
# [29/300]
#  - TRAIN LOSS : 0.11628310995786523 TRAIN F1 : 0.9116587728316481
# - TEST LOSS : 0.11499158353608678 TEST F1 : 0.912761712859556
# [30/300]
#  - TRAIN LOSS : 0.11623162744909334 TRAIN F1 : 0.9117454633975618
# - TEST LOSS : 0.11557490216655024 TEST F1 : 0.9133606710132938
# Epoch 31, Gradient for in_layer.weight: 0.001771829673089087
# Epoch 31, Gradient for in_layer.bias: 0.0035153937060385942
# Epoch 31, Gradient for in_ln.weight: 0.0020519252866506577
# Epoch 31, Gradient for in_ln.bias: 0.00389045849442482
# Epoch 31, Gradient for h_layers.0.weight: 0.00010710671631386504
# Epoch 31, Gradient for h_layers.0.bias: 0.0006647724658250809
# Epoch 31, Gradient for h_layers.1.weight: 0.0008957862155511975
# Epoch 31, Gradient for h_layers.1.bias: 0.000991401611827314
# Epoch 31, Gradient for h_layers.4.weight: 2.8804517569369636e-05
# Epoch 31, Gradient for h_layers.4.bias: 0.00013895099982619286
# Epoch 31, Gradient for h_layers.5.weight: 0.0003005435282830149
# Epoch 31, Gradient for h_layers.5.bias: 0.0004499044443946332
# Epoch 31, Gradient for h_layers.8.weight: 7.624961654073559e-06
# Epoch 31, Gradient for h_layers.8.bias: 3.3445154258515686e-05
# Epoch 31, Gradient for h_layers.9.weight: 9.587759268470109e-05
# Epoch 31, Gradient for h_layers.9.bias: 0.00015458867710549384
# Epoch 31, Gradient for h_layers.12.weight: 4.515200089372229e-06
# Epoch 31, Gradient for h_layers.12.bias: 9.150324331130832e-06
# Epoch 31, Gradient for h_layers.13.weight: 0.0003904638288076967
# Epoch 31, Gradient for h_layers.13.bias: 0.0006588047835975885
# Epoch 31, Gradient for extra_layer.0.weight: 0.025870632380247116
# Epoch 31, Gradient for extra_layer.0.bias: 0.0039023112040013075
# Epoch 31, Gradient for out_layer.weight: 0.0014467723667621613
# Epoch 31, Gradient for out_layer.bias: 0.015984708443284035
# [31/300]
#  - TRAIN LOSS : 0.11595470035126584 TRAIN F1 : 0.9119939720886951
# - TEST LOSS : 0.11563514139697514 TEST F1 : 0.9122528459648418
# [32/300]
#  - TRAIN LOSS : 0.11576834683786236 TRAIN F1 : 0.9119713361287269
# - TEST LOSS : 0.11422564978391778 TEST F1 : 0.9138617806116158
# [33/300]
#  - TRAIN LOSS : 0.11567429773141404 TRAIN F1 : 0.9122211833613135
# - TEST LOSS : 0.11437069964948753 TEST F1 : 0.9139078655050964
# [34/300]
#  - TRAIN LOSS : 0.11553128468859447 TRAIN F1 : 0.9122492157175033
# - TEST LOSS : 0.11464870980270173 TEST F1 : 0.91389067205724
# [35/300]
#  - TRAIN LOSS : 0.11528750588846447 TRAIN F1 : 0.912644595502171
# - TEST LOSS : 0.11377733997448475 TEST F1 : 0.9142720218546764
# [36/300]
#  - TRAIN LOSS : 0.11512970775996369 TRAIN F1 : 0.9126845332399379
# - TEST LOSS : 0.114202012478869 TEST F1 : 0.9126739583316464
# [37/300]
#  - TRAIN LOSS : 0.11501894629332905 TRAIN F1 : 0.9127117345775908
# - TEST LOSS : 0.11311506136761057 TEST F1 : 0.9148210292874621
# [38/300]
#  - TRAIN LOSS : 0.11484736571768392 TRAIN F1 : 0.9127925720682738
# - TEST LOSS : 0.1139834108384972 TEST F1 : 0.9133383156396006
# [39/300]
#  - TRAIN LOSS : 0.11480144316659455 TRAIN F1 : 0.9127945176609481
# - TEST LOSS : 0.11470881472158519 TEST F1 : 0.9116449565049823
# [40/300]
#  - TRAIN LOSS : 0.11459833475993733 TRAIN F1 : 0.9131906718315602
# - TEST LOSS : 0.114034459564736 TEST F1 : 0.9142781978665637
# Epoch 41, Gradient for in_layer.weight: 0.0013151825405657291
# Epoch 41, Gradient for in_layer.bias: 0.003148966934531927
# Epoch 41, Gradient for in_ln.weight: 0.002354396739974618
# Epoch 41, Gradient for in_ln.bias: 0.0036099825520068407
# Epoch 41, Gradient for h_layers.0.weight: 0.00010992843454005197
# Epoch 41, Gradient for h_layers.0.bias: 0.000518524379003793
# Epoch 41, Gradient for h_layers.1.weight: 0.001149614225141704
# Epoch 41, Gradient for h_layers.1.bias: 0.00133797328453511
# Epoch 41, Gradient for h_layers.4.weight: 3.709139855345711e-05
# Epoch 41, Gradient for h_layers.4.bias: 0.0001720347790978849
# Epoch 41, Gradient for h_layers.5.weight: 0.00041915549081750214
# Epoch 41, Gradient for h_layers.5.bias: 0.0006391456699930131
# Epoch 41, Gradient for h_layers.8.weight: 1.0952362572425045e-05
# Epoch 41, Gradient for h_layers.8.bias: 4.2959458369296044e-05
# Epoch 41, Gradient for h_layers.9.weight: 0.00010930174903478473
# Epoch 41, Gradient for h_layers.9.bias: 0.0002081216953229159
# Epoch 41, Gradient for h_layers.12.weight: 4.156054728809977e-06
# Epoch 41, Gradient for h_layers.12.bias: 9.511772077530622e-06
# Epoch 41, Gradient for h_layers.13.weight: 0.00014994222146924585
# Epoch 41, Gradient for h_layers.13.bias: 0.00021816666412632912
# Epoch 41, Gradient for extra_layer.0.weight: 0.0129266157746315
# Epoch 41, Gradient for extra_layer.0.bias: 0.001746616093441844
# Epoch 41, Gradient for out_layer.weight: 0.0006347512826323509
# Epoch 41, Gradient for out_layer.bias: 0.001390127930790186
# [41/300]
#  - TRAIN LOSS : 0.11448064930941518 TRAIN F1 : 0.9132690504179672
# - TEST LOSS : 0.11481183179520404 TEST F1 : 0.9128461458763723
# [42/300]
#  - TRAIN LOSS : 0.11431461638776962 TRAIN F1 : 0.9134241107834226
# - TEST LOSS : 0.11395957091412517 TEST F1 : 0.9134906848526175
# [43/300]
#  - TRAIN LOSS : 0.11421685325712892 TRAIN F1 : 0.9134506242054924
# - TEST LOSS : 0.11358307204520277 TEST F1 : 0.9135392218473737
# [44/300]
#  - TRAIN LOSS : 0.11408256415954271 TRAIN F1 : 0.9136244327675173
# - TEST LOSS : 0.11326703533789267 TEST F1 : 0.9143752236597492
# [45/300]
#  - TRAIN LOSS : 0.1139652320499935 TRAIN F1 : 0.9136537400141618
# - TEST LOSS : 0.11327625552306508 TEST F1 : 0.9143122602032612
# [46/300]
#  - TRAIN LOSS : 0.1138623000103009 TRAIN F1 : 0.9137468641271094
# - TEST LOSS : 0.11425085478894283 TEST F1 : 0.9138849653678538
# [47/300]
#  - TRAIN LOSS : 0.11375091663661455 TRAIN F1 : 0.9138252571593265
# - TEST LOSS : 0.11293053298520583 TEST F1 : 0.9141711230683741
# [48/300]
#  - TRAIN LOSS : 0.11367104472796973 TRAIN F1 : 0.9140214210868646
# - TEST LOSS : 0.11343619604301038 TEST F1 : 0.914598082274553
# [49/300]
#  - TRAIN LOSS : 0.11074677879989406 TRAIN F1 : 0.9163815520356144
# - TEST LOSS : 0.11086713844213263 TEST F1 : 0.9163354644836468
# [50/300]
#  - TRAIN LOSS : 0.11025559083794645 TRAIN F1 : 0.9168427941593029
# - TEST LOSS : 0.11077290899158615 TEST F1 : 0.9161204531447994
# Epoch 51, Gradient for in_layer.weight: 0.0014747950481250882
# Epoch 51, Gradient for in_layer.bias: 0.0037096254527568817
# Epoch 51, Gradient for in_ln.weight: 0.001901858951896429
# Epoch 51, Gradient for in_ln.bias: 0.004180643241852522
# Epoch 51, Gradient for h_layers.0.weight: 6.910153751960024e-05
# Epoch 51, Gradient for h_layers.0.bias: 0.00042191785178147256
# Epoch 51, Gradient for h_layers.1.weight: 0.0008222510223276913
# Epoch 51, Gradient for h_layers.1.bias: 0.0008906424045562744
# Epoch 51, Gradient for h_layers.4.weight: 2.292322642460931e-05
# Epoch 51, Gradient for h_layers.4.bias: 0.00012953458644915372
# Epoch 51, Gradient for h_layers.5.weight: 0.00037890777457505465
# Epoch 51, Gradient for h_layers.5.bias: 0.0005341064534150064
# Epoch 51, Gradient for h_layers.8.weight: 7.629494575667195e-06
# Epoch 51, Gradient for h_layers.8.bias: 4.5330602006288245e-05
# Epoch 51, Gradient for h_layers.9.weight: 0.0001281590375583619
# Epoch 51, Gradient for h_layers.9.bias: 0.00022612900647800416
# Epoch 51, Gradient for h_layers.12.weight: 5.583130132436054e-06
# Epoch 51, Gradient for h_layers.12.bias: 1.843540303525515e-05
# Epoch 51, Gradient for h_layers.13.weight: 0.0004855731676798314
# Epoch 51, Gradient for h_layers.13.bias: 0.0010926941176876426
# Epoch 51, Gradient for extra_layer.0.weight: 0.00871008075773716
# Epoch 51, Gradient for extra_layer.0.bias: 0.0010954018216580153
# Epoch 51, Gradient for out_layer.weight: 0.0010285564931109548
# Epoch 51, Gradient for out_layer.bias: 0.02375415898859501
# [51/300]
#  - TRAIN LOSS : 0.11006709916682442 TRAIN F1 : 0.9169543157257515
# - TEST LOSS : 0.1104605909522149 TEST F1 : 0.9168768916671034
# [52/300]
#  - TRAIN LOSS : 0.10993554386236148 TRAIN F1 : 0.9171184273646277
# - TEST LOSS : 0.11052570596187353 TEST F1 : 0.9164547571542605
# [53/300]
#  - TRAIN LOSS : 0.10987995389375191 TRAIN F1 : 0.917140541533102
# - TEST LOSS : 0.11045293073388872 TEST F1 : 0.9168691277394901
# [54/300]
#  - TRAIN LOSS : 0.10970898941235935 TRAIN F1 : 0.9173548622433461
# - TEST LOSS : 0.11054672921435994 TEST F1 : 0.9164195397635283
# [55/300]
#  - TRAIN LOSS : 0.10974132949333 TRAIN F1 : 0.9171967225208919
# - TEST LOSS : 0.11042799598998361 TEST F1 : 0.9167737949254419
# [56/300]
#  - TRAIN LOSS : 0.10963442689685486 TRAIN F1 : 0.9175225451275065
# - TEST LOSS : 0.11047408476144703 TEST F1 : 0.9164521211674752
# [57/300]
#  - TRAIN LOSS : 0.109715423980525 TRAIN F1 : 0.9173566241222898
# - TEST LOSS : 0.11046099560326758 TEST F1 : 0.9169640080708489
# [58/300]
#  - TRAIN LOSS : 0.10957405715379846 TRAIN F1 : 0.9175364499640705
# - TEST LOSS : 0.11028043123376227 TEST F1 : 0.9167895803185416
# [59/300]
#  - TRAIN LOSS : 0.10957447947288394 TRAIN F1 : 0.9173409188000957
# - TEST LOSS : 0.11057662268331972 TEST F1 : 0.9167930721036905
# [60/300]
#  - TRAIN LOSS : 0.10947620666637839 TRAIN F1 : 0.9174922028432062
# - TEST LOSS : 0.11046092073992918 TEST F1 : 0.9164714132659717
# Epoch 61, Gradient for in_layer.weight: 0.0014663414331153035
# Epoch 61, Gradient for in_layer.bias: 0.003565237857401371
# Epoch 61, Gradient for in_ln.weight: 0.002582632703706622
# Epoch 61, Gradient for in_ln.bias: 0.004531044512987137
# Epoch 61, Gradient for h_layers.0.weight: 9.886400948744267e-05
# Epoch 61, Gradient for h_layers.0.bias: 0.0005701790796592832
# Epoch 61, Gradient for h_layers.1.weight: 0.0009678815258666873
# Epoch 61, Gradient for h_layers.1.bias: 0.001021372969262302
# Epoch 61, Gradient for h_layers.4.weight: 3.5867498809238896e-05
# Epoch 61, Gradient for h_layers.4.bias: 0.0001433749421266839
# Epoch 61, Gradient for h_layers.5.weight: 0.000529554788954556
# Epoch 61, Gradient for h_layers.5.bias: 0.0006711020250804722
# Epoch 61, Gradient for h_layers.8.weight: 9.643525118008256e-06
# Epoch 61, Gradient for h_layers.8.bias: 4.2428826418472454e-05
# Epoch 61, Gradient for h_layers.9.weight: 0.0001229348563356325
# Epoch 61, Gradient for h_layers.9.bias: 0.00020516393124125898
# Epoch 61, Gradient for h_layers.12.weight: 5.279184733808506e-06
# Epoch 61, Gradient for h_layers.12.bias: 1.9890603653038852e-05
# Epoch 61, Gradient for h_layers.13.weight: 0.0004896268364973366
# Epoch 61, Gradient for h_layers.13.bias: 0.000999477575533092
# Epoch 61, Gradient for extra_layer.0.weight: 0.01503207441419363
# Epoch 61, Gradient for extra_layer.0.bias: 0.0020896720234304667
# Epoch 61, Gradient for out_layer.weight: 0.0011201963061466813
# Epoch 61, Gradient for out_layer.bias: 0.021600577980279922
# [61/300]
#  - TRAIN LOSS : 0.10951286923636197 TRAIN F1 : 0.9173818350056389
# - TEST LOSS : 0.11024542793202105 TEST F1 : 0.9168771388218802
# [62/300]
#  - TRAIN LOSS : 0.10949421712859429 TRAIN F1 : 0.9174985555095184
# - TEST LOSS : 0.11029627586409027 TEST F1 : 0.9166953876928136
# [63/300]
#  - TRAIN LOSS : 0.10909065403119207 TRAIN F1 : 0.917790249186378
# - TEST LOSS : 0.11008394793330369 TEST F1 : 0.9169255884001262
# [64/300]
#  - TRAIN LOSS : 0.10912301956896635 TRAIN F1 : 0.9178957711281519
# - TEST LOSS : 0.11002641878374542 TEST F1 : 0.9171025379687847
# [65/300]
#  - TRAIN LOSS : 0.1090573756308836 TRAIN F1 : 0.9179223053982142
# - TEST LOSS : 0.11000411479656345 TEST F1 : 0.9171222354115856
# [66/300]
#  - TRAIN LOSS : 0.10894002031580922 TRAIN F1 : 0.9179951075801911
# - TEST LOSS : 0.11000665579867112 TEST F1 : 0.9171671501562776
# [67/300]
#  - TRAIN LOSS : 0.10901157293530063 TRAIN F1 : 0.9180136480248531
# - TEST LOSS : 0.11005738443113039 TEST F1 : 0.917166989992653
# [68/300]
#  - TRAIN LOSS : 0.10904903575575213 TRAIN F1 : 0.9179456120903953
# - TEST LOSS : 0.10996928529750832 TEST F1 : 0.9171354730196863
# [69/300]
#  - TRAIN LOSS : 0.10895017169531833 TRAIN F1 : 0.9179494933943517
# - TEST LOSS : 0.11003402551978636 TEST F1 : 0.9170666950183076
# [70/300]
#  - TRAIN LOSS : 0.10892936815298951 TRAIN F1 : 0.9179357068645551
# - TEST LOSS : 0.1100139536079418 TEST F1 : 0.9170893866756261
# Epoch 71, Gradient for in_layer.weight: 0.0006525189965032041
# Epoch 71, Gradient for in_layer.bias: 0.0015878449194133282
# Epoch 71, Gradient for in_ln.weight: 0.0015138492453843355
# Epoch 71, Gradient for in_ln.bias: 0.0021871193312108517
# Epoch 71, Gradient for h_layers.0.weight: 5.474860518006608e-05
# Epoch 71, Gradient for h_layers.0.bias: 0.000322058709571138
# Epoch 71, Gradient for h_layers.1.weight: 0.0006774294306524098
# Epoch 71, Gradient for h_layers.1.bias: 0.0006447340128943324
# Epoch 71, Gradient for h_layers.4.weight: 1.8698196072364226e-05
# Epoch 71, Gradient for h_layers.4.bias: 9.677941125119105e-05
# Epoch 71, Gradient for h_layers.5.weight: 0.0003454469551797956
# Epoch 71, Gradient for h_layers.5.bias: 0.0004265674506314099
# Epoch 71, Gradient for h_layers.8.weight: 5.77337050344795e-06
# Epoch 71, Gradient for h_layers.8.bias: 3.802555147558451e-05
# Epoch 71, Gradient for h_layers.9.weight: 0.00010811742686200887
# Epoch 71, Gradient for h_layers.9.bias: 0.00019279273692518473
# Epoch 71, Gradient for h_layers.12.weight: 4.149047981627518e-06
# Epoch 71, Gradient for h_layers.12.bias: 1.403600526828086e-05
# Epoch 71, Gradient for h_layers.13.weight: 0.00037717315717600286
# Epoch 71, Gradient for h_layers.13.bias: 0.0007537674391642213
# Epoch 71, Gradient for extra_layer.0.weight: 0.013468822464346886
# Epoch 71, Gradient for extra_layer.0.bias: 0.0012577830348163843
# Epoch 71, Gradient for out_layer.weight: 0.0009797823149710894
# Epoch 71, Gradient for out_layer.bias: 0.015101620927453041
# [71/300]
#  - TRAIN LOSS : 0.10897525900570984 TRAIN F1 : 0.9178512580058821
# - TEST LOSS : 0.11001786731749309 TEST F1 : 0.9171975563015288
# [72/300]
#  - TRAIN LOSS : 0.10897824559232931 TRAIN F1 : 0.9179295744191368
# - TEST LOSS : 0.11003567213831641 TEST F1 : 0.9170734240391444
# [73/300]
#  - TRAIN LOSS : 0.1089985885678672 TRAIN F1 : 0.9179514702508347
# - TEST LOSS : 0.11003194085517447 TEST F1 : 0.9171000774694166
# [74/300]
#  - TRAIN LOSS : 0.10900833750141943 TRAIN F1 : 0.9179083102439809
# - TEST LOSS : 0.11000031761054806 TEST F1 : 0.9171393833788621
# [75/300]
#  - TRAIN LOSS : 0.10893561255011268 TRAIN F1 : 0.9178747312884099
# - TEST LOSS : 0.11001555114841363 TEST F1 : 0.9171463101475149
# [76/300]
#  - TRAIN LOSS : 0.10897532698066952 TRAIN F1 : 0.9178905909064704
# - TEST LOSS : 0.10998837128826924 TEST F1 : 0.9171507358441959
# [77/300]
#  - TRAIN LOSS : 0.10902365392597166 TRAIN F1 : 0.9179518780627604
# - TEST LOSS : 0.11000385692706102 TEST F1 : 0.9170651246949498
# [78/300]
#  - TRAIN LOSS : 0.10896034816140267 TRAIN F1 : 0.9178920833484252
# - TEST LOSS : 0.1099446608287036 TEST F1 : 0.9172139656074747
# [79/300]
#  - TRAIN LOSS : 0.10895935445989857 TRAIN F1 : 0.9179905957512537
# - TEST LOSS : 0.1099981396136105 TEST F1 : 0.9172231114357846
# [80/300]
#  - TRAIN LOSS : 0.10899911012239788 TRAIN F1 : 0.917864027248537
# - TEST LOSS : 0.10992684523828075 TEST F1 : 0.9172036740066584
# Epoch 81, Gradient for in_layer.weight: 0.0019301113206893206
# Epoch 81, Gradient for in_layer.bias: 0.003256189404055476
# Epoch 81, Gradient for in_ln.weight: 0.001527225598692894
# Epoch 81, Gradient for in_ln.bias: 0.0031968227121979
# Epoch 81, Gradient for h_layers.0.weight: 6.922179454704747e-05
# Epoch 81, Gradient for h_layers.0.bias: 0.00036577769787982106
# Epoch 81, Gradient for h_layers.1.weight: 0.0007071164436638355
# Epoch 81, Gradient for h_layers.1.bias: 0.0007357720751315355
# Epoch 81, Gradient for h_layers.4.weight: 2.501178823877126e-05
# Epoch 81, Gradient for h_layers.4.bias: 0.00010810884850798175
# Epoch 81, Gradient for h_layers.5.weight: 0.00029607414035126567
# Epoch 81, Gradient for h_layers.5.bias: 0.00042322848457843065
# Epoch 81, Gradient for h_layers.8.weight: 7.55993050916004e-06
# Epoch 81, Gradient for h_layers.8.bias: 3.649952122941613e-05
# Epoch 81, Gradient for h_layers.9.weight: 0.0001068522033165209
# Epoch 81, Gradient for h_layers.9.bias: 0.0001649258629186079
# Epoch 81, Gradient for h_layers.12.weight: 4.2032834244309925e-06
# Epoch 81, Gradient for h_layers.12.bias: 7.630863365193363e-06
# Epoch 81, Gradient for h_layers.13.weight: 0.0003750456962734461
# Epoch 81, Gradient for h_layers.13.bias: 0.0006127795204520226
# Epoch 81, Gradient for extra_layer.0.weight: 0.009111026301980019
# Epoch 81, Gradient for extra_layer.0.bias: 0.0013240061234682798
# Epoch 81, Gradient for out_layer.weight: 0.0014428681461140513
# Epoch 81, Gradient for out_layer.bias: 0.01147384662181139
# [81/300]
#  - TRAIN LOSS : 0.1090086492263326 TRAIN F1 : 0.9180167768078993
# - TEST LOSS : 0.10997147790385514 TEST F1 : 0.9171768206363409
# [82/300]
#  - TRAIN LOSS : 0.10895811915210186 TRAIN F1 : 0.9179739057363334
# - TEST LOSS : 0.11005695150672626 TEST F1 : 0.9171162487385148
# 성능 및 손실 개선이 없어서 81 EPOCH에 학습 중단

# %%
MODEL_PATH = './saved_models/'

model = URLClassifier(in_in = in_in, in_out = in_out, in_extra = in_extra,
                      out_out = out_out, dropout_prob = dropout,
                      h_ins = h_inouts, h_outs = h_inouts)

model.load_state_dict(torch.load(MODEL_PATH + 'model_weights_56.pth', weights_only = True, map_location = torch.device('cpu')))
# Out:
# <All keys matched successfully>

# %%
model.eval()

y_test_preds = []

with torch.no_grad():
    for test_url, test_extra_features in test_loader:
        outputs = model(test_url, test_extra_features).squeeze()
        y_test_preds.extend(outputs.cpu().numpy())

submission_df["probability"] = y_test_preds
submission_df.to_csv(DATA_PATH + "submission_mlp.csv", index=False)
